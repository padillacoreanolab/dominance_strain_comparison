# %% [markdown]
# # MED-PC Extracting the Recording Data and Metadata

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from moviepy.editor import *
from datetime import datetime
from IPython.display import Video

# %%
from medpc2excel.medpc_read import medpc_read
import cv2

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %% [markdown]
# ## Getting the Metadata from all the MED-PC Recording Files

# %% [markdown]
# - Getting all the file paths of the recording files(that happen to all end in `.txt`

# %% [markdown]
# # NOTE: The following path must be changed to the directory where your MED-PC recording files are located, if they are not in the specied folder

# %%
all_med_pc_file = sorted(glob.glob("./data/**/*.txt", recursive=True))

# %% [markdown]
# - Use this instead if you're using you're own data

# %% [raw]
# all_med_pc_file = glob.glob("./data/clock_recording/*.txt")

# %%
all_med_pc_file[:10]
# Out:
# ['./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.3v1.4.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 2.1v2.2.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 2.3v2.4.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 3.3v3.4.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 4.1v4.2.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 4.3v4.4.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 3.3v3.4.txt']

# %% [markdown]
# - Selecting only one of the files
#     - The tone times are the same for both C57 and CD1s

# %%
all_med_pc_file[0]
# Out:
# './data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt'

# %% [markdown]
# - Example of what the MED-PC Recording file looks like

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1.2.txt
#
#
#
#
#
#
#
# Start Date: 10/03/22
#
# End Date: 10/03/22
#
# Subject: 1.1v1.2
#
# Experiment: CD1_vs_C57_Comparison
#
# Group: Cage_1
#
# Box: 1
#
# Start Time: 09:45:25
#
# End Time: 10:46:28
#
# MSN: C57_reward_competition
#
# A:    5399.000
#
# D:    8000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    1860.000

# %% [markdown]
# - We will be extracting the first 10 or so lines that look like:
#
# ```
# File: C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (2).txt
#
# Start Date: 05/06/22
#
# End Date: 05/06/22
#
# Subject: 3.4 (2)
#
# Experiment: Pilot of Pilot
#
# Group: Cage 4
#
# Box: 1
#
# Start Time: 12:59:58
#
# End Time: 14:02:38
#
# MSN: levelNP_CS_reward_laserepochON1st_noshock
# ```
#
# - We will just find all the lines that start with "File", "Start Date", "End Date", "Subject", "Experiment", "Group", "Box", "Start Time", "End Time", or "MSN". And then stop once all the metadata types have been collected

# %%
# This makes a nested dictionary of file paths to each individual metadata type
file_path_to_meta_data = extract.metadata.get_all_med_pc_meta_data_from_files(list_of_files=all_med_pc_file)

# %%
for key, value in file_path_to_meta_data.items():
    print("File path: {}".format(key))
    print("Metadata types and associated values: {}".format(value))
    break
# Out:
# File path: ./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt
# Metadata types and associated values: {'File': 'C:\\MED-PC\\Data\\2022-10-03_09h45m_Subject 1.1v1.2.txt', 'Start Date': '10/03/22', 'End Date': '10/03/22', 'Subject': '1.1v1.2', 'Experiment': 'CD1_vs_C57_Comparison', 'Group': 'Cage_1', 'Box': '1', 'Start Time': '09:45:25', 'End Time': '10:46:28', 'MSN': 'C57_reward_competition'}

# %% [markdown]
# ## Making a Dataframe out of the Metadata

# %%
# Turning the dictionary into a Pandas Dataframe
metadata_df = pd.DataFrame.from_dict(file_path_to_meta_data, orient="index")
# Resetting the index because currently the file path is the index 
metadata_df = metadata_df.reset_index()

# %%
metadata_df.head()
# Out:
#                                                index  \
# 0  ./data/med_pc_recording_files/2022-10-03_09h45...
# 1  ./data/med_pc_recording_files/2022-10-03_09h45...
# 2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 3  ./data/med_pc_recording_files/2022-10-03_09h45...
# 4  ./data/med_pc_recording_files/2022-10-03_10h57...
#
#                                                 File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1...   10/03/22  10/03/22
# 1  C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.3v1...   10/03/22  10/03/22
# 2  C:\MED-PC\Data\2022-10-03_09h45m_Subject 2.1v2...   10/03/22  10/03/22
# 3  C:\MED-PC\Data\2022-10-03_09h45m_Subject 2.3v2...   10/03/22  10/03/22
# 4  C:\MED-PC\Data\2022-10-03_10h57m_Subject 3.1v3...   10/03/22  10/03/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0  1.1v1.2  CD1_vs_C57_Comparison  Cage_1   1   09:45:25  10:46:28
# 1  1.3v1.4  CD1_vs_C57_Comparison  Cage_1   2   09:45:25  10:46:28
# 2  2.1v2.2  CD1_vs_C57_Comparison  Cage_2   3   09:45:25  10:46:28
# 3  2.3v2.4  CD1_vs_C57_Comparison  Cage_2   4   09:45:25  10:46:28
# 4  3.1v3.2  CD1_vs_C57_Comparison  Cage_3   1   10:57:09  11:00:18
#
#                       MSN
# 0  C57_reward_competition
# 1  C57_reward_competition
# 2  C57_reward_competition
# 3  C57_reward_competition
# 4  C57_reward_competition

# %%
metadata_df.tail()
# Out:
#                                                 index  \
# 71  ./data/med_pc_recording_files/2022-10-04_14h51...
# 72  ./data/med_pc_recording_files/2022-10-04_15h37...
# 73  ./data/med_pc_recording_files/2022-10-04_15h37...
# 74  ./data/med_pc_recording_files/2022-10-04_15h37...
# 75  ./data/med_pc_recording_files/2022-10-04_15h37...
#
#                                                  File Start Date  End Date  \
# 71  C:\MED-PC\Data\2022-10-04_14h51m_Subject 4.3v4...   10/04/22  10/04/22
# 72  C:\MED-PC\Data\2022-10-04_15h37m_Subject 1.1v1...   10/04/22  10/04/22
# 73  C:\MED-PC\Data\2022-10-04_15h37m_Subject 1.3v1...   10/04/22  10/04/22
# 74  C:\MED-PC\Data\2022-10-04_15h37m_Subject 2.1v2...   10/04/22  10/04/22
# 75  C:\MED-PC\Data\2022-10-04_15h37m_Subject 2.3v2...   10/04/22  10/04/22
#
#     Subject             Experiment   Group Box Start Time  End Time  \
# 71  4.3v4.4  CD1_vs_C57_Comparison  Cage_4   1   14:51:26  15:28:06
# 72  1.1v1.2  CD1_vs_C57_Comparison  Cage_1   4   15:37:25  16:13:43
# 73  1.3v1.4  CD1_vs_C57_Comparison  Cage_1   3   15:37:25  16:13:43
# 74  2.1v2.2  CD1_vs_C57_Comparison  Cage_2   2   15:37:25  16:13:43
# 75  2.3v2.4  CD1_vs_C57_Comparison  Cage_2   1   15:37:25  16:13:43
#
#                        MSN
# 71  CD1_reward_competition
# 72  C57_reward_competition
# 73  C57_reward_competition
# 74  C57_reward_competition
# 75  C57_reward_competition

# %% [markdown]
# - Just getting the numbers out of the column that contains the cage information

# %% [markdown]
# ## Inputting all the MED-PC log files

# %% [markdown]
# - Example of what the MED-PC Script looks like that was ran when recording the behaviors

# %%
med_pc_scripts = glob.glob("./data/**/*.MPC")

# %%
med_pc_scripts
# Out:
# ['./data/med_pc_recording_files/C57_reward_competition.MPC',
#  './data/med_pc_recording_files/CD1_reward_competition.MPC']

# %%
with open(med_pc_scripts[0]) as f:
    lines = f.readlines()
    for line in lines[:100]:
        print(line)
# Out:
# \INPUTS
#
#
#
# ^port = 8
#
#
#
#
#
# \OUTPUTS
#
# ^whitenoise = 1
#
# ^tone1 = 2
#
# ^tone2 = 3
#
# ^pump = 9
#
# ^fan = 16
#
# ^toneled = 17
#
# ^peled = 18
#
#
#
#
#
#
#
# \ARRAYS
#
#
#
# DIM P = 20000 \Port entry time stamp array
#
#
#
# DIM Q = 250 \US delivery time stamp array (absolute)
#
#
#
# DIM R = 250 \US time stamp array (relative to last CS)
#
#
#
# DIM W = 2500 \ITI values used for CS
#
#
#
# DIM S = 2500 \CS presentation values (absolute - every time yellow light turns on)
#
#
#
# DIM N = 20000 \Port exit time stamp array
#
#
#
# DIM K = 250 \CS type
#
#
#
# DIM G = 250 \controlled_stimulus_seconds computer clock time (seconds on clock every time yellow light/tone turns on)
#
#
#
# DIM H = 250 \controlled_stimulus_minutes computer clock time (minutes on clock every time yellow light/tone turns on)
#
#
#
# DIM I = 250 \controlled_stimulus_hours computer clock time (hours every time yellow light/tone turns on)
#
#
#
# DIM B = 2500 \port_entry_seconds computer clock time (seconds on clock every time red light turns on)
#
#
#
# DIM F = 2500 \port_entry_minutes computer clock time (minutes on clock every time red light turns on)
#
#
#
# DIM J = 2500 \port_entry_hours computer clock time (hours every time red light turns on)
#
#
#
#
#
#
#
# \Original List of ITIs
#
#
#
# LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80", 95", 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 90", 80", 90", 100", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90" \, 100", 108", 117", 121", 133", 145", 165" \CS ITI values (tone + houselight)
#
#
#
#
#
#
#
# \Counter and Flag array
#
# DIM C = 6
#
#
#
# \are all 1-indexed i.e. 3 port entries means 3 port entries
#
#
#
# \C(0) counter for number of port entries
#
#
#
# \C(1) counter for CS presentation number
#
#
#
# \C(2) counter for US delivery
#
#
#
# \C(3) flag to indicate if sucrose is in port =0 if no port entry was made, =1 if port entry was made (i.e., no sucrose)
#
#
#
# \C(4) counter for number of port exits
#
#
#
# \C(5) number of CS1 (tones)
#
#
#
# \C(6) number of sucrose deliveries
#
#
#
#
#
#
#
# \Z-pulses
#
#
#
# \Z1: start task after initial delay
#
#
#
# \Z2: start of CS
#
#
#
# \Z3: port entry
#
#
#
# \Z4: port exit
#
#
#
# \Z5: trigger CS1
#
#
#
# \Z6: turn off CS1 triggers
#
#
#
#
#
#
#
# \Variables
#
#
#
# \A - Time since last CS
#
#
#
# \B -
#
#
#
# \C - Counter array
#
#
#
# \D - Current ITI value
#
#
#
# \E - CS ITI values for first few trials

# %% [markdown]
# - We will be using the comments in the MED-PC script(which starts with the `\`) to create a name for the variables. By default, MED-PC uses a single letter as the name of the variable.
#     - This will use the medpc2excel library found in https://github.com/cyf203/medpc2excel
# - Example of the comments in the MED-PC script that we will use the names from:
#
# ```
# \Variables
#
# \A - Time since last CS
#
# \B - Shock intensity
#
# \C - Counter array
#
# \D - Current ITI value
#
# \E - CS ITI values for first few trials
#
# \F - Shock duration
#
# \G -
#
# \H -
#
# \I -
#
# \J - Shock intensity repo
#
# \K - CS type
#
# \L -
#
# \M - CS type repo
#
# \N - Port exit time stamp array
#
# \O -
#
# \P - Port entry time stamp array
#
# \Q - Sucrose delivery time stamp array (absolute)
#
# \R - Sucrose delivery time stamp array (relative to last CS)
#
# \S - CS presentation time stamp array
#
# \T - Session timer
#
# \U - Time since last CS presentation
#
# \V - List of CS ITI values (tone + houselight)
#
# \W - ITI values used for CS one each trial
#
# \X -
#
# \Y - Beam break monitor variable
#
# \Z -
# ```

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1.2.txt
#
#
#
#
#
#
#
# Start Date: 10/03/22
#
# End Date: 10/03/22
#
# Subject: 1.1v1.2
#
# Experiment: CD1_vs_C57_Comparison
#
# Group: Cage_1
#
# Box: 1
#
# Start Time: 09:45:25
#
# End Time: 10:46:28
#
# MSN: C57_reward_competition
#
# A:    5399.000
#
# D:    8000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    1860.000

# %% [markdown]
# - **Please make sure that the corresponding `.mpc` file (aka the MED-PC script) that was ran to create the log file, is also in the same folder**

# %%
all_med_pc_file
# Out:
# ['./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.3v1.4.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 2.1v2.2.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 2.3v2.4.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 3.3v3.4.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 4.1v4.2.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 4.3v4.4.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 3.3v3.4.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 4.1v4.2.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 4.3v4.4.txt',
#  './data/med_pc_recording_files/2022-10-03_11h45m_Subject 5.1v5.2.txt',
#  './data/med_pc_recording_files/2022-10-03_11h45m_Subject 5.3v5.4.txt',
#  './data/med_pc_recording_files/2022-10-03_11h45m_Subject 6.1v6.2.txt',
#  './data/med_pc_recording_files/2022-10-03_11h45m_Subject 6.3v6.4.txt',
#  './data/med_pc_recording_files/2022-10-03_12h32m_Subject 1.1v1.3.txt',
#  './data/med_pc_recording_files/2022-10-03_12h32m_Subject 1.2v1.4.txt',
#  './data/med_pc_recording_files/2022-10-03_12h32m_Subject 2.1v2.3.txt',
#  './data/med_pc_recording_files/2022-10-03_12h32m_Subject 2.2v2.4.txt',
#  './data/med_pc_recording_files/2022-10-03_13h24m_Subject 3.1v3.3.txt',
#  './data/med_pc_recording_files/2022-10-03_13h24m_Subject 3.2v3.4.txt',
#  './data/med_pc_recording_files/2022-10-03_13h24m_Subject 4.1v4.3.txt',
#  './data/med_pc_recording_files/2022-10-03_13h24m_Subject 4.2v4.4.txt',
#  './data/med_pc_recording_files/2022-10-03_14h17m_Subject 5.1v5.3.txt',
#  './data/med_pc_recording_files/2022-10-03_14h17m_Subject 5.2v5.4.txt',
#  './data/med_pc_recording_files/2022-10-03_14h17m_Subject 6.1v6.3.txt',
#  './data/med_pc_recording_files/2022-10-03_14h17m_Subject 6.2v6.4.txt',
#  './data/med_pc_recording_files/2022-10-03_15h04m_Subject 1.1v1.4.txt',
#  './data/med_pc_recording_files/2022-10-03_15h04m_Subject 1.2v1.3.txt',
#  './data/med_pc_recording_files/2022-10-03_15h04m_Subject 2.1v2.4.txt',
#  './data/med_pc_recording_files/2022-10-03_15h04m_Subject 2.2v2.3.txt',
#  './data/med_pc_recording_files/2022-10-03_16h10m_Subject 3.1v3.4.txt',
#  './data/med_pc_recording_files/2022-10-03_16h10m_Subject 3.2v3.3.txt',
#  './data/med_pc_recording_files/2022-10-03_16h10m_Subject 4.1v4.4.txt',
#  './data/med_pc_recording_files/2022-10-03_16h10m_Subject 4.2v4.3.txt',
#  './data/med_pc_recording_files/2022-10-03_16h53m_Subject 5.1v5.4.txt',
#  './data/med_pc_recording_files/2022-10-03_16h53m_Subject 5.2v5.3.txt',
#  './data/med_pc_recording_files/2022-10-03_16h53m_Subject 6.1v6.4.txt',
#  './data/med_pc_recording_files/2022-10-03_16h53m_Subject 6.2v6.3.txt',
#  './data/med_pc_recording_files/2022-10-04_09h07m_Subject 5.1v5.4.txt',
#  './data/med_pc_recording_files/2022-10-04_09h07m_Subject 5.2v5.3.txt',
#  './data/med_pc_recording_files/2022-10-04_09h07m_Subject 6.1v6.4.txt',
#  './data/med_pc_recording_files/2022-10-04_09h07m_Subject 6.2v6.3.txt',
#  './data/med_pc_recording_files/2022-10-04_09h56m_Subject 3.1v3.4.txt',
#  './data/med_pc_recording_files/2022-10-04_09h56m_Subject 3.2v3.3.txt',
#  './data/med_pc_recording_files/2022-10-04_09h56m_Subject 4.1v4.4.txt',
#  './data/med_pc_recording_files/2022-10-04_09h56m_Subject 4.2v4.3.txt',
#  './data/med_pc_recording_files/2022-10-04_10h39m_Subject 1.1v1.4.txt',
#  './data/med_pc_recording_files/2022-10-04_10h39m_Subject 1.2v1.3.txt',
#  './data/med_pc_recording_files/2022-10-04_10h39m_Subject 2.1v2.4.txt',
#  './data/med_pc_recording_files/2022-10-04_10h39m_Subject 2.2v2.3.txt',
#  './data/med_pc_recording_files/2022-10-04_11h42m_Subject 5.1v5.3.txt',
#  './data/med_pc_recording_files/2022-10-04_11h42m_Subject 5.2v5.4.txt',
#  './data/med_pc_recording_files/2022-10-04_11h42m_Subject 6.1v6.3.txt',
#  './data/med_pc_recording_files/2022-10-04_11h42m_Subject 6.2v6.4.txt',
#  './data/med_pc_recording_files/2022-10-04_12h23m_Subject 3.1v3.3.txt',
#  './data/med_pc_recording_files/2022-10-04_12h23m_Subject 3.2v3.4.txt',
#  './data/med_pc_recording_files/2022-10-04_12h23m_Subject 4.1v4.3.txt',
#  './data/med_pc_recording_files/2022-10-04_12h23m_Subject 4.2v4.4.txt',
#  './data/med_pc_recording_files/2022-10-04_13h08m_Subject 1.1v1.3.txt',
#  './data/med_pc_recording_files/2022-10-04_13h08m_Subject 1.2v1.4.txt',
#  './data/med_pc_recording_files/2022-10-04_13h08m_Subject 2.1v2.3.txt',
#  './data/med_pc_recording_files/2022-10-04_13h08m_Subject 2.2v2.4.txt',
#  './data/med_pc_recording_files/2022-10-04_14h12m_Subject 5.1v5.2.txt',
#  './data/med_pc_recording_files/2022-10-04_14h12m_Subject 5.3v5.4.txt',
#  './data/med_pc_recording_files/2022-10-04_14h12m_Subject 6.1v6.2.txt',
#  './data/med_pc_recording_files/2022-10-04_14h12m_Subject 6.3v6.4.txt',
#  './data/med_pc_recording_files/2022-10-04_14h51m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-04_14h51m_Subject 3.3v3.4.txt',
#  './data/med_pc_recording_files/2022-10-04_14h51m_Subject 4.1v4.2.txt',
#  './data/med_pc_recording_files/2022-10-04_14h51m_Subject 4.3v4.4.txt',
#  './data/med_pc_recording_files/2022-10-04_15h37m_Subject 1.1v1.2.txt',
#  './data/med_pc_recording_files/2022-10-04_15h37m_Subject 1.3v1.4.txt',
#  './data/med_pc_recording_files/2022-10-04_15h37m_Subject 2.1v2.2.txt',
#  './data/med_pc_recording_files/2022-10-04_15h37m_Subject 2.3v2.4.txt']

# %%
concatted_medpc_df = extract.dataframe.get_medpc_dataframe_from_list_of_files(medpc_files=[all_med_pc_file[0]])
concatted_medpc_df = concatted_medpc_df.reset_index(drop=True)

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          0.12           64.0      399.0           0.0              60.01
# 1         10.41          144.0      399.0           0.0             140.01
# 2         10.61          234.0      399.0           0.0             230.01
# 3         11.20          314.0      399.0           0.0             310.01
# 4         11.53          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0         0.16        1.0                                    28.0
# 1        10.43        1.0                                    49.0
# 2        10.63        1.0                                    18.0
# 3        11.42        1.0                                    38.0
# 4        11.56        1.0                                    53.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    16.0
# 1                                    17.0
# 2                                    19.0
# 3                                    20.0
# 4                                    21.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  10.0                           29.0
# 1                                  10.0                           39.0
# 2                                  10.0                           39.0
# 3                                  10.0                           39.0
# 4                                  10.0                           40.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           15.0                         10.0  20221003
# 1                           15.0                         10.0  20221003
# 2                           15.0                         10.0  20221003
# 3                           15.0                         10.0  20221003
# 4                           15.0                         10.0  20221003
#
#    subject                                          file_path
# 0  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 1  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 2  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 3  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 4  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...

# %%
concatted_medpc_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 5003           NaN            NaN        NaN           NaN                NaN
# 5004           NaN            NaN        NaN           NaN                NaN
# 5005           NaN            NaN        NaN           NaN                NaN
# 5006           NaN            NaN        NaN           NaN                NaN
# 5007           NaN            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 5003          NaN        NaN                                     NaN
# 5004          NaN        NaN                                     NaN
# 5005          NaN        NaN                                     NaN
# 5006          NaN        NaN                                     NaN
# 5007          NaN        NaN                                     NaN
#
#       (H)controlled_stimulus_minutescomputer  \
# 5003                                     NaN
# 5004                                     NaN
# 5005                                     NaN
# 5006                                     NaN
# 5007                                     NaN
#
#       (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 5003                                   NaN                           20.0
# 5004                                   NaN                            1.0
# 5005                                   NaN                         4385.0
# 5006                                   NaN                           19.0
# 5007                                   NaN                           20.0
#
#       (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 5003                            NaN                          NaN  20221003
# 5004                            NaN                          NaN  20221003
# 5005                            NaN                          NaN  20221003
# 5006                            NaN                          NaN  20221003
# 5007                            NaN                          NaN  20221003
#
#       subject                                          file_path
# 5003  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5004  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5005  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5006  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5007  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...

# %% [markdown]
# - Dropping all rows that don't have the CS presentation time

# %%
cs_time_df = concatted_medpc_df[concatted_medpc_df["(S)CSpresentation"] != 0.0].dropna(subset="(S)CSpresentation")

# %%
cs_time_df = cs_time_df[cs_time_df["(S)CSpresentation"] % 100 != 0]

# %%
cs_time_df["file_path"].unique()
# Out:
# array(['./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt'],
#       dtype=object)

# %%
cs_time_df
# Out:
#     (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0           0.12           64.0      399.0           0.0              60.01
# 1          10.41          144.0      399.0           0.0             140.01
# 2          10.61          234.0      399.0           0.0             230.01
# 3          11.20          314.0      399.0           0.0             310.01
# 4          11.53          389.0      399.0           0.0             385.01
# 5          11.58          489.0      399.0           0.0             485.01
# 6          11.90          584.0      399.0           0.0             580.01
# 7          12.67          674.0      399.0           0.0             670.01
# 8          14.85          754.0      399.0           0.0             750.01
# 9          18.39          844.0      399.0           0.0             840.01
# 10         18.86          944.0      399.0           0.0             940.01
# 11         19.06         1034.0      399.0           0.0            1030.01
# 12         19.17         1154.0      399.0           0.0            1150.01
# 13         19.45         1244.0      399.0           0.0            1240.01
# 14         19.86         1329.0      399.0           0.0            1325.01
# 15         20.48         1419.0      399.0           0.0            1415.01
# 16         20.58         1514.0      399.0           0.0            1510.01
# 17         21.70         1634.0      399.0           0.0            1630.01
# 18         22.00         1714.0      399.0           0.0            1710.01
#
#     (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0          0.16        1.0                                    28.0
# 1         10.43        1.0                                    49.0
# 2         10.63        1.0                                    18.0
# 3         11.42        1.0                                    38.0
# 4         11.56        1.0                                    53.0
# 5         11.88        1.0                                    33.0
# 6         12.16        1.0                                     8.0
# 7         12.93        1.0                                    38.0
# 8         14.91        1.0                                    58.0
# 9         18.83        1.0                                    28.0
# 10        19.04        1.0                                     8.0
# 11        19.13        1.0                                    38.0
# 12        19.43        1.0                                    39.0
# 13        19.48        1.0                                     8.0
# 14        20.46        1.0                                    33.0
# 15        20.56        1.0                                     4.0
# 16        21.68        1.0                                    39.0
# 17        21.80        1.0                                    38.0
# 18        22.04        1.0                                    58.0
#
#     (H)controlled_stimulus_minutescomputer  \
# 0                                     16.0
# 1                                     17.0
# 2                                     19.0
# 3                                     20.0
# 4                                     21.0
# 5                                     23.0
# 6                                     25.0
# 7                                     26.0
# 8                                     27.0
# 9                                     29.0
# 10                                    31.0
# 11                                    32.0
# 12                                    34.0
# 13                                    36.0
# 14                                    37.0
# 15                                    39.0
# 16                                    40.0
# 17                                    42.0
# 18                                    43.0
#
#     (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                   10.0                           29.0
# 1                                   10.0                           39.0
# 2                                   10.0                           39.0
# 3                                   10.0                           39.0
# 4                                   10.0                           40.0
# 5                                   10.0                           40.0
# 6                                   10.0                           40.0
# 7                                   10.0                           41.0
# 8                                   10.0                           43.0
# 9                                   10.0                           47.0
# 10                                  10.0                           47.0
# 11                                  10.0                           48.0
# 12                                  10.0                           48.0
# 13                                  10.0                           48.0
# 14                                  10.0                           48.0
# 15                                  10.0                           49.0
# 16                                  10.0                           49.0
# 17                                  10.0                           50.0
# 18                                  10.0                           50.0
#
#     (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                            15.0                         10.0  20221003
# 1                            15.0                         10.0  20221003
# 2                            15.0                         10.0  20221003
# 3                            15.0                         10.0  20221003
# 4                            15.0                         10.0  20221003
# 5                            15.0                         10.0  20221003
# 6                            15.0                         10.0  20221003
# 7                            15.0                         10.0  20221003
# 8                            15.0                         10.0  20221003
# 9                            15.0                         10.0  20221003
# 10                           15.0                         10.0  20221003
# 11                           15.0                         10.0  20221003
# 12                           15.0                         10.0  20221003
# 13                           15.0                         10.0  20221003
# 14                           15.0                         10.0  20221003
# 15                           15.0                         10.0  20221003
# 16                           15.0                         10.0  20221003
# 17                           15.0                         10.0  20221003
# 18                           15.0                         10.0  20221003
#
#     subject                                          file_path
# 0   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 1   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 2   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 3   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 4   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 6   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 7   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 8   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 9   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 10  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 11  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 12  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 13  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 14  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 15  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 16  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 17  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 18  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...

# %%
cs_time_df["cs_minute_only"] = cs_time_df["(S)CSpresentation"] // 60
cs_time_df["cs_second_only"] = cs_time_df["(S)CSpresentation"] % 60

# %% [markdown]
# ## Getting a list of the Tone presentation times

# %%
cs_presentation_time = cs_time_df[["(S)CSpresentation", "cs_minute_only", "cs_second_only"]].copy()

# %%
cs_presentation_time
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only
# 0               60.01             1.0            0.01
# 1              140.01             2.0           20.01
# 2              230.01             3.0           50.01
# 3              310.01             5.0           10.01
# 4              385.01             6.0           25.01
# 5              485.01             8.0            5.01
# 6              580.01             9.0           40.01
# 7              670.01            11.0           10.01
# 8              750.01            12.0           30.01
# 9              840.01            14.0            0.01
# 10             940.01            15.0           40.01
# 11            1030.01            17.0           10.01
# 12            1150.01            19.0           10.01
# 13            1240.01            20.0           40.01
# 14            1325.01            22.0            5.01
# 15            1415.01            23.0           35.01
# 16            1510.01            25.0           10.01
# 17            1630.01            27.0           10.01
# 18            1710.01            28.0           30.01

# %% [markdown]
# # Importing Video Data

# %%
from IPython.display import Video

# %% [markdown]
# 1. Play the video, and go to time where the first tone is played in the dataframe above
#     - Usually 1 minute
# 2. Note when the first tone is playing in the video
# 3. Subtract the difference between the time that the tone is playing in the video and in the dataframe
#     - i.e. 1 minute 12 seconds - 1 minute = 12 seconds

# %%
video_file_paths = sorted(glob.glob("./data/videos/*/*.mp4", recursive=True))

# %%
for index, file_path in enumerate(video_file_paths):
    print("Index: {} File Path: {}".format(index, file_path))
# Out:
# Index: 0 File Path: ./data/videos/c57/10-03-22_Test_13_2-2v2-4.mp4
# Index: 1 File Path: ./data/videos/c57/10-03-22_Test_25_1-2v1-3.mp4
# Index: 2 File Path: ./data/videos/c57/10-03-22_Test_29_3-2v3-3.mp4
# Index: 3 File Path: ./data/videos/cd1/10-03-22_Test_22_6-1v6-3.mp4
# Index: 4 File Path: ./data/videos/cd1/10-03-22_Test_32_4-1v4-4.mp4
# Index: 5 File Path: ./data/videos/cd1/10-03-22_Test_34_5-1v5-4.mp4

# %%
video_path = video_file_paths[0]

# %%
video_path
# Out:
# './data/videos/c57/10-03-22_Test_13_2-2v2-4.mp4'

# %% [raw]
# Video(video_path, embed=True)

# %% [markdown]
# ## Calculating the predicted tone times in the video based on the difference

# %% [markdown]
# # NOTE: Change the value of the difference below

# %%
cs_time_difference = 11

# %%
cs_presentation_time["video_cs_time"] = cs_presentation_time["(S)CSpresentation"] + cs_time_difference

# %%
cs_presentation_time
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  video_cs_time
# 0               60.01             1.0            0.01          71.01
# 1              140.01             2.0           20.01         151.01
# 2              230.01             3.0           50.01         241.01
# 3              310.01             5.0           10.01         321.01
# 4              385.01             6.0           25.01         396.01
# 5              485.01             8.0            5.01         496.01
# 6              580.01             9.0           40.01         591.01
# 7              670.01            11.0           10.01         681.01
# 8              750.01            12.0           30.01         761.01
# 9              840.01            14.0            0.01         851.01
# 10             940.01            15.0           40.01         951.01
# 11            1030.01            17.0           10.01        1041.01
# 12            1150.01            19.0           10.01        1161.01
# 13            1240.01            20.0           40.01        1251.01
# 14            1325.01            22.0            5.01        1336.01
# 15            1415.01            23.0           35.01        1426.01
# 16            1510.01            25.0           10.01        1521.01
# 17            1630.01            27.0           10.01        1641.01
# 18            1710.01            28.0           30.01        1721.01

# %%
cs_presentation_time["video_cs_minute_only"] = cs_presentation_time["video_cs_time"] // 60
cs_presentation_time["video_cs_second_only"] = cs_presentation_time["video_cs_time"] % 60

# %% [markdown]
# # Converting the tone time to frames

# %% [markdown]
# - Getting the FPS of the video

# %%
cam = cv2.VideoCapture(video_path)
fps = cam.get(cv2.CAP_PROP_FPS)

# %%
fps
# Out:
# 24.867696055527258

# %%
2008/fps
# Out:
# 80.74732759787325

# %% [markdown]
# - Calculating the frame number by multiplying the FPS by the time in the video

# %%
cs_presentation_time["video_cs_frame"] = (cs_presentation_time["video_cs_time"] * fps).astype(int)

# %%
cs_presentation_time.head()
# Out:
#    (S)CSpresentation  cs_minute_only  cs_second_only  video_cs_time  \
# 0              60.01             1.0            0.01          71.01
# 1             140.01             2.0           20.01         151.01
# 2             230.01             3.0           50.01         241.01
# 3             310.01             5.0           10.01         321.01
# 4             385.01             6.0           25.01         396.01
#
#    video_cs_minute_only  video_cs_second_only  video_cs_frame
# 0                   1.0                 11.01            1765
# 1                   2.0                 31.01            3755
# 2                   4.0                  1.01            5993
# 3                   5.0                 21.01            7982
# 4                   6.0                 36.01            9847

# %%
cs_presentation_time.tail()
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  video_cs_time  \
# 14            1325.01            22.0            5.01        1336.01
# 15            1415.01            23.0           35.01        1426.01
# 16            1510.01            25.0           10.01        1521.01
# 17            1630.01            27.0           10.01        1641.01
# 18            1710.01            28.0           30.01        1721.01
#
#     video_cs_minute_only  video_cs_second_only  video_cs_frame
# 14                  22.0                 16.01           33223
# 15                  23.0                 46.01           35461
# 16                  25.0                 21.01           37824
# 17                  27.0                 21.01           40808
# 18                  28.0                 41.01           42797

# %% [markdown]
# # Doing this for all videos

# %% [markdown]
# ## Getting the estimated tone time

# %%
video_file_name_to_sub_dicts = defaultdict(dict)

# %% [raw]
# video_file_names = ["10-03-22_Test_13_2-2v2-4.mp4"
# "10-03-22_Test_25_1-2v1-3.mp4"
# "10-03-22_Test_29_3-2v3-3.mp4"
# "10-03-22_Test_22_6-1v6-3.mp4"
# "10-03-22_Test_32_4-1v4-4.mp4"
# "10-03-22_Test_34_5-1v5-4.mp4"]

# %%
video_file_name_to_sub_dicts["10-03-22_Test_13_2-2v2-4.mp4"]["delay_in_seconds"] = 11
video_file_name_to_sub_dicts["10-03-22_Test_25_1-2v1-3.mp4"]["delay_in_seconds"] = 8
video_file_name_to_sub_dicts["10-03-22_Test_29_3-2v3-3.mp4"]["delay_in_seconds"] = 7
video_file_name_to_sub_dicts["10-03-22_Test_22_6-1v6-3.mp4"]["delay_in_seconds"] = 9
video_file_name_to_sub_dicts["10-03-22_Test_32_4-1v4-4.mp4"]["delay_in_seconds"] = 7
video_file_name_to_sub_dicts["10-03-22_Test_34_5-1v5-4.mp4"]["delay_in_seconds"] = 7

# %%
video_file_name_to_sub_dicts
# Out:
# defaultdict(dict,
#             {'10-03-22_Test_13_2-2v2-4.mp4': {'delay_in_seconds': 11},
#              '10-03-22_Test_25_1-2v1-3.mp4': {'delay_in_seconds': 8},
#              '10-03-22_Test_29_3-2v3-3.mp4': {'delay_in_seconds': 7},
#              '10-03-22_Test_22_6-1v6-3.mp4': {'delay_in_seconds': 9},
#              '10-03-22_Test_32_4-1v4-4.mp4': {'delay_in_seconds': 7},
#              '10-03-22_Test_34_5-1v5-4.mp4': {'delay_in_seconds': 7}})

# %%
cs_presentation_time = cs_time_df[["(S)CSpresentation", "cs_minute_only", "cs_second_only"]].copy()

# %%
for video_relative_path in video_file_paths:
    video_file_name = os.path.basename(video_relative_path)
    video_full_path = os.path.abspath(video_relative_path)
    if video_file_name in video_file_name_to_sub_dicts:
        copy_cs_presentation_time = cs_presentation_time.copy()
        copy_cs_presentation_time["video_file_name"] = video_file_name
        copy_cs_presentation_time["video_full_path"] = video_full_path
        copy_cs_presentation_time["estimated_cs_time_in_seconds"] = copy_cs_presentation_time["(S)CSpresentation"] + video_file_name_to_sub_dicts[video_file_name]["delay_in_seconds"]
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"] = copy_cs_presentation_time

# %%
video_file_name
# Out:
# '10-03-22_Test_34_5-1v5-4.mp4'

# %%
video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  \
# 0               60.01             1.0            0.01
# 1              140.01             2.0           20.01
# 2              230.01             3.0           50.01
# 3              310.01             5.0           10.01
# 4              385.01             6.0           25.01
# 5              485.01             8.0            5.01
# 6              580.01             9.0           40.01
# 7              670.01            11.0           10.01
# 8              750.01            12.0           30.01
# 9              840.01            14.0            0.01
# 10             940.01            15.0           40.01
# 11            1030.01            17.0           10.01
# 12            1150.01            19.0           10.01
# 13            1240.01            20.0           40.01
# 14            1325.01            22.0            5.01
# 15            1415.01            23.0           35.01
# 16            1510.01            25.0           10.01
# 17            1630.01            27.0           10.01
# 18            1710.01            28.0           30.01
#
#                  video_file_name  \
# 0   10-03-22_Test_34_5-1v5-4.mp4
# 1   10-03-22_Test_34_5-1v5-4.mp4
# 2   10-03-22_Test_34_5-1v5-4.mp4
# 3   10-03-22_Test_34_5-1v5-4.mp4
# 4   10-03-22_Test_34_5-1v5-4.mp4
# 5   10-03-22_Test_34_5-1v5-4.mp4
# 6   10-03-22_Test_34_5-1v5-4.mp4
# 7   10-03-22_Test_34_5-1v5-4.mp4
# 8   10-03-22_Test_34_5-1v5-4.mp4
# 9   10-03-22_Test_34_5-1v5-4.mp4
# 10  10-03-22_Test_34_5-1v5-4.mp4
# 11  10-03-22_Test_34_5-1v5-4.mp4
# 12  10-03-22_Test_34_5-1v5-4.mp4
# 13  10-03-22_Test_34_5-1v5-4.mp4
# 14  10-03-22_Test_34_5-1v5-4.mp4
# 15  10-03-22_Test_34_5-1v5-4.mp4
# 16  10-03-22_Test_34_5-1v5-4.mp4
# 17  10-03-22_Test_34_5-1v5-4.mp4
# 18  10-03-22_Test_34_5-1v5-4.mp4
#
#                                       video_full_path  \
# 0   /nancy/user/riwata/projects/behavioral_datafra...
# 1   /nancy/user/riwata/projects/behavioral_datafra...
# 2   /nancy/user/riwata/projects/behavioral_datafra...
# 3   /nancy/user/riwata/projects/behavioral_datafra...
# 4   /nancy/user/riwata/projects/behavioral_datafra...
# 5   /nancy/user/riwata/projects/behavioral_datafra...
# 6   /nancy/user/riwata/projects/behavioral_datafra...
# 7   /nancy/user/riwata/projects/behavioral_datafra...
# 8   /nancy/user/riwata/projects/behavioral_datafra...
# 9   /nancy/user/riwata/projects/behavioral_datafra...
# 10  /nancy/user/riwata/projects/behavioral_datafra...
# 11  /nancy/user/riwata/projects/behavioral_datafra...
# 12  /nancy/user/riwata/projects/behavioral_datafra...
# 13  /nancy/user/riwata/projects/behavioral_datafra...
# 14  /nancy/user/riwata/projects/behavioral_datafra...
# 15  /nancy/user/riwata/projects/behavioral_datafra...
# 16  /nancy/user/riwata/projects/behavioral_datafra...
# 17  /nancy/user/riwata/projects/behavioral_datafra...
# 18  /nancy/user/riwata/projects/behavioral_datafra...
#
#     estimated_cs_time_in_seconds
# 0                          67.01
# 1                         147.01
# 2                         237.01
# 3                         317.01
# 4                         392.01
# 5                         492.01
# 6                         587.01
# 7                         677.01
# 8                         757.01
# 9                         847.01
# 10                        947.01
# 11                       1037.01
# 12                       1157.01
# 13                       1247.01
# 14                       1332.01
# 15                       1422.01
# 16                       1517.01
# 17                       1637.01
# 18                       1717.01

# %% [markdown]
# ## Calculating the estimated tone frame time

# %%
video_file_paths
# Out:
# ['./data/videos/c57/10-03-22_Test_13_2-2v2-4.mp4',
#  './data/videos/c57/10-03-22_Test_25_1-2v1-3.mp4',
#  './data/videos/c57/10-03-22_Test_29_3-2v3-3.mp4',
#  './data/videos/cd1/10-03-22_Test_22_6-1v6-3.mp4',
#  './data/videos/cd1/10-03-22_Test_32_4-1v4-4.mp4',
#  './data/videos/cd1/10-03-22_Test_34_5-1v5-4.mp4']

# %%
for video_relative_path in video_file_paths:
    video_file_name = os.path.basename(video_relative_path)
    print(video_file_name)

    if video_file_name in video_file_name_to_sub_dicts:
        copy_cs_presentation_time = cs_presentation_time.copy()
        copy_cs_presentation_time["video_file_name"] = video_file_name
        copy_cs_presentation_time["estimated_cs_time_in_seconds"] = copy_cs_presentation_time["(S)CSpresentation"] + video_file_name_to_sub_dicts[video_file_name]["delay_in_seconds"]
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"] = copy_cs_presentation_time
        
        
        
        cv2_video_object = cv2.VideoCapture(video_relative_path)
        fps = cv2_video_object.get(cv2.CAP_PROP_FPS)
        video_file_name_to_sub_dicts[video_file_name]["fps"] = fps
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["fps"] = fps
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["estimated_cs_time_in_frames"] = (video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["estimated_cs_time_in_seconds"] * fps)
# Out:
# 10-03-22_Test_13_2-2v2-4.mp4
# 10-03-22_Test_25_1-2v1-3.mp4
# 10-03-22_Test_29_3-2v3-3.mp4
# 10-03-22_Test_22_6-1v6-3.mp4
# 10-03-22_Test_32_4-1v4-4.mp4
# 10-03-22_Test_34_5-1v5-4.mp4

# %%
video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  \
# 0               60.01             1.0            0.01
# 1              140.01             2.0           20.01
# 2              230.01             3.0           50.01
# 3              310.01             5.0           10.01
# 4              385.01             6.0           25.01
# 5              485.01             8.0            5.01
# 6              580.01             9.0           40.01
# 7              670.01            11.0           10.01
# 8              750.01            12.0           30.01
# 9              840.01            14.0            0.01
# 10             940.01            15.0           40.01
# 11            1030.01            17.0           10.01
# 12            1150.01            19.0           10.01
# 13            1240.01            20.0           40.01
# 14            1325.01            22.0            5.01
# 15            1415.01            23.0           35.01
# 16            1510.01            25.0           10.01
# 17            1630.01            27.0           10.01
# 18            1710.01            28.0           30.01
#
#                  video_file_name  estimated_cs_time_in_seconds        fps  \
# 0   10-03-22_Test_34_5-1v5-4.mp4                         67.01  29.837709
# 1   10-03-22_Test_34_5-1v5-4.mp4                        147.01  29.837709
# 2   10-03-22_Test_34_5-1v5-4.mp4                        237.01  29.837709
# 3   10-03-22_Test_34_5-1v5-4.mp4                        317.01  29.837709
# 4   10-03-22_Test_34_5-1v5-4.mp4                        392.01  29.837709
# 5   10-03-22_Test_34_5-1v5-4.mp4                        492.01  29.837709
# 6   10-03-22_Test_34_5-1v5-4.mp4                        587.01  29.837709
# 7   10-03-22_Test_34_5-1v5-4.mp4                        677.01  29.837709
# 8   10-03-22_Test_34_5-1v5-4.mp4                        757.01  29.837709
# 9   10-03-22_Test_34_5-1v5-4.mp4                        847.01  29.837709
# 10  10-03-22_Test_34_5-1v5-4.mp4                        947.01  29.837709
# 11  10-03-22_Test_34_5-1v5-4.mp4                       1037.01  29.837709
# 12  10-03-22_Test_34_5-1v5-4.mp4                       1157.01  29.837709
# 13  10-03-22_Test_34_5-1v5-4.mp4                       1247.01  29.837709
# 14  10-03-22_Test_34_5-1v5-4.mp4                       1332.01  29.837709
# 15  10-03-22_Test_34_5-1v5-4.mp4                       1422.01  29.837709
# 16  10-03-22_Test_34_5-1v5-4.mp4                       1517.01  29.837709
# 17  10-03-22_Test_34_5-1v5-4.mp4                       1637.01  29.837709
# 18  10-03-22_Test_34_5-1v5-4.mp4                       1717.01  29.837709
#
#     estimated_cs_time_in_frames
# 0                   1999.424854
# 1                   4386.441543
# 2                   7071.835318
# 3                   9458.852007
# 4                  11696.680152
# 5                  14680.451013
# 6                  17515.033331
# 7                  20200.427106
# 8                  22587.443795
# 9                  25272.837570
# 10                 28256.608431
# 11                 30942.002206
# 12                 34522.527239
# 13                 37207.921014
# 14                 39744.126246
# 15                 42429.520021
# 16                 45264.102339
# 17                 48844.627372
# 18                 51231.644061

# %% [markdown]
# # Adding the actual frame times

# %%
video_file_name_to_sub_dicts["10-03-22_Test_13_2-2v2-4.mp4"]["first_cs_presentation_frame"] = 1771
video_file_name_to_sub_dicts["10-03-22_Test_25_1-2v1-3.mp4"]["first_cs_presentation_frame"] = 1685
video_file_name_to_sub_dicts["10-03-22_Test_29_3-2v3-3.mp4"]["first_cs_presentation_frame"] = 1669
video_file_name_to_sub_dicts["10-03-22_Test_22_6-1v6-3.mp4"]["first_cs_presentation_frame"] = 2055
video_file_name_to_sub_dicts["10-03-22_Test_32_4-1v4-4.mp4"]["first_cs_presentation_frame"] = 1669
video_file_name_to_sub_dicts["10-03-22_Test_34_5-1v5-4.mp4"]["first_cs_presentation_frame"] = 2008

# %%
for video_relative_path in video_file_paths:
    video_file_name = os.path.basename(video_relative_path)
    if video_file_name in video_file_name_to_sub_dicts:
        first_cs_presentation_in_frames = video_file_name_to_sub_dicts[video_file_name]["first_cs_presentation_frame"]       
        estimated_vs_actual_first_cs_presentation_in_frames_difference = first_cs_presentation_in_frames - video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["estimated_cs_time_in_frames"].iloc[0]
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["observed_cs_presentation_in_frame"] = (video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["estimated_cs_time_in_frames"] + estimated_vs_actual_first_cs_presentation_in_frames_difference).round(0).astype(int)
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["observed_cs_presentation_in_seconds"] = (video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["observed_cs_presentation_in_frame"] / video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["fps"]).round(2)
        
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["10_seconds_before_cs_presentation_in_frame"] = video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["observed_cs_presentation_in_frame"] - (10 * video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["fps"])
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["10_seconds_before_cs_presentation_in_frame"] = (video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["10_seconds_before_cs_presentation_in_frame"]).round(0).astype(int)
        
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["10_seconds_after_cs_presentation_in_frame"] = video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["observed_cs_presentation_in_frame"] + (10 * video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["fps"])
        video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["10_seconds_after_cs_presentation_in_frame"] = (video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]["10_seconds_after_cs_presentation_in_frame"]).round(0).astype(int)

# %%
video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"]
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  \
# 0               60.01             1.0            0.01
# 1              140.01             2.0           20.01
# 2              230.01             3.0           50.01
# 3              310.01             5.0           10.01
# 4              385.01             6.0           25.01
# 5              485.01             8.0            5.01
# 6              580.01             9.0           40.01
# 7              670.01            11.0           10.01
# 8              750.01            12.0           30.01
# 9              840.01            14.0            0.01
# 10             940.01            15.0           40.01
# 11            1030.01            17.0           10.01
# 12            1150.01            19.0           10.01
# 13            1240.01            20.0           40.01
# 14            1325.01            22.0            5.01
# 15            1415.01            23.0           35.01
# 16            1510.01            25.0           10.01
# 17            1630.01            27.0           10.01
# 18            1710.01            28.0           30.01
#
#                  video_file_name  estimated_cs_time_in_seconds        fps  \
# 0   10-03-22_Test_34_5-1v5-4.mp4                         67.01  29.837709
# 1   10-03-22_Test_34_5-1v5-4.mp4                        147.01  29.837709
# 2   10-03-22_Test_34_5-1v5-4.mp4                        237.01  29.837709
# 3   10-03-22_Test_34_5-1v5-4.mp4                        317.01  29.837709
# 4   10-03-22_Test_34_5-1v5-4.mp4                        392.01  29.837709
# 5   10-03-22_Test_34_5-1v5-4.mp4                        492.01  29.837709
# 6   10-03-22_Test_34_5-1v5-4.mp4                        587.01  29.837709
# 7   10-03-22_Test_34_5-1v5-4.mp4                        677.01  29.837709
# 8   10-03-22_Test_34_5-1v5-4.mp4                        757.01  29.837709
# 9   10-03-22_Test_34_5-1v5-4.mp4                        847.01  29.837709
# 10  10-03-22_Test_34_5-1v5-4.mp4                        947.01  29.837709
# 11  10-03-22_Test_34_5-1v5-4.mp4                       1037.01  29.837709
# 12  10-03-22_Test_34_5-1v5-4.mp4                       1157.01  29.837709
# 13  10-03-22_Test_34_5-1v5-4.mp4                       1247.01  29.837709
# 14  10-03-22_Test_34_5-1v5-4.mp4                       1332.01  29.837709
# 15  10-03-22_Test_34_5-1v5-4.mp4                       1422.01  29.837709
# 16  10-03-22_Test_34_5-1v5-4.mp4                       1517.01  29.837709
# 17  10-03-22_Test_34_5-1v5-4.mp4                       1637.01  29.837709
# 18  10-03-22_Test_34_5-1v5-4.mp4                       1717.01  29.837709
#
#     estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
# 0                   1999.424854                               2008
# 1                   4386.441543                               4395
# 2                   7071.835318                               7080
# 3                   9458.852007                               9467
# 4                  11696.680152                              11705
# 5                  14680.451013                              14689
# 6                  17515.033331                              17524
# 7                  20200.427106                              20209
# 8                  22587.443795                              22596
# 9                  25272.837570                              25281
# 10                 28256.608431                              28265
# 11                 30942.002206                              30951
# 12                 34522.527239                              34531
# 13                 37207.921014                              37216
# 14                 39744.126246                              39753
# 15                 42429.520021                              42438
# 16                 45264.102339                              45273
# 17                 48844.627372                              48853
# 18                 51231.644061                              51240
#
#     observed_cs_presentation_in_seconds  \
# 0                                 67.30
# 1                                147.30
# 2                                237.28
# 3                                317.28
# 4                                392.29
# 5                                492.30
# 6                                587.31
# 7                                677.30
# 8                                757.30
# 9                                847.28
# 10                               947.29
# 11                              1037.31
# 12                              1157.29
# 13                              1247.28
# 14                              1332.31
# 15                              1422.29
# 16                              1517.31
# 17                              1637.29
# 18                              1717.29
#
#     10_seconds_before_cs_presentation_in_frame  \
# 0                                         1710
# 1                                         4097
# 2                                         6782
# 3                                         9169
# 4                                        11407
# 5                                        14391
# 6                                        17226
# 7                                        19911
# 8                                        22298
# 9                                        24983
# 10                                       27967
# 11                                       30653
# 12                                       34233
# 13                                       36918
# 14                                       39455
# 15                                       42140
# 16                                       44975
# 17                                       48555
# 18                                       50942
#
#     10_seconds_after_cs_presentation_in_frame
# 0                                        2306
# 1                                        4693
# 2                                        7378
# 3                                        9765
# 4                                       12003
# 5                                       14987
# 6                                       17822
# 7                                       20507
# 8                                       22894
# 9                                       25579
# 10                                      28563
# 11                                      31249
# 12                                      34829
# 13                                      37514
# 14                                      40051
# 15                                      42736
# 16                                      45571
# 17                                      49151
# 18                                      51538

# %% [markdown]
# - Combining all the videos

# %%
all_cs_presentation_df_list = []
for video_relative_path in video_file_paths:
    video_file_name = os.path.basename(video_relative_path)
    if video_file_name in video_file_name_to_sub_dicts:
        all_cs_presentation_df_list.append(video_file_name_to_sub_dicts[video_file_name]["cs_presentation_df"])

# %%
all_cs_presentation_df_list
# Out:
# [    (S)CSpresentation  cs_minute_only  cs_second_only  \
#  0               60.01             1.0            0.01
#  1              140.01             2.0           20.01
#  2              230.01             3.0           50.01
#  3              310.01             5.0           10.01
#  4              385.01             6.0           25.01
#  5              485.01             8.0            5.01
#  6              580.01             9.0           40.01
#  7              670.01            11.0           10.01
#  8              750.01            12.0           30.01
#  9              840.01            14.0            0.01
#  10             940.01            15.0           40.01
#  11            1030.01            17.0           10.01
#  12            1150.01            19.0           10.01
#  13            1240.01            20.0           40.01
#  14            1325.01            22.0            5.01
#  15            1415.01            23.0           35.01
#  16            1510.01            25.0           10.01
#  17            1630.01            27.0           10.01
#  18            1710.01            28.0           30.01
#
#                   video_file_name  estimated_cs_time_in_seconds        fps  \
#  0   10-03-22_Test_13_2-2v2-4.mp4                         71.01  24.867696
#  1   10-03-22_Test_13_2-2v2-4.mp4                        151.01  24.867696
#  2   10-03-22_Test_13_2-2v2-4.mp4                        241.01  24.867696
#  3   10-03-22_Test_13_2-2v2-4.mp4                        321.01  24.867696
#  4   10-03-22_Test_13_2-2v2-4.mp4                        396.01  24.867696
#  5   10-03-22_Test_13_2-2v2-4.mp4                        496.01  24.867696
#  6   10-03-22_Test_13_2-2v2-4.mp4                        591.01  24.867696
#  7   10-03-22_Test_13_2-2v2-4.mp4                        681.01  24.867696
#  8   10-03-22_Test_13_2-2v2-4.mp4                        761.01  24.867696
#  9   10-03-22_Test_13_2-2v2-4.mp4                        851.01  24.867696
#  10  10-03-22_Test_13_2-2v2-4.mp4                        951.01  24.867696
#  11  10-03-22_Test_13_2-2v2-4.mp4                       1041.01  24.867696
#  12  10-03-22_Test_13_2-2v2-4.mp4                       1161.01  24.867696
#  13  10-03-22_Test_13_2-2v2-4.mp4                       1251.01  24.867696
#  14  10-03-22_Test_13_2-2v2-4.mp4                       1336.01  24.867696
#  15  10-03-22_Test_13_2-2v2-4.mp4                       1426.01  24.867696
#  16  10-03-22_Test_13_2-2v2-4.mp4                       1521.01  24.867696
#  17  10-03-22_Test_13_2-2v2-4.mp4                       1641.01  24.867696
#  18  10-03-22_Test_13_2-2v2-4.mp4                       1721.01  24.867696
#
#      estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
#  0                   1765.855097                               1771
#  1                   3755.270781                               3760
#  2                   5993.363426                               5999
#  3                   7982.779111                               7988
#  4                   9847.856315                               9853
#  5                  12334.625921                              12340
#  6                  14697.057046                              14702
#  7                  16935.149691                              16940
#  8                  18924.565375                              18930
#  9                  21162.658020                              21168
#  10                 23649.427626                              23655
#  11                 25887.520271                              25893
#  12                 28871.643797                              28877
#  13                 31109.736442                              31115
#  14                 33223.490607                              33229
#  15                 35461.583252                              35467
#  16                 37824.014377                              37829
#  17                 40808.137904                              40813
#  18                 42797.553589                              42803
#
#      observed_cs_presentation_in_seconds  \
#  0                                 71.22
#  1                                151.20
#  2                                241.24
#  3                                321.22
#  4                                396.22
#  5                                496.23
#  6                                591.21
#  7                                681.21
#  8                                761.23
#  9                                851.22
#  10                               951.23
#  11                              1041.23
#  12                              1161.23
#  13                              1251.22
#  14                              1336.23
#  15                              1426.23
#  16                              1521.21
#  17                              1641.21
#  18                              1721.23
#
#      10_seconds_before_cs_presentation_in_frame  \
#  0                                         1522
#  1                                         3511
#  2                                         5750
#  3                                         7739
#  4                                         9604
#  5                                        12091
#  6                                        14453
#  7                                        16691
#  8                                        18681
#  9                                        20919
#  10                                       23406
#  11                                       25644
#  12                                       28628
#  13                                       30866
#  14                                       32980
#  15                                       35218
#  16                                       37580
#  17                                       40564
#  18                                       42554
#
#      10_seconds_after_cs_presentation_in_frame
#  0                                        2020
#  1                                        4009
#  2                                        6248
#  3                                        8237
#  4                                       10102
#  5                                       12589
#  6                                       14951
#  7                                       17189
#  8                                       19179
#  9                                       21417
#  10                                      23904
#  11                                      26142
#  12                                      29126
#  13                                      31364
#  14                                      33478
#  15                                      35716
#  16                                      38078
#  17                                      41062
#  18                                      43052  ,
#      (S)CSpresentation  cs_minute_only  cs_second_only  \
#  0               60.01             1.0            0.01
#  1              140.01             2.0           20.01
#  2              230.01             3.0           50.01
#  3              310.01             5.0           10.01
#  4              385.01             6.0           25.01
#  5              485.01             8.0            5.01
#  6              580.01             9.0           40.01
#  7              670.01            11.0           10.01
#  8              750.01            12.0           30.01
#  9              840.01            14.0            0.01
#  10             940.01            15.0           40.01
#  11            1030.01            17.0           10.01
#  12            1150.01            19.0           10.01
#  13            1240.01            20.0           40.01
#  14            1325.01            22.0            5.01
#  15            1415.01            23.0           35.01
#  16            1510.01            25.0           10.01
#  17            1630.01            27.0           10.01
#  18            1710.01            28.0           30.01
#
#                   video_file_name  estimated_cs_time_in_seconds        fps  \
#  0   10-03-22_Test_25_1-2v1-3.mp4                         68.01  24.847611
#  1   10-03-22_Test_25_1-2v1-3.mp4                        148.01  24.847611
#  2   10-03-22_Test_25_1-2v1-3.mp4                        238.01  24.847611
#  3   10-03-22_Test_25_1-2v1-3.mp4                        318.01  24.847611
#  4   10-03-22_Test_25_1-2v1-3.mp4                        393.01  24.847611
#  5   10-03-22_Test_25_1-2v1-3.mp4                        493.01  24.847611
#  6   10-03-22_Test_25_1-2v1-3.mp4                        588.01  24.847611
#  7   10-03-22_Test_25_1-2v1-3.mp4                        678.01  24.847611
#  8   10-03-22_Test_25_1-2v1-3.mp4                        758.01  24.847611
#  9   10-03-22_Test_25_1-2v1-3.mp4                        848.01  24.847611
#  10  10-03-22_Test_25_1-2v1-3.mp4                        948.01  24.847611
#  11  10-03-22_Test_25_1-2v1-3.mp4                       1038.01  24.847611
#  12  10-03-22_Test_25_1-2v1-3.mp4                       1158.01  24.847611
#  13  10-03-22_Test_25_1-2v1-3.mp4                       1248.01  24.847611
#  14  10-03-22_Test_25_1-2v1-3.mp4                       1333.01  24.847611
#  15  10-03-22_Test_25_1-2v1-3.mp4                       1423.01  24.847611
#  16  10-03-22_Test_25_1-2v1-3.mp4                       1518.01  24.847611
#  17  10-03-22_Test_25_1-2v1-3.mp4                       1638.01  24.847611
#  18  10-03-22_Test_25_1-2v1-3.mp4                       1718.01  24.847611
#
#      estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
#  0                   1689.886034                               1685
#  1                   3677.694926                               3673
#  2                   5913.979929                               5909
#  3                   7901.788821                               7897
#  4                   9765.359657                               9760
#  5                  12250.120772                              12245
#  6                  14610.643831                              14606
#  7                  16846.928835                              16842
#  8                  18834.737727                              18830
#  9                  21071.022730                              21066
#  10                 23555.783845                              23551
#  11                 25792.068848                              25787
#  12                 28773.782186                              28769
#  13                 31010.067189                              31005
#  14                 33122.114137                              33117
#  15                 35358.399140                              35354
#  16                 37718.922199                              37714
#  17                 40700.635537                              40696
#  18                 42688.444429                              42684
#
#      observed_cs_presentation_in_seconds  \
#  0                                 67.81
#  1                                147.82
#  2                                237.81
#  3                                317.82
#  4                                392.79
#  5                                492.80
#  6                                587.82
#  7                                677.81
#  8                                757.82
#  9                                847.81
#  10                               947.82
#  11                              1037.81
#  12                              1157.82
#  13                              1247.81
#  14                              1332.80
#  15                              1422.83
#  16                              1517.81
#  17                              1637.82
#  18                              1717.83
#
#      10_seconds_before_cs_presentation_in_frame  \
#  0                                         1437
#  1                                         3425
#  2                                         5661
#  3                                         7649
#  4                                         9512
#  5                                        11997
#  6                                        14358
#  7                                        16594
#  8                                        18582
#  9                                        20818
#  10                                       23303
#  11                                       25539
#  12                                       28521
#  13                                       30757
#  14                                       32869
#  15                                       35106
#  16                                       37466
#  17                                       40448
#  18                                       42436
#
#      10_seconds_after_cs_presentation_in_frame
#  0                                        1933
#  1                                        3921
#  2                                        6157
#  3                                        8145
#  4                                       10008
#  5                                       12493
#  6                                       14854
#  7                                       17090
#  8                                       19078
#  9                                       21314
#  10                                      23799
#  11                                      26035
#  12                                      29017
#  13                                      31253
#  14                                      33365
#  15                                      35602
#  16                                      37962
#  17                                      40944
#  18                                      42932  ,
#      (S)CSpresentation  cs_minute_only  cs_second_only  \
#  0               60.01             1.0            0.01
#  1              140.01             2.0           20.01
#  2              230.01             3.0           50.01
#  3              310.01             5.0           10.01
#  4              385.01             6.0           25.01
#  5              485.01             8.0            5.01
#  6              580.01             9.0           40.01
#  7              670.01            11.0           10.01
#  8              750.01            12.0           30.01
#  9              840.01            14.0            0.01
#  10             940.01            15.0           40.01
#  11            1030.01            17.0           10.01
#  12            1150.01            19.0           10.01
#  13            1240.01            20.0           40.01
#  14            1325.01            22.0            5.01
#  15            1415.01            23.0           35.01
#  16            1510.01            25.0           10.01
#  17            1630.01            27.0           10.01
#  18            1710.01            28.0           30.01
#
#                   video_file_name  estimated_cs_time_in_seconds        fps  \
#  0   10-03-22_Test_29_3-2v3-3.mp4                         67.01  24.855201
#  1   10-03-22_Test_29_3-2v3-3.mp4                        147.01  24.855201
#  2   10-03-22_Test_29_3-2v3-3.mp4                        237.01  24.855201
#  3   10-03-22_Test_29_3-2v3-3.mp4                        317.01  24.855201
#  4   10-03-22_Test_29_3-2v3-3.mp4                        392.01  24.855201
#  5   10-03-22_Test_29_3-2v3-3.mp4                        492.01  24.855201
#  6   10-03-22_Test_29_3-2v3-3.mp4                        587.01  24.855201
#  7   10-03-22_Test_29_3-2v3-3.mp4                        677.01  24.855201
#  8   10-03-22_Test_29_3-2v3-3.mp4                        757.01  24.855201
#  9   10-03-22_Test_29_3-2v3-3.mp4                        847.01  24.855201
#  10  10-03-22_Test_29_3-2v3-3.mp4                        947.01  24.855201
#  11  10-03-22_Test_29_3-2v3-3.mp4                       1037.01  24.855201
#  12  10-03-22_Test_29_3-2v3-3.mp4                       1157.01  24.855201
#  13  10-03-22_Test_29_3-2v3-3.mp4                       1247.01  24.855201
#  14  10-03-22_Test_29_3-2v3-3.mp4                       1332.01  24.855201
#  15  10-03-22_Test_29_3-2v3-3.mp4                       1422.01  24.855201
#  16  10-03-22_Test_29_3-2v3-3.mp4                       1517.01  24.855201
#  17  10-03-22_Test_29_3-2v3-3.mp4                       1637.01  24.855201
#  18  10-03-22_Test_29_3-2v3-3.mp4                       1717.01  24.855201
#
#      estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
#  0                   1665.547016                               1669
#  1                   3653.963091                               3657
#  2                   5890.931177                               5894
#  3                   7879.347253                               7883
#  4                   9743.487324                               9747
#  5                  12229.007419                              12232
#  6                  14590.251509                              14594
#  7                  16827.219594                              16831
#  8                  18815.635670                              18819
#  9                  21052.603755                              21056
#  10                 23538.123850                              23542
#  11                 25775.091935                              25779
#  12                 28757.716049                              28761
#  13                 30994.684135                              30998
#  14                 33107.376215                              33111
#  15                 35344.344301                              35348
#  16                 37705.588391                              37709
#  17                 40688.212504                              40692
#  18                 42676.628580                              42680
#
#      observed_cs_presentation_in_seconds  \
#  0                                 67.15
#  1                                147.13
#  2                                237.13
#  3                                317.16
#  4                                392.15
#  5                                492.13
#  6                                587.16
#  7                                677.16
#  8                                757.15
#  9                                847.15
#  10                               947.17
#  11                              1037.17
#  12                              1157.14
#  13                              1247.14
#  14                              1332.16
#  15                              1422.16
#  16                              1517.15
#  17                              1637.16
#  18                              1717.15
#
#      10_seconds_before_cs_presentation_in_frame  \
#  0                                         1420
#  1                                         3408
#  2                                         5645
#  3                                         7634
#  4                                         9498
#  5                                        11983
#  6                                        14345
#  7                                        16582
#  8                                        18570
#  9                                        20807
#  10                                       23293
#  11                                       25530
#  12                                       28512
#  13                                       30749
#  14                                       32862
#  15                                       35099
#  16                                       37460
#  17                                       40443
#  18                                       42431
#
#      10_seconds_after_cs_presentation_in_frame
#  0                                        1918
#  1                                        3906
#  2                                        6143
#  3                                        8132
#  4                                        9996
#  5                                       12481
#  6                                       14843
#  7                                       17080
#  8                                       19068
#  9                                       21305
#  10                                      23791
#  11                                      26028
#  12                                      29010
#  13                                      31247
#  14                                      33360
#  15                                      35597
#  16                                      37958
#  17                                      40941
#  18                                      42929  ,
#      (S)CSpresentation  cs_minute_only  cs_second_only  \
#  0               60.01             1.0            0.01
#  1              140.01             2.0           20.01
#  2              230.01             3.0           50.01
#  3              310.01             5.0           10.01
#  4              385.01             6.0           25.01
#  5              485.01             8.0            5.01
#  6              580.01             9.0           40.01
#  7              670.01            11.0           10.01
#  8              750.01            12.0           30.01
#  9              840.01            14.0            0.01
#  10             940.01            15.0           40.01
#  11            1030.01            17.0           10.01
#  12            1150.01            19.0           10.01
#  13            1240.01            20.0           40.01
#  14            1325.01            22.0            5.01
#  15            1415.01            23.0           35.01
#  16            1510.01            25.0           10.01
#  17            1630.01            27.0           10.01
#  18            1710.01            28.0           30.01
#
#                   video_file_name  estimated_cs_time_in_seconds        fps  \
#  0   10-03-22_Test_22_6-1v6-3.mp4                         69.01  29.835108
#  1   10-03-22_Test_22_6-1v6-3.mp4                        149.01  29.835108
#  2   10-03-22_Test_22_6-1v6-3.mp4                        239.01  29.835108
#  3   10-03-22_Test_22_6-1v6-3.mp4                        319.01  29.835108
#  4   10-03-22_Test_22_6-1v6-3.mp4                        394.01  29.835108
#  5   10-03-22_Test_22_6-1v6-3.mp4                        494.01  29.835108
#  6   10-03-22_Test_22_6-1v6-3.mp4                        589.01  29.835108
#  7   10-03-22_Test_22_6-1v6-3.mp4                        679.01  29.835108
#  8   10-03-22_Test_22_6-1v6-3.mp4                        759.01  29.835108
#  9   10-03-22_Test_22_6-1v6-3.mp4                        849.01  29.835108
#  10  10-03-22_Test_22_6-1v6-3.mp4                        949.01  29.835108
#  11  10-03-22_Test_22_6-1v6-3.mp4                       1039.01  29.835108
#  12  10-03-22_Test_22_6-1v6-3.mp4                       1159.01  29.835108
#  13  10-03-22_Test_22_6-1v6-3.mp4                       1249.01  29.835108
#  14  10-03-22_Test_22_6-1v6-3.mp4                       1334.01  29.835108
#  15  10-03-22_Test_22_6-1v6-3.mp4                       1424.01  29.835108
#  16  10-03-22_Test_22_6-1v6-3.mp4                       1519.01  29.835108
#  17  10-03-22_Test_22_6-1v6-3.mp4                       1639.01  29.835108
#  18  10-03-22_Test_22_6-1v6-3.mp4                       1719.01  29.835108
#
#      estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
#  0                   2058.920787                               2055
#  1                   4445.729407                               4442
#  2                   7130.889106                               7127
#  3                   9517.697727                               9514
#  4                  11755.330809                              11751
#  5                  14738.841585                              14735
#  6                  17573.176822                              17569
#  7                  20258.336520                              20254
#  8                  22645.145141                              22641
#  9                  25330.304840                              25326
#  10                 28313.815616                              28310
#  11                 30998.975314                              30995
#  12                 34579.188245                              34575
#  13                 37264.347944                              37260
#  14                 39800.332103                              39796
#  15                 42485.491802                              42482
#  16                 45319.827039                              45316
#  17                 48900.039970                              48896
#  18                 51286.848591                              51283
#
#      observed_cs_presentation_in_seconds  \
#  0                                 68.88
#  1                                148.88
#  2                                238.88
#  3                                318.89
#  4                                393.86
#  5                                493.88
#  6                                588.87
#  7                                678.86
#  8                                758.87
#  9                                848.87
#  10                               948.88
#  11                              1038.88
#  12                              1158.87
#  13                              1248.86
#  14                              1333.86
#  15                              1423.89
#  16                              1518.88
#  17                              1638.87
#  18                              1718.88
#
#      10_seconds_before_cs_presentation_in_frame  \
#  0                                         1757
#  1                                         4144
#  2                                         6829
#  3                                         9216
#  4                                        11453
#  5                                        14437
#  6                                        17271
#  7                                        19956
#  8                                        22343
#  9                                        25028
#  10                                       28012
#  11                                       30697
#  12                                       34277
#  13                                       36962
#  14                                       39498
#  15                                       42184
#  16                                       45018
#  17                                       48598
#  18                                       50985
#
#      10_seconds_after_cs_presentation_in_frame
#  0                                        2353
#  1                                        4740
#  2                                        7425
#  3                                        9812
#  4                                       12049
#  5                                       15033
#  6                                       17867
#  7                                       20552
#  8                                       22939
#  9                                       25624
#  10                                      28608
#  11                                      31293
#  12                                      34873
#  13                                      37558
#  14                                      40094
#  15                                      42780
#  16                                      45614
#  17                                      49194
#  18                                      51581  ,
#      (S)CSpresentation  cs_minute_only  cs_second_only  \
#  0               60.01             1.0            0.01
#  1              140.01             2.0           20.01
#  2              230.01             3.0           50.01
#  3              310.01             5.0           10.01
#  4              385.01             6.0           25.01
#  5              485.01             8.0            5.01
#  6              580.01             9.0           40.01
#  7              670.01            11.0           10.01
#  8              750.01            12.0           30.01
#  9              840.01            14.0            0.01
#  10             940.01            15.0           40.01
#  11            1030.01            17.0           10.01
#  12            1150.01            19.0           10.01
#  13            1240.01            20.0           40.01
#  14            1325.01            22.0            5.01
#  15            1415.01            23.0           35.01
#  16            1510.01            25.0           10.01
#  17            1630.01            27.0           10.01
#  18            1710.01            28.0           30.01
#
#                   video_file_name  estimated_cs_time_in_seconds        fps  \
#  0   10-03-22_Test_32_4-1v4-4.mp4                         67.01  24.855867
#  1   10-03-22_Test_32_4-1v4-4.mp4                        147.01  24.855867
#  2   10-03-22_Test_32_4-1v4-4.mp4                        237.01  24.855867
#  3   10-03-22_Test_32_4-1v4-4.mp4                        317.01  24.855867
#  4   10-03-22_Test_32_4-1v4-4.mp4                        392.01  24.855867
#  5   10-03-22_Test_32_4-1v4-4.mp4                        492.01  24.855867
#  6   10-03-22_Test_32_4-1v4-4.mp4                        587.01  24.855867
#  7   10-03-22_Test_32_4-1v4-4.mp4                        677.01  24.855867
#  8   10-03-22_Test_32_4-1v4-4.mp4                        757.01  24.855867
#  9   10-03-22_Test_32_4-1v4-4.mp4                        847.01  24.855867
#  10  10-03-22_Test_32_4-1v4-4.mp4                        947.01  24.855867
#  11  10-03-22_Test_32_4-1v4-4.mp4                       1037.01  24.855867
#  12  10-03-22_Test_32_4-1v4-4.mp4                       1157.01  24.855867
#  13  10-03-22_Test_32_4-1v4-4.mp4                       1247.01  24.855867
#  14  10-03-22_Test_32_4-1v4-4.mp4                       1332.01  24.855867
#  15  10-03-22_Test_32_4-1v4-4.mp4                       1422.01  24.855867
#  16  10-03-22_Test_32_4-1v4-4.mp4                       1517.01  24.855867
#  17  10-03-22_Test_32_4-1v4-4.mp4                       1637.01  24.855867
#  18  10-03-22_Test_32_4-1v4-4.mp4                       1717.01  24.855867
#
#      estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
#  0                   1665.591644                               1669
#  1                   3654.061000                               3657
#  2                   5891.089025                               5894
#  3                   7879.558380                               7883
#  4                   9743.748401                               9747
#  5                  12229.335096                              12233
#  6                  14590.642456                              14594
#  7                  16827.670481                              16831
#  8                  18816.139837                              18820
#  9                  21053.167862                              21057
#  10                 23538.754556                              23542
#  11                 25775.782581                              25779
#  12                 28758.486615                              28762
#  13                 30995.514640                              30999
#  14                 33108.263330                              33112
#  15                 35345.291356                              35349
#  16                 37706.598715                              37710
#  17                 40689.302749                              40693
#  18                 42677.772104                              42681
#
#      observed_cs_presentation_in_seconds  \
#  0                                 67.15
#  1                                147.13
#  2                                237.13
#  3                                317.15
#  4                                392.14
#  5                                492.16
#  6                                587.15
#  7                                677.14
#  8                                757.17
#  9                                847.16
#  10                               947.14
#  11                              1037.14
#  12                              1157.15
#  13                              1247.15
#  14                              1332.16
#  15                              1422.16
#  16                              1517.15
#  17                              1637.16
#  18                              1717.14
#
#      10_seconds_before_cs_presentation_in_frame  \
#  0                                         1420
#  1                                         3408
#  2                                         5645
#  3                                         7634
#  4                                         9498
#  5                                        11984
#  6                                        14345
#  7                                        16582
#  8                                        18571
#  9                                        20808
#  10                                       23293
#  11                                       25530
#  12                                       28513
#  13                                       30750
#  14                                       32863
#  15                                       35100
#  16                                       37461
#  17                                       40444
#  18                                       42432
#
#      10_seconds_after_cs_presentation_in_frame
#  0                                        1918
#  1                                        3906
#  2                                        6143
#  3                                        8132
#  4                                        9996
#  5                                       12482
#  6                                       14843
#  7                                       17080
#  8                                       19069
#  9                                       21306
#  10                                      23791
#  11                                      26028
#  12                                      29011
#  13                                      31248
#  14                                      33361
#  15                                      35598
#  16                                      37959
#  17                                      40942
#  18                                      42930  ,
#      (S)CSpresentation  cs_minute_only  cs_second_only  \
#  0               60.01             1.0            0.01
#  1              140.01             2.0           20.01
#  2              230.01             3.0           50.01
#  3              310.01             5.0           10.01
#  4              385.01             6.0           25.01
#  5              485.01             8.0            5.01
#  6              580.01             9.0           40.01
#  7              670.01            11.0           10.01
#  8              750.01            12.0           30.01
#  9              840.01            14.0            0.01
#  10             940.01            15.0           40.01
#  11            1030.01            17.0           10.01
#  12            1150.01            19.0           10.01
#  13            1240.01            20.0           40.01
#  14            1325.01            22.0            5.01
#  15            1415.01            23.0           35.01
#  16            1510.01            25.0           10.01
#  17            1630.01            27.0           10.01
#  18            1710.01            28.0           30.01
#
#                   video_file_name  estimated_cs_time_in_seconds        fps  \
#  0   10-03-22_Test_34_5-1v5-4.mp4                         67.01  29.837709
#  1   10-03-22_Test_34_5-1v5-4.mp4                        147.01  29.837709
#  2   10-03-22_Test_34_5-1v5-4.mp4                        237.01  29.837709
#  3   10-03-22_Test_34_5-1v5-4.mp4                        317.01  29.837709
#  4   10-03-22_Test_34_5-1v5-4.mp4                        392.01  29.837709
#  5   10-03-22_Test_34_5-1v5-4.mp4                        492.01  29.837709
#  6   10-03-22_Test_34_5-1v5-4.mp4                        587.01  29.837709
#  7   10-03-22_Test_34_5-1v5-4.mp4                        677.01  29.837709
#  8   10-03-22_Test_34_5-1v5-4.mp4                        757.01  29.837709
#  9   10-03-22_Test_34_5-1v5-4.mp4                        847.01  29.837709
#  10  10-03-22_Test_34_5-1v5-4.mp4                        947.01  29.837709
#  11  10-03-22_Test_34_5-1v5-4.mp4                       1037.01  29.837709
#  12  10-03-22_Test_34_5-1v5-4.mp4                       1157.01  29.837709
#  13  10-03-22_Test_34_5-1v5-4.mp4                       1247.01  29.837709
#  14  10-03-22_Test_34_5-1v5-4.mp4                       1332.01  29.837709
#  15  10-03-22_Test_34_5-1v5-4.mp4                       1422.01  29.837709
#  16  10-03-22_Test_34_5-1v5-4.mp4                       1517.01  29.837709
#  17  10-03-22_Test_34_5-1v5-4.mp4                       1637.01  29.837709
#  18  10-03-22_Test_34_5-1v5-4.mp4                       1717.01  29.837709
#
#      estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
#  0                   1999.424854                               2008
#  1                   4386.441543                               4395
#  2                   7071.835318                               7080
#  3                   9458.852007                               9467
#  4                  11696.680152                              11705
#  5                  14680.451013                              14689
#  6                  17515.033331                              17524
#  7                  20200.427106                              20209
#  8                  22587.443795                              22596
#  9                  25272.837570                              25281
#  10                 28256.608431                              28265
#  11                 30942.002206                              30951
#  12                 34522.527239                              34531
#  13                 37207.921014                              37216
#  14                 39744.126246                              39753
#  15                 42429.520021                              42438
#  16                 45264.102339                              45273
#  17                 48844.627372                              48853
#  18                 51231.644061                              51240
#
#      observed_cs_presentation_in_seconds  \
#  0                                 67.30
#  1                                147.30
#  2                                237.28
#  3                                317.28
#  4                                392.29
#  5                                492.30
#  6                                587.31
#  7                                677.30
#  8                                757.30
#  9                                847.28
#  10                               947.29
#  11                              1037.31
#  12                              1157.29
#  13                              1247.28
#  14                              1332.31
#  15                              1422.29
#  16                              1517.31
#  17                              1637.29
#  18                              1717.29
#
#      10_seconds_before_cs_presentation_in_frame  \
#  0                                         1710
#  1                                         4097
#  2                                         6782
#  3                                         9169
#  4                                        11407
#  5                                        14391
#  6                                        17226
#  7                                        19911
#  8                                        22298
#  9                                        24983
#  10                                       27967
#  11                                       30653
#  12                                       34233
#  13                                       36918
#  14                                       39455
#  15                                       42140
#  16                                       44975
#  17                                       48555
#  18                                       50942
#
#      10_seconds_after_cs_presentation_in_frame
#  0                                        2306
#  1                                        4693
#  2                                        7378
#  3                                        9765
#  4                                       12003
#  5                                       14987
#  6                                       17822
#  7                                       20507
#  8                                       22894
#  9                                       25579
#  10                                      28563
#  11                                      31249
#  12                                      34829
#  13                                      37514
#  14                                      40051
#  15                                      42736
#  16                                      45571
#  17                                      49151
#  18                                      51538  ]

# %%
all_cs_presentation_dataframe = pd.concat(all_cs_presentation_df_list)

# %%
all_cs_presentation_dataframe
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  \
# 0               60.01             1.0            0.01
# 1              140.01             2.0           20.01
# 2              230.01             3.0           50.01
# 3              310.01             5.0           10.01
# 4              385.01             6.0           25.01
# ..                ...             ...             ...
# 14            1325.01            22.0            5.01
# 15            1415.01            23.0           35.01
# 16            1510.01            25.0           10.01
# 17            1630.01            27.0           10.01
# 18            1710.01            28.0           30.01
#
#                  video_file_name  estimated_cs_time_in_seconds        fps  \
# 0   10-03-22_Test_13_2-2v2-4.mp4                         71.01  24.867696
# 1   10-03-22_Test_13_2-2v2-4.mp4                        151.01  24.867696
# 2   10-03-22_Test_13_2-2v2-4.mp4                        241.01  24.867696
# 3   10-03-22_Test_13_2-2v2-4.mp4                        321.01  24.867696
# 4   10-03-22_Test_13_2-2v2-4.mp4                        396.01  24.867696
# ..                           ...                           ...        ...
# 14  10-03-22_Test_34_5-1v5-4.mp4                       1332.01  29.837709
# 15  10-03-22_Test_34_5-1v5-4.mp4                       1422.01  29.837709
# 16  10-03-22_Test_34_5-1v5-4.mp4                       1517.01  29.837709
# 17  10-03-22_Test_34_5-1v5-4.mp4                       1637.01  29.837709
# 18  10-03-22_Test_34_5-1v5-4.mp4                       1717.01  29.837709
#
#     estimated_cs_time_in_frames  observed_cs_presentation_in_frame  \
# 0                   1765.855097                               1771
# 1                   3755.270781                               3760
# 2                   5993.363426                               5999
# 3                   7982.779111                               7988
# 4                   9847.856315                               9853
# ..                          ...                                ...
# 14                 39744.126246                              39753
# 15                 42429.520021                              42438
# 16                 45264.102339                              45273
# 17                 48844.627372                              48853
# 18                 51231.644061                              51240
#
#     observed_cs_presentation_in_seconds  \
# 0                                 71.22
# 1                                151.20
# 2                                241.24
# 3                                321.22
# 4                                396.22
# ..                                  ...
# 14                              1332.31
# 15                              1422.29
# 16                              1517.31
# 17                              1637.29
# 18                              1717.29
#
#     10_seconds_before_cs_presentation_in_frame  \
# 0                                         1522
# 1                                         3511
# 2                                         5750
# 3                                         7739
# 4                                         9604
# ..                                         ...
# 14                                       39455
# 15                                       42140
# 16                                       44975
# 17                                       48555
# 18                                       50942
#
#     10_seconds_after_cs_presentation_in_frame
# 0                                        2020
# 1                                        4009
# 2                                        6248
# 3                                        8237
# 4                                       10102
# ..                                        ...
# 14                                      40051
# 15                                      42736
# 16                                      45571
# 17                                      49151
# 18                                      51538
#
# [114 rows x 11 columns]

# %%
all_cs_presentation_dataframe["video_file_name"].unique()
# Out:
# array(['10-03-22_Test_13_2-2v2-4.mp4', '10-03-22_Test_25_1-2v1-3.mp4',
#        '10-03-22_Test_29_3-2v3-3.mp4', '10-03-22_Test_22_6-1v6-3.mp4',
#        '10-03-22_Test_32_4-1v4-4.mp4', '10-03-22_Test_34_5-1v5-4.mp4'],
#       dtype=object)

# %%
all_cs_presentation_dataframe.to_csv("./proc/cs_presentation_frame_numbers.csv")

# %% [markdown]
# # Trimming the video

# %%
raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 raise ValueError()
#
# ValueError:

# %%
video_object = VideoFileClip(video_path)

# %%
video_object.duration

# %% [markdown]
# fixed func issue with: https://github.com/Zulko/moviepy/issues/1765

# %%
video_object.

# %%
video_path

# %%
file_name = os.path.basename(video_path)
file_name_without_extention = os.path.splitext(file_name)[0]
file_name_without_extention = "_".join(file_name_without_extention.split())

# %%
file_name_without_extention

# %%
clip_output_dir = "./data/videos/tone_clips/"

# %%
current_clip_output_dir = os.path.join(clip_output_dir, file_name_without_extention)
os.makedirs(current_clip_output_dir, exist_ok=True)

# %%
for index, row in cs_presentation_time.iterrows():
    cs_trimmed_video = video_object.subclip(row["video_cs_time"] - 5, row["video_cs_time"] + 15)
    cs_trimmed_file_name = "cs_number_{:02d}_date_{}.mp4".format(index + 1, file_name_without_extention)
    print(cs_trimmed_file_name)
    cs_trimmed_video.to_videofile(os.path.join(current_clip_output_dir, cs_trimmed_file_name))

# %%
cs_trimmed_times_name = "cs_times_{}_.csv".format(file_name_without_extention)

# %%
cs_presentation_time.to_csv(os.path.join(current_clip_output_dir, cs_trimmed_times_name))
