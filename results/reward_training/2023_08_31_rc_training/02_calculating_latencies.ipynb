# %% [markdown]
# # Notebook 2: MED-PC Calculating Latencies

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from medpc2excel.medpc_read import medpc_read

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %%
# Increase size of plot in jupyter

plt.rcParams["figure.figsize"] = (13.5,7.5)

# %% [markdown]
# # Loading in Recording and Metadata from Previous Notebook

# %% [markdown]
# # NOTE: If you changed the directory of where the MED-PC recording dataframes, then you must change the directories in the following paths

# %% [markdown]
# - This will get all the files in each specified path. The `*` is called a wildcard, and it can be replaced with any number of characters.
#     - For more information: https://www.malikbrowne.com/blog/a-beginners-guide-glob-patterns

# %%
cohort = "pilot_1"

# %%
concatted_medpc_files = glob.glob("./proc/extracted_recording_data_and_metadata/domcomp_pilot_reward_training_metadata.csv")
metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/domcomp_pilot_reward_training_medpc.csv")
recording_and_metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/domcomp_pilot_reward_training_medpc_metadata.csv")

# %% [markdown]
# # NOTE: If there is more than one MED-PC recording dataframes, then you must manually change the path in the `pd.read_csv()` for the corresponding variables. Verify if this is the correct file that you want to use

# %%
metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/domcomp_pilot_reward_training_medpc.csv'

# %%
concatted_medpc_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/domcomp_pilot_reward_training_metadata.csv'

# %%
recording_and_metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/domcomp_pilot_reward_training_medpc_metadata.csv'

# %%
metadata_df = pd.read_csv(metadata_files[0], index_col=0)
concatted_medpc_df = pd.read_csv(concatted_medpc_files[0], index_col=0)
recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)
# Out:
# /tmp/ipykernel_150184/169435060.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata_df = pd.read_csv(metadata_files[0], index_col=0)
# /tmp/ipykernel_150184/169435060.py:3: DtypeWarning: Columns (9,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)

# %% [markdown]
# - The Dataframe the contains the metadata(columns) of each recording file(rows)
#     - We will mostly use this to get the cage number for each subject

# %%
metadata_df.head()
# Out:
#                                           index  \
# 0      ./data/2022-05-16_11h28m_Subject 2.1.txt
# 1      ./data/2022-05-04_10h11m_Subject 2.1.txt
# 2  ./data/2022-05-06_12h59m_Subject 3.1 (1).txt
# 3      ./data/2022-05-07_08h53m_Subject 1.4.txt
# 4  ./data/2022-05-03_16h09m_Subject 3.4 (2).txt
#
#                                                 File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-05-16_11h28m_Subject 2.1.txt   05/16/22  05/16/22
# 1   C:\MED-PC\Data\2022-05-04_10h11m_Subject 2.1.txt   05/04/22  05/04/22
# 2  C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.1 (...   05/06/22  05/06/22
# 3   C:\MED-PC\Data\2022-05-07_08h53m_Subject 1.4.txt   05/07/22  05/07/22
# 4  C:\MED-PC\Data\2022-05-03_16h09m_Subject 3.4 (...   05/03/22  05/03/22
#
#    Subject      Experiment   Group  Box Start Time  End Time  \
# 0      2.1  Pilot of Pilot  Cage 2    3   11:28:27  12:35:20
# 1      2.1  Pilot of Pilot  Cage 2    2   10:11:55  11:18:44
# 2  3.1 (1)  Pilot of Pilot  Cage 4    4   12:59:58  14:02:38
# 3      1.4  Pilot of Pilot  Cage 1    3   08:53:46  10:21:47
# 4  3.4 (2)  Pilot of Pilot  Cage 4    2   16:09:34  17:19:39
#
#                                          MSN  cage   cohort
# 0  levelNP_CS_reward_laserepochON1st_noshock     2  pilot_1
# 1  levelNP_CS_reward_laserepochON1st_noshock     2  pilot_1
# 2  levelNP_CS_reward_laserepochON1st_noshock     4  pilot_1
# 3  levelNP_CS_reward_laserepochON1st_noshock     1  pilot_1
# 4  levelNP_CS_reward_laserepochON1st_noshock     4  pilot_1

# %% [markdown]
# - The Dataframe the contains the recording data for all the files.
#     - The 1st row is the first data entries for each type of data(with the type being specified by the column label). This does not mean that all these are related or occured for the same trial. i.e. There can be many port entries and exits for a subject before and after a tone is played.
#     - Each recording session will usually have a few thousand rows(although, most of of the columns will probably be blank by the end). And then after the last row of one session, the next row will be the next session with a different `file_path`

# %%
concatted_medpc_df.head()
# Out:
#                                       index  \
# 0  ./data/2022-05-03_10h38m_Subject 1.1.txt
# 1  ./data/2022-05-03_10h38m_Subject 2.2.txt
# 2  ./data/2022-05-03_10h38m_Subject 2.3.txt
# 3  ./data/2022-05-03_10h38m_Subject 1.4.txt
# 4  ./data/2022-05-03_11h42m_Subject 1.1.txt
#
#                                                File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-05-03_10h38m_Subject 1.1.txt   05/03/22  05/03/22
# 1  C:\MED-PC\Data\2022-05-03_10h38m_Subject 2.2.txt   05/03/22  05/03/22
# 2  C:\MED-PC\Data\2022-05-03_10h38m_Subject 2.3.txt   05/03/22  05/03/22
# 3  C:\MED-PC\Data\2022-05-03_10h38m_Subject 1.4.txt   05/03/22  05/03/22
# 4  C:\MED-PC\Data\2022-05-03_11h42m_Subject 1.1.txt   05/03/22  05/03/22
#
#   Subject      Experiment   Group  Box Start Time  End Time  \
# 0     1.1  Pilot of Pilot   Cage1    1   10:38:08  11:17:00
# 1     2.2  Pilot of Pilot   Cage1    2   10:38:27  11:17:00
# 2     2.3  Pilot of Pilot   Cage1    3   10:38:37  11:17:00
# 3     1.4  Pilot of Pilot   Cage1    4   10:38:47  11:17:00
# 4     1.1  Pilot of Pilot  Cage 1    1   11:42:09  11:47:02
#
#                                          MSN  cage        date  cohort
# 0  levelNP_CS_reward_laserepochON1st_noshock     1  2022-05-03       1
# 1  levelNP_CS_reward_laserepochON1st_noshock     1  2022-05-03       1
# 2  levelNP_CS_reward_laserepochON1st_noshock     1  2022-05-03       1
# 3  levelNP_CS_reward_laserepochON1st_noshock     1  2022-05-03       1
# 4  levelNP_CS_reward_laserepochON1st_noshock     1  2022-05-03       1

# %%
concatted_medpc_df["c"].unique()
# Out:
# array(['1.1', '2.2', '2.3', '1.4', '2.1', '1.2', '1.3', '2.4', '4.1 (1)',
#        '3.2 (2)', '4.2 (3)', '3.3 (4)', '3.1 (1)', '3.4 (2)', '4.3 (3)',
#        '4.4 (4)', '1', '2', '3', '4', '4.1', '4.2', '4.3', '4.4', '5.1',
#        '5.2', '5.3', '5.4', '6.1', '6.2', '6.3', '6.4', '3.1', '3.2',
#        '3.3', '3.4'], dtype=object)

# %% [markdown]
# - This dataframe combines the recording data and metadata dataframes. This is done by using the subject ID as a common column to merge together off of.

# %%
recording_and_metadata_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          3.95           64.0      399.0           0.0              60.01
# 1         16.56          144.0      399.0           0.0             140.01
# 2         16.85          234.0      399.0           0.0             230.01
# 3         16.97          314.0      399.0           0.0             310.01
# 4         24.95          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date subject  ...  \
# 0         5.03        1.0                0.0  20220516     2.1  ...
# 1        16.70        1.0                0.0  20220516     2.1  ...
# 2        16.88        1.0                0.0  20220516     2.1  ...
# 3        17.93        1.0                0.0  20220516     2.1  ...
# 4        25.28        1.0                0.0  20220516     2.1  ...
#
#        Experiment   Group Box Start Time  End Time  \
# 0  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 1  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 2  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 3  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 4  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
#
#                                          MSN cage session  strain   cohort
# 0  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 1  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 2  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 3  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 4  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
#
# [5 rows x 26 columns]

# %%
recording_and_metadata_df["subject"] = recording_and_metadata_df["subject"].astype(str)

# %% [markdown]
# # Getting the Cage Numbers and the Dates for the file names

# %% [markdown]
# - Seeing if any rows have NaN values for the cages

# %%
recording_and_metadata_df[pd.isna(recording_and_metadata_df["cage"])]
# Out:
# Empty DataFrame
# Columns: [(P)Portentry, (Q)USdelivery, (R)UStime, (W)ITIvalues, (S)CSpresentation, (N)Portexit, (K)CStype, (B)shockintensity, date, subject, file_path, index, File, Start Date, End Date, Subject, Experiment, Group, Box, Start Time, End Time, MSN, cage, session, strain, cohort]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# - Dropping the NaN values so we can get the cage numbers

# %%
recording_and_metadata_df = recording_and_metadata_df.dropna(subset=["cage"])

# %% [markdown]
# # Adjusting the days and cages that are being looked at

# %% [markdown]
# - List of all the subject names

# %%
all_subjects = sorted([str(subject_id) for subject_id in recording_and_metadata_df["subject"].unique()])

# %%
all_subjects
# Out:
# ['1.1',
#  '1.2',
#  '1.3',
#  '1.4',
#  '2.1',
#  '2.2',
#  '2.3',
#  '2.4',
#  '3.1 (1)',
#  '3.2 (2)',
#  '3.3 (4)',
#  '3.4 (2)',
#  '4.1 (1)',
#  '4.2 (3)',
#  '4.3 (3)',
#  '4.4 (4)']

# %% [markdown]
# - List of all the cage numbers

# %%
all_cages = sorted(recording_and_metadata_df["cage"].unique())

# %%
all_cages
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# - List of all the dates

# %%
all_dates = sorted(recording_and_metadata_df["date"].unique())

# %%
all_dates
# Out:
# [20220503,
#  20220504,
#  20220505,
#  20220506,
#  20220507,
#  20220508,
#  20220509,
#  20220510,
#  20220511,
#  20220512,
#  20220516,
#  20220517]

# %% [markdown]
# # NOTE: Follow directions below if you want to change which cages or dates to plot

# %% [markdown]
# - You must change the cell below by clicking on the cell and then pressing the `esc` key. Then press the `Y` button on your keyboard. If you want to switch it back do the same but press the `R` button instead. This switches it from a cell that is run as if it's code, or back to a cell where it's just treated as text
# - Then from above, copy the numbers that you want to use for the cage numbers and the dates

# %% [raw]
# all_cages = [1]
# all_dates = [20220508, 20220509, 20220510, 20220511, 20220512]

# %%
recording_and_metadata_df = recording_and_metadata_df[recording_and_metadata_df["cage"].isin(all_cages) & recording_and_metadata_df["date"].isin(all_dates)]

# %%
all_cages
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Getting the Cage Numbers and the Dates to name the files

# %%
# removing blank spaces
cage_numbers = [str(int(number)) for number in all_cages if number is not np.nan]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4'

# %%
# Getting the first and last recording date to get a range
earliest_date = min(all_dates)
latest_date = max(all_dates)

# %%
earliest_date
# Out:
# 20220503

# %%
latest_date
# Out:
# 20220517

# %% [markdown]
# # Getting the times that the tones are being played

# %% [markdown]
# - Getting all the rows that correspond to one of the files paths. This will be the equivalent of getting all the rows for one session

# %%
example_file = recording_and_metadata_df["file_path"].unique()[0]

# %%
example_file
# Out:
# './data/2022-05-16_11h28m_Subject 2.1.txt'

# %%
example_one_session_recording_df = recording_and_metadata_df[recording_and_metadata_df["file_path"] == example_file]

# %% [markdown]
# - Everything looks normal enough

# %%
example_one_session_recording_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          3.95           64.0      399.0           0.0              60.01
# 1         16.56          144.0      399.0           0.0             140.01
# 2         16.85          234.0      399.0           0.0             230.01
# 3         16.97          314.0      399.0           0.0             310.01
# 4         24.95          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date subject  ...  \
# 0         5.03        1.0                0.0  20220516     2.1  ...
# 1        16.70        1.0                0.0  20220516     2.1  ...
# 2        16.88        1.0                0.0  20220516     2.1  ...
# 3        17.93        1.0                0.0  20220516     2.1  ...
# 4        25.28        1.0                0.0  20220516     2.1  ...
#
#        Experiment   Group Box Start Time  End Time  \
# 0  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 1  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 2  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 3  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 4  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
#
#                                          MSN cage session  strain   cohort
# 0  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 1  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 2  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 3  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 4  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
#
# [5 rows x 26 columns]

# %% [markdown]
# - `(S)CSpresentation` is the time that the tone starts playing. MED-PC starts inputting in random numbers that are in the 1000's. So we will remove these

# %%
example_one_session_recording_df[50:60]
# Out:
#     (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 50        296.08            NaN        NaN           0.0             9000.0
# 51        299.40            NaN        NaN           0.0            12000.0
# 52        302.96            NaN        NaN           0.0             9000.0
# 53        308.01            NaN        NaN           0.0             8500.0
# 54        335.43            NaN        NaN           0.0             9000.0
# 55        347.56            NaN        NaN           0.0             9500.0
# 56        354.38            NaN        NaN           0.0            12000.0
# 57        366.31            NaN        NaN           0.0             8000.0
# 58        372.12            NaN        NaN           0.0             9500.0
# 59        378.69            NaN        NaN           0.0             8000.0
#
#     (N)Portexit  (K)CStype  (B)shockintensity      date subject  ...  \
# 50       298.89        0.0                0.0  20220516     2.1  ...
# 51       299.71        0.0                0.0  20220516     2.1  ...
# 52       304.22        0.0                0.0  20220516     2.1  ...
# 53       333.39        0.0                0.0  20220516     2.1  ...
# 54       338.66        0.0                0.0  20220516     2.1  ...
# 55       352.56        0.0                0.0  20220516     2.1  ...
# 56       355.87        0.0                0.0  20220516     2.1  ...
# 57       370.63        0.0                0.0  20220516     2.1  ...
# 58       374.18        0.0                0.0  20220516     2.1  ...
# 59       379.97        0.0                0.0  20220516     2.1  ...
#
#         Experiment   Group Box Start Time  End Time  \
# 50  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 51  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 52  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 53  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 54  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 55  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 56  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 57  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 58  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 59  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
#
#                                           MSN cage session  strain   cohort
# 50  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 51  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 52  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 53  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 54  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 55  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 56  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 57  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 58  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 59  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
#
# [10 rows x 26 columns]

# %% [markdown]
# - `(S)CSpresentation` then starts adding blanks(NaN) so we will remove these too

# %%
example_one_session_recording_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 2536           NaN            NaN        NaN           NaN                NaN
# 2537           NaN            NaN        NaN           NaN                NaN
# 2538           NaN            NaN        NaN           NaN                NaN
# 2539           NaN            NaN        NaN           NaN                NaN
# 2540           NaN            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (B)shockintensity      date subject  ...  \
# 2536          NaN        1.0                NaN  20220516     2.1  ...
# 2537          NaN        1.0                NaN  20220516     2.1  ...
# 2538          NaN        1.0                NaN  20220516     2.1  ...
# 2539          NaN        1.0                NaN  20220516     2.1  ...
# 2540          NaN        1.0                NaN  20220516     2.1  ...
#
#           Experiment   Group Box Start Time  End Time  \
# 2536  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 2537  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 2538  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 2539  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
# 2540  Pilot of Pilot  Cage 2   3   11:28:27  12:35:20
#
#                                             MSN cage session  strain   cohort
# 2536  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 2537  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 2538  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 2539  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
# 2540  levelNP_CS_reward_laserepochON1st_noshock    2      11     C57  pilot_1
#
# [5 rows x 26 columns]

# %% [markdown]
# - We will use a function that removes the `NaN` and the tone times that are divisible by 1000. This will get the tones time that were actually used for the recordings

# %%
example_one_session_valid_tones = processing.tone.get_valid_tones(example_one_session_recording_df["(S)CSpresentation"])

# %%
example_one_session_valid_tones
# Out:
# 0       60.01
# 1      140.01
# 2      230.01
# 3      310.01
# 4      385.01
# 5      485.01
# 6      580.01
# 7      670.01
# 8      750.01
# 9      840.01
# 10     940.01
# 11    1030.01
# 12    1150.01
# 13    1240.01
# 14    1325.01
# 15    1415.01
# 16    1510.01
# 17    1630.01
# 18    1710.01
# 19    1805.01
# 20    1885.01
# 21    1975.01
# 22    2055.01
# 23    2130.01
# 24    2230.01
# 25    2325.01
# 26    2415.01
# 27    2495.01
# 28    2585.01
# 29    2685.01
# 30    2775.01
# 31    2895.01
# 32    2985.01
# 33    3070.01
# 34    3160.01
# 35    3255.01
# 36    3345.01
# 37    3425.01
# 38    3515.01
# 39    3615.01
# Name: (S)CSpresentation, dtype: float64

# %% [markdown]
# # Getting the First Port Entry After Each Tone

# %% [markdown]
# - With these tone playing times, we will get the first port entry that comes after the tone playing time
#     - This was done by getting all the port entries that came after the tone. And then getting the port entry time that was earliest in time(aka smallest number)

# %%
processing.tone.get_first_port_entries_after_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=example_one_session_recording_df["(P)Portentry"], port_exits_pd_series=example_one_session_recording_df["(N)Portexit"])
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 0               60.01                        62.44
# 1              140.01                       144.48
# 2              230.01                       243.34
# 3              310.01                       335.43
# 4              385.01                       405.95
# 5              485.01                       503.92
# 6              580.01                       581.37
# 7              670.01                       670.43
# 8              750.01                       778.23
# 9              840.01                       842.10
# 10             940.01                       958.95
# 11            1030.01                      1035.87
# 12            1150.01                      1150.11
# 13            1240.01                      1241.67
# 14            1325.01                      1327.77
# 15            1415.01                      1415.84
# 16            1510.01                      1511.82
# 17            1630.01                      1647.29
# 18            1710.01                      1733.95
# 19            1805.01                      1805.81
# 20            1885.01                      1901.42
# 21            1975.01                      1976.62
# 22            2055.01                      2068.83
# 23            2130.01                      2151.83
# 24            2230.01                      2246.64
# 25            2325.01                      2327.22
# 26            2415.01                      2415.03
# 27            2495.01                      2507.16
# 28            2585.01                      2585.37
# 29            2685.01                      2685.20
# 30            2775.01                      2775.25
# 31            2895.01                      2912.75
# 32            2985.01                      2986.76
# 33            3070.01                      3092.94
# 34            3160.01                      3163.36
# 35            3255.01                      3255.89
# 36            3345.01                      3347.20
# 37            3425.01                      3445.86
# 38            3515.01                      3533.15
# 39            3615.01                      3645.69
#
#     port_exit_after_first_port_entry_after_tone
# 0                                         62.49
# 1                                        160.30
# 2                                        246.01
# 3                                        338.66
# 4                                        408.49
# 5                                        508.02
# 6                                        592.80
# 7                                        685.90
# 8                                        780.07
# 9                                        859.78
# 10                                       959.99
# 11                                      1046.70
# 12                                      1170.87
# 13                                      1258.50
# 14                                      1349.99
# 15                                      1431.24
# 16                                      1526.38
# 17                                      1652.41
# 18                                      1735.94
# 19                                      1825.47
# 20                                      1902.31
# 21                                      1987.51
# 22                                      2072.33
# 23                                      2154.35
# 24                                      2251.82
# 25                                      2345.50
# 26                                      2427.20
# 27                                      2511.72
# 28                                      2603.76
# 29                                      2703.09
# 30                                      2798.23
# 31                                      2915.39
# 32                                      2997.19
# 33                                      3096.56
# 34                                      3182.92
# 35                                      3275.76
# 36                                      3366.84
# 37                                      3453.97
# 38                                      3533.61
# 39                                      3649.23

# %% [markdown]
# - Getting the first port entry times for all the sessions

# %%
recording_and_metadata_df
# Out:
#         (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  \
# 0               3.95           64.0      399.0           0.0
# 1              16.56          144.0      399.0           0.0
# 2              16.85          234.0      399.0           0.0
# 3              16.97          314.0      399.0           0.0
# 4              24.95          389.0      399.0           0.0
# ...              ...            ...        ...           ...
# 467539           NaN            NaN        NaN           NaN
# 467540           NaN            NaN        NaN           NaN
# 467541           NaN            NaN        NaN           NaN
# 467542           NaN            NaN        NaN           NaN
# 467543           NaN            NaN        NaN           NaN
#
#         (S)CSpresentation  (N)Portexit  (K)CStype  (B)shockintensity  \
# 0                   60.01         5.03        1.0                0.0
# 1                  140.01        16.70        1.0                0.0
# 2                  230.01        16.88        1.0                0.0
# 3                  310.01        17.93        1.0                0.0
# 4                  385.01        25.28        1.0                0.0
# ...                   ...          ...        ...                ...
# 467539                NaN          NaN        1.0                NaN
# 467540                NaN          NaN        1.0                NaN
# 467541                NaN          NaN        1.0                NaN
# 467542                NaN          NaN        1.0                NaN
# 467543                NaN          NaN        1.0                NaN
#
#             date  subject  ...      Experiment   Group Box Start Time  \
# 0       20220516      2.1  ...  Pilot of Pilot  Cage 2   3   11:28:27
# 1       20220516      2.1  ...  Pilot of Pilot  Cage 2   3   11:28:27
# 2       20220516      2.1  ...  Pilot of Pilot  Cage 2   3   11:28:27
# 3       20220516      2.1  ...  Pilot of Pilot  Cage 2   3   11:28:27
# 4       20220516      2.1  ...  Pilot of Pilot  Cage 2   3   11:28:27
# ...          ...      ...  ...             ...     ...  ..        ...
# 467539  20220509  4.2 (3)  ...  Pilot of Pilot  Cage 3   1   12:43:20
# 467540  20220509  4.2 (3)  ...  Pilot of Pilot  Cage 3   1   12:43:20
# 467541  20220509  4.2 (3)  ...  Pilot of Pilot  Cage 3   1   12:43:20
# 467542  20220509  4.2 (3)  ...  Pilot of Pilot  Cage 3   1   12:43:20
# 467543  20220509  4.2 (3)  ...  Pilot of Pilot  Cage 3   1   12:43:20
#
#         End Time                                        MSN cage session  \
# 0       12:35:20  levelNP_CS_reward_laserepochON1st_noshock    2      11
# 1       12:35:20  levelNP_CS_reward_laserepochON1st_noshock    2      11
# 2       12:35:20  levelNP_CS_reward_laserepochON1st_noshock    2      11
# 3       12:35:20  levelNP_CS_reward_laserepochON1st_noshock    2      11
# 4       12:35:20  levelNP_CS_reward_laserepochON1st_noshock    2      11
# ...          ...                                        ...  ...     ...
# 467539  13:48:27  levelNP_CS_reward_laserepochON1st_noshock    3       7
# 467540  13:48:27  levelNP_CS_reward_laserepochON1st_noshock    3       7
# 467541  13:48:27  levelNP_CS_reward_laserepochON1st_noshock    3       7
# 467542  13:48:27  levelNP_CS_reward_laserepochON1st_noshock    3       7
# 467543  13:48:27  levelNP_CS_reward_laserepochON1st_noshock    3       7
#
#         strain   cohort
# 0          C57  pilot_1
# 1          C57  pilot_1
# 2          C57  pilot_1
# 3          C57  pilot_1
# 4          C57  pilot_1
# ...        ...      ...
# 467539     CD1  pilot_1
# 467540     CD1  pilot_1
# 467541     CD1  pilot_1
# 467542     CD1  pilot_1
# 467543     CD1  pilot_1
#
# [467544 rows x 26 columns]

# %%
concatted_first_porty_entry_dataframe = processing.tone.get_concatted_first_porty_entry_after_tone_dataframe(concatted_medpc_df=recording_and_metadata_df, date_column="session")

# %%
concatted_first_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        62.44
# 1             140.01                       144.48
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        62.49
# 1                                       160.30
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
#
#                                   file_path  session subject
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1

# %%
concatted_first_porty_entry_dataframe.tail()
# Out:
#       current_tone_time  first_port_entry_after_tone  \
# 7187            3255.01                      3258.91
# 7188            3345.01                      3347.56
# 7189            3425.01                      3432.09
# 7190            3515.01                      3519.75
# 7191            3615.01                      3618.00
#
#       port_exit_after_first_port_entry_after_tone  \
# 7187                                      3259.52
# 7188                                      3348.56
# 7189                                      3437.32
# 7190                                      3524.23
# 7191                                      3618.57
#
#                                          file_path  session  subject
# 7187  ./data/2022-05-09_12h43m_Subject 4.2 (3).txt        7  4.2 (3)
# 7188  ./data/2022-05-09_12h43m_Subject 4.2 (3).txt        7  4.2 (3)
# 7189  ./data/2022-05-09_12h43m_Subject 4.2 (3).txt        7  4.2 (3)
# 7190  ./data/2022-05-09_12h43m_Subject 4.2 (3).txt        7  4.2 (3)
# 7191  ./data/2022-05-09_12h43m_Subject 4.2 (3).txt        7  4.2 (3)

# %% [markdown]
# # Getting the Last Port Entry Before the Tone

# %% [markdown]
# - We will do the same, but get the port entries that happened before the tone

# %%
port_entries_pd_series = example_one_session_recording_df["(P)Portentry"]
port_exit_pd_series = example_one_session_recording_df["(N)Portexit"]

# %% [markdown]
# - Example run for one session

# %%
example_last_port_entries_before_tone = processing.tone.get_last_port_entries_before_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=port_entries_pd_series, port_exits_pd_series=port_exit_pd_series)

# %%
example_last_port_entries_before_tone
# Out:
#     current_tone_time  last_port_entry_before_tone  \
# 0               60.01                        55.03
# 1              140.01                       121.59
# 2              230.01                       228.33
# 3              310.01                       308.01
# 4              385.01                       383.35
# 5              485.01                       484.92
# 6              580.01                       573.13
# 7              670.01                       666.76
# 8              750.01                       748.43
# 9              840.01                       836.65
# 10             940.01                       938.39
# 11            1030.01                      1021.48
# 12            1150.01                      1148.76
# 13            1240.01                      1235.48
# 14            1325.01                      1320.79
# 15            1415.01                      1413.52
# 16            1510.01                      1508.68
# 17            1630.01                      1628.51
# 18            1710.01                      1709.76
# 19            1805.01                      1804.14
# 20            1885.01                      1882.41
# 21            1975.01                      1969.18
# 22            2055.01                      2053.64
# 23            2130.01                      2129.18
# 24            2230.01                      2225.68
# 25            2325.01                      2319.01
# 26            2415.01                      2411.17
# 27            2495.01                      2494.02
# 28            2585.01                      2576.56
# 29            2685.01                      2684.25
# 30            2775.01                      2772.99
# 31            2895.01                      2893.20
# 32            2985.01                      2980.85
# 33            3070.01                      3069.84
# 34            3160.01                      3151.73
# 35            3255.01                      3251.28
# 36            3345.01                      3343.32
# 37            3425.01                      3423.89
# 38            3515.01                      3510.92
# 39            3615.01                      3613.49
#
#     port_exit_after_last_port_entry_before_tone
# 0                                         56.22
# 1                                        124.01
# 2                                        242.78
# 3                                        333.39
# 4                                        404.79
# 5                                        503.19
# 6                                        575.47
# 7                                        668.24
# 8                                        774.62
# 9                                        838.60
# 10                                       958.92
# 11                                      1022.76
# 12                                      1149.97
# 13                                      1237.75
# 14                                      1323.76
# 15                                      1414.47
# 16                                      1509.03
# 17                                      1646.08
# 18                                      1733.12
# 19                                      1804.86
# 20                                      1900.02
# 21                                      1972.03
# 22                                      2067.83
# 23                                      2150.96
# 24                                      2245.76
# 25                                      2320.68
# 26                                      2413.55
# 27                                      2506.70
# 28                                      2577.81
# 29                                      2685.02
# 30                                      2775.00
# 31                                      2912.38
# 32                                      2983.59
# 33                                      3092.59
# 34                                      3153.58
# 35                                      3254.87
# 36                                      3343.60
# 37                                      3445.45
# 38                                      3532.86
# 39                                      3644.87

# %% [markdown]
# - Getting all the port entries that happen before the tone for all sessions

# %%
concatted_last_porty_entry_dataframe = processing.tone.get_concatted_last_porty_entry_before_tone_dataframe(concatted_medpc_df=recording_and_metadata_df, date_column="session")

# %%
concatted_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  last_port_entry_before_tone  \
# 0              60.01                        55.03
# 1             140.01                       121.59
# 2             230.01                       228.33
# 3             310.01                       308.01
# 4             385.01                       383.35
#
#    port_exit_after_last_port_entry_before_tone  \
# 0                                        56.22
# 1                                       124.01
# 2                                       242.78
# 3                                       333.39
# 4                                       404.79
#
#                                   file_path  session subject
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1

# %% [markdown]
# ## Merging the dataframes for the first port entry after the tone and the last tone before the tone

# %%
# Combining it based on the tone times and the file path
concatted_first_and_last_porty_entry_dataframe = pd.merge(concatted_first_porty_entry_dataframe, concatted_last_porty_entry_dataframe,  how='left', left_on=['current_tone_time','file_path'], right_on = ['current_tone_time','file_path'], suffixes=('', '_y'))
# Dropping all columns that are duplicates
concatted_first_and_last_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.drop(concatted_first_and_last_porty_entry_dataframe.filter(regex='_y$').columns.tolist(), axis=1)

# %% [markdown]
# - Adding the cage and strain information

# %%
subject_to_cage = pd.Series(metadata_df["cage"].astype(str).values,index=metadata_df["Subject"].astype(str).values).to_dict()

# %%
concatted_first_and_last_porty_entry_dataframe["subject"] = concatted_first_and_last_porty_entry_dataframe["subject"].astype(str)
recording_and_metadata_df["cage"] = recording_and_metadata_df["cage"].astype(str)
recording_and_metadata_df["subject"] = recording_and_metadata_df["subject"].astype(str)
metadata_df["cage"] = metadata_df["cage"].astype(str)
metadata_df["Subject"] = metadata_df["Subject"].astype(str)

# %%
concatted_first_and_last_porty_entry_dataframe["cage"] = concatted_first_and_last_porty_entry_dataframe["subject"].map(subject_to_cage)

# %%
cage_to_strain = pd.Series(recording_and_metadata_df["strain"].values,index=recording_and_metadata_df["cage"].values).to_dict()

# %%
cage_to_strain
# Out:
# {'2': 'C57', '4': 'CD1', '1': 'C57', '3': 'CD1'}

# %%
concatted_first_and_last_porty_entry_dataframe["strain"] = concatted_first_and_last_porty_entry_dataframe["cage"].map(cage_to_strain)

# %%
concatted_first_and_last_porty_entry_dataframe["strain"].unique()
# Out:
# array(['C57', 'CD1'], dtype=object)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        62.44
# 1             140.01                       144.48
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        62.49
# 1                                       160.30
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
#
#                                   file_path  session subject  \
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        55.03                                        56.22
# 1                       121.59                                       124.01
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
#
#   cage strain
# 0    2    C57
# 1    2    C57
# 2    2    C57
# 3    2    C57
# 4    2    C57

# %%
concatted_first_and_last_porty_entry_dataframe.shape
# Out:
# (7192, 10)

# %% [markdown]
# - Getting all the rows that have port entry to port exit time that overlaps with the tone playing
#     - This would be the port entries that came before the tone, but had a port exit after

# %%
port_entries_that_overlap = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["port_exit_after_last_port_entry_before_tone"] >= concatted_first_and_last_porty_entry_dataframe["current_tone_time"]]

# %%
port_entries_that_overlap.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
# 5             485.01                       503.92
# 8             750.01                       778.23
#
#    port_exit_after_first_port_entry_after_tone  \
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
# 5                                       508.02
# 8                                       780.07
#
#                                   file_path  session subject  \
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 5  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 8  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
# 5                       484.92                                       503.19
# 8                       748.43                                       774.62
#
#   cage strain
# 2    2    C57
# 3    2    C57
# 4    2    C57
# 5    2    C57
# 8    2    C57

# %%
port_entries_that_overlap.shape
# Out:
# (1697, 10)

# %% [markdown]
# # Getting the Latency for Each Session of a Tone Playing

# %% [markdown]
# - To calculate latency, we would just subtract the time of the first port entry to that of the tone playing

# %%
concatted_first_and_last_porty_entry_dataframe["latency"] = concatted_first_porty_entry_dataframe["first_port_entry_after_tone"] - concatted_first_and_last_porty_entry_dataframe["current_tone_time"]

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        62.44
# 1             140.01                       144.48
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        62.49
# 1                                       160.30
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
#
#                                   file_path  session subject  \
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        55.03                                        56.22
# 1                       121.59                                       124.01
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
#
#   cage strain  latency
# 0    2    C57     2.43
# 1    2    C57     4.47
# 2    2    C57    13.33
# 3    2    C57    25.42
# 4    2    C57    20.94

# %% [markdown]
# - For all the latencies that are are greater than 30 seconds, we changed the latency to 30 seconds

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"] = concatted_first_and_last_porty_entry_dataframe["latency"].apply(lambda x: 30 if x >= 30 else x)

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["latency"] >= 30].head()
# Out:
#      current_tone_time  first_port_entry_after_tone  \
# 39             3615.01                      3645.69
# 79             3615.01                      3648.03
# 120              60.01                        95.16
# 121             140.01                       203.69
# 129             840.01                       956.77
#
#      port_exit_after_first_port_entry_after_tone  \
# 39                                       3649.23
# 79                                       3651.94
# 120                                        95.41
# 121                                       205.80
# 129                                       973.82
#
#                                     file_path  session subject  \
# 39   ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 79   ./data/2022-05-04_10h11m_Subject 2.1.txt        2     2.1
# 120  ./data/2022-05-07_08h53m_Subject 1.4.txt        5     1.4
# 121  ./data/2022-05-07_08h53m_Subject 1.4.txt        5     1.4
# 129  ./data/2022-05-07_08h53m_Subject 1.4.txt        5     1.4
#
#      last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 39                       3613.49                                      3644.87
# 79                       3604.22                                      3606.79
# 120                        49.50                                        49.52
# 121                       138.44                                       139.79
# 129                       823.60                                       932.46
#
#     cage strain  latency  latency_adjusted_greater_than_30
# 39     2    C57    30.68                              30.0
# 79     2    C57    33.02                              30.0
# 120    1    C57    35.15                              30.0
# 121    1    C57    63.68                              30.0
# 129    1    C57   116.76                              30.0

# %% [markdown]
# # Seeing which port entries and port exit durations overlap with the tone

# %% [markdown]
# - Making a column that states whether or not the last port entry before the tone has a port exit after the tone. This would mean that they are overlapping.

# %%
concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: True if row["port_exit_after_last_port_entry_before_tone"] >= row["current_tone_time"] else False, axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        62.44
# 1             140.01                       144.48
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        62.49
# 1                                       160.30
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
#
#                                   file_path  session subject  \
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        55.03                                        56.22
# 1                       121.59                                       124.01
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
#
#   cage strain  latency  latency_adjusted_greater_than_30  \
# 0    2    C57     2.43                              2.43
# 1    2    C57     4.47                              4.47
# 2    2    C57    13.33                             13.33
# 3    2    C57    25.42                             25.42
# 4    2    C57    20.94                             20.94
#
#    overlapping_port_entry_with_tone
# 0                             False
# 1                             False
# 2                              True
# 3                              True
# 4                              True

# %% [markdown]
# - Comparing the latencies of the first port entry after the tone between these two groups:
#     - 1. Those with the last port entry before the tone that has a port exit after the tone("overlapping" group)
#     - 2. Those with the last port entry before the tone that has a port exit before the tone("nonoverlapping" group)

# %%
overlapping_df = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %%
non_overlapping_df = concatted_first_and_last_porty_entry_dataframe[~concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %% [markdown]
# - Number of rows of overlapping and nonoverlapping last port entries before the tone

# %%
overlapping_df.shape
# Out:
# (1697, 13)

# %%
non_overlapping_df.shape
# Out:
# (5495, 13)

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone

# %%
overlapping_df["latency"].mean()
# Out:
# 13.525705014749176

# %%
non_overlapping_df["latency"].mean()
# Out:
# 13.74066445182713

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone. This had been adjusted so that all latencies that are greater than 30 seconds were adjusted to be just 30 seconds.

# %%
overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 12.318525073746219

# %%
non_overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 8.185751199704612

# %% [markdown]
# # Adjusting the Latencies if the Port Entries/Exit Overlap With the Tone Times

# %% [markdown]
# - For all the rows with overlapping last port entries before the tone, we will adjust the latency of the tone to the first port entry after the tone to 0. (Because the first port entry after the tone would be considered to be the same as the last port entry before the tone)

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: 0 if row["overlapping_port_entry_with_tone"] else row["latency_adjusted_greater_than_30"], axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        62.44
# 1             140.01                       144.48
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        62.49
# 1                                       160.30
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
#
#                                   file_path  session subject  \
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        55.03                                        56.22
# 1                       121.59                                       124.01
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
#
#   cage strain  latency  latency_adjusted_greater_than_30  \
# 0    2    C57     2.43                              2.43
# 1    2    C57     4.47                              4.47
# 2    2    C57    13.33                             13.33
# 3    2    C57    25.42                             25.42
# 4    2    C57    20.94                             20.94
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap
# 0                             False                      2.43
# 1                             False                      4.47
# 2                              True                      0.00
# 3                              True                      0.00
# 4                              True                      0.00

# %% [markdown]
# - All the rows with overlapping last port entries before the tone

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]].head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
# 5             485.01                       503.92
# 8             750.01                       778.23
#
#    port_exit_after_first_port_entry_after_tone  \
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
# 5                                       508.02
# 8                                       780.07
#
#                                   file_path  session subject  \
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 5  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 8  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
# 5                       484.92                                       503.19
# 8                       748.43                                       774.62
#
#   cage strain  latency  latency_adjusted_greater_than_30  \
# 2    2    C57    13.33                             13.33
# 3    2    C57    25.42                             25.42
# 4    2    C57    20.94                             20.94
# 5    2    C57    18.91                             18.91
# 8    2    C57    28.22                             28.22
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap
# 2                              True                       0.0
# 3                              True                       0.0
# 4                              True                       0.0
# 5                              True                       0.0
# 8                              True                       0.0

# %% [markdown]
# ## Labeling if a row's latency is less than 10 seconds or not

# %% [markdown]
# - We will be getting the ratio of latencies(from the time that the tone played, to the first port entry after the tone) that are less than 10 seconds for each session. So we will label all the adjusted latencies that are less than 10 seconds as `True`, and the those with latencies that are greater than 10 seconds as `False`

# %%
concatted_first_and_last_porty_entry_dataframe["adjusted_30_second_latency_less_than_10_seconds_ratio"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe["overlap_adjusted_latency_less_than_10_seconds"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        62.44
# 1             140.01                       144.48
# 2             230.01                       243.34
# 3             310.01                       335.43
# 4             385.01                       405.95
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        62.49
# 1                                       160.30
# 2                                       246.01
# 3                                       338.66
# 4                                       408.49
#
#                                   file_path  session subject  \
# 0  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 1  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 2  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 3  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
# 4  ./data/2022-05-16_11h28m_Subject 2.1.txt       11     2.1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        55.03                                        56.22
# 1                       121.59                                       124.01
# 2                       228.33                                       242.78
# 3                       308.01                                       333.39
# 4                       383.35                                       404.79
#
#   cage strain  latency  latency_adjusted_greater_than_30  \
# 0    2    C57     2.43                              2.43
# 1    2    C57     4.47                              4.47
# 2    2    C57    13.33                             13.33
# 3    2    C57    25.42                             25.42
# 4    2    C57    20.94                             20.94
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap  \
# 0                             False                      2.43
# 1                             False                      4.47
# 2                              True                      0.00
# 3                              True                      0.00
# 4                              True                      0.00
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                           True
# 4                                           True

# %% [markdown]
# # Making Dataframes that have Each Subject as the Row and Each Date as the Column

# %% [markdown]
# - Pivot plots allow us to make columns out of each unique entry in a selected column. (For this, it will be the date column that we will turn into columns) The index for the rows will be each unique entry in another column. (For this, it will be the subject's ID) And the values will be the aggregate of the values that have both the values in the previous two selected columns. (For this it will be the latency columns and we will take the mean)
#     - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %% [markdown]
# - Making a folder for all the pivotplots

# %% [markdown]
# # NOTE: If you decide to change the cage numbers or the dates used from the original ones from the imported dataframes, you will need to change the subsequent path to the cage number and dates you are using

# %%
first_port_entry_to_tone_latency_output_directory = "./proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
first_port_entry_to_tone_latency_output_directory
# Out:
# './proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(first_port_entry_to_tone_latency_output_directory, exist_ok=True)

# %%
latencies_less_than_10_seconds_ratio_output_directory = "./proc/subject_rows_with_date_columns_dataframes/latencies_less_than_10_seconds_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
latencies_less_than_10_seconds_ratio_output_directory
# Out:
# './proc/subject_rows_with_date_columns_dataframes/latencies_less_than_10_seconds_ratio/cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(latencies_less_than_10_seconds_ratio_output_directory, exist_ok=True)

# %% [markdown]
# ## Making a pivot plot with the original latency

# %%
all_latency_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency', \
                                        index=['subject'], columns=['session'], aggfunc=np.mean)

# %%
all_latency_pivot_plot.head()
# Out:
# session         1          2           3          4         5          6   \
# subject
# 1.1      42.218000   6.046829   11.537750   5.956341   3.59800  10.863590
# 1.2      49.817857  25.471538   13.112195   7.628250   5.64800   4.987692
# 1.3      86.598000  36.300526  373.844750  14.234500   7.00100   8.922821
# 1.4      61.345333  10.832683  125.872000  29.977805  12.33400   6.594103
# 2.1      30.953125   7.548500   18.269268   5.618500   3.92925   6.335897
#
# session       7         8         9          10        11       12
# subject
# 1.1      7.18400  6.876750   9.92700   8.523659  72.79875      NaN
# 1.2      4.09525  9.064000   6.92650  18.890000  10.48700  9.65600
# 1.3      8.97225  8.345250   7.85100  16.605500  13.88725  6.03575
# 1.4      5.93475  8.869625  19.38650  12.103659   6.84700      NaN
# 2.1      5.16775  6.824000   4.94175  17.108250   9.88850  5.96375

# %% [markdown]
# - Getting the cage numbers for each subject and then making a dictionary out of it
#     - This will be used to add the cage information to the pivot plots

# %%
# Converting the cage numbers from floats to integers
# When the metadata is imported from the csv files, the cage number is imported as a float
# metadata_df["cage"] = metadata_df["cage"].astype(int)

# %%
subject_to_cage = pd.Series(metadata_df["cage"].values,index=metadata_df["Subject"].values).to_dict()

# %%
subject_to_cage
# Out:
# {'2.1': '2',
#  '3.1 (1)': '4',
#  '1.4': '1',
#  '3.4 (2)': '4',
#  '4.3 (3)': '4',
#  '2.4': '2',
#  '1.1': '1',
#  '4.1 (1)': '3',
#  '2.2': '1',
#  '1.2': '2',
#  '3.3 (4)': '3',
#  '4.4 (4)': '4',
#  '1.3': '2',
#  '3.2 (2)': '3',
#  '4.2 (3)': '3',
#  '2.3': '1'}

# %% [markdown]
# - Adding the cage information with the dictionary

# %%
all_latency_pivot_plot["cage"] = all_latency_pivot_plot.index.map(subject_to_cage)

# %%
all_latency_pivot_plot.head()
# Out:
# session          1          2           3          4         5          6  \
# subject
# 1.1      42.218000   6.046829   11.537750   5.956341   3.59800  10.863590
# 1.2      49.817857  25.471538   13.112195   7.628250   5.64800   4.987692
# 1.3      86.598000  36.300526  373.844750  14.234500   7.00100   8.922821
# 1.4      61.345333  10.832683  125.872000  29.977805  12.33400   6.594103
# 2.1      30.953125   7.548500   18.269268   5.618500   3.92925   6.335897
#
# session        7         8         9         10        11       12 cage
# subject
# 1.1      7.18400  6.876750   9.92700   8.523659  72.79875      NaN    1
# 1.2      4.09525  9.064000   6.92650  18.890000  10.48700  9.65600    2
# 1.3      8.97225  8.345250   7.85100  16.605500  13.88725  6.03575    2
# 1.4      5.93475  8.869625  19.38650  12.103659   6.84700      NaN    1
# 2.1      5.16775  6.824000   4.94175  17.108250   9.88850  5.96375    2

# %%
file_path = "original_latency_cage_{}_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    all_latency_pivot_plot.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    all_latency_pivot_plot.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with the latency that were greater than 30 seconds being adjusted

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_greater_than_30', index=['subject'],

                    columns=['session'], aggfunc=np.mean)

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot["cage"] = latency_greater_than_30_seconds_adjusted_pivot_plot.index.map(subject_to_cage)

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot.head()
# Out:
# session          1          2          3          4        5          6  \
# subject
# 1.1      19.980000   6.046829   9.446750   5.956341  3.59800  10.670769
# 1.2      27.120000  17.573077  11.960732   7.628250  5.64800   4.987692
# 1.3      27.746000  21.131316  26.896000  10.405250  6.65950   8.282564
# 1.4      22.285333  10.832683  24.336000  12.144634  9.19425   6.594103
# 2.1      17.701875   7.473000  10.245122   5.289500  3.92925   5.700256
#
# session        7         8         9         10        11       12 cage
# subject
# 1.1      7.18400  6.862375   9.92350   8.523659  12.16200      NaN    1
# 1.2      4.09525  7.562000   6.92650  16.957250   9.76425  9.60225    2
# 1.3      7.27000  8.273500   7.78250  15.180500  13.35200  6.03575    2
# 1.4      5.93475  8.779250  14.12675  11.990732   6.84700      NaN    1
# 2.1      5.16775  6.824000   4.94175  15.184500   9.87150  5.96375    2

# %%
file_path = "subject_to_date_latency_greater_than_30_seconds_adjusted_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    latency_greater_than_30_seconds_adjusted_pivot_plot.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    latency_greater_than_30_seconds_adjusted_pivot_plot.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with adjusted latencies that overlapped with a tone playing

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_overlap', index=['subject'],

                    columns=['session'], aggfunc=np.mean)

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot["cage"] = latency_that_overlaps_with_tone_adjusted_pivot_plot.index.map(subject_to_cage)

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot.head()
# Out:
# session          1          2          3          4        5         6  \
# subject
# 1.1      19.980000   5.638780   8.474500   3.185366  1.96425  2.244872
# 1.2      22.605714  17.554615  10.497805   6.671250  4.24600  3.467436
# 1.3      27.746000  21.131316  26.146000   9.181750  3.99875  4.985128
# 1.4      21.607333  10.755366  24.336000  11.102683  6.52950  5.418974
# 2.1      12.203125   7.106250  10.013659   4.803500  2.69950  3.656410
#
# session        7         8        9        10       11       12 cage
# subject
# 1.1      1.64500  1.147125  0.66375  0.994878  6.50900      NaN    1
# 1.2      2.48425  1.726750  2.05925  1.292750  1.41775  1.67125    2
# 1.3      3.83350  2.830000  3.09475  1.147000  0.68725  1.81000    2
# 1.4      3.51200  2.715875  4.73125  1.088537  1.70225      NaN    1
# 2.1      1.60600  1.242750  2.20575  3.282250  0.93000  0.91725    2

# %%
file_path = "subject_to_date_latency_that_overlaps_with_tone_adjusted_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    latency_that_overlaps_with_tone_adjusted_pivot_plot.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    latency_that_overlaps_with_tone_adjusted_pivot_plot.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with the ratio of original latencies that are less than 10 seconds

# %%
original_less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='adjusted_30_second_latency_less_than_10_seconds_ratio', index=['subject'],

                    columns=['session'], aggfunc=np.mean)

# %%
original_less_than_10_latency_df["cage"] = original_less_than_10_latency_df.index.map(subject_to_cage)

# %%
original_less_than_10_latency_df
# Out:
# session         1         2         3         4      5         6      7  \
# subject
# 1.1      0.333333  0.780488  0.675000  0.829268  0.975  0.589744  0.725
# 1.2      0.062500  0.400000  0.487805  0.675000  0.925  0.923077  0.950
# 1.3      0.000000  0.225000  0.073171  0.600000  0.825  0.717949  0.700
# 1.4      0.200000  0.487805  0.025000  0.512195  0.600  0.769231  0.825
# 2.1      0.250000  0.775000  0.658537  0.875000  0.925  0.820513  0.775
# 2.2      0.200000  0.487805  0.750000  0.804878  0.925  0.820513  0.675
# 2.3      0.066667  0.487805  0.725000  0.902439  0.900  0.923077  0.925
# 2.4      0.250000  0.275000  0.536585  0.675000  0.850  0.923077  1.000
# 3.1 (1)  0.675000  0.780488  0.800000  0.825000  0.900  0.897436  0.950
# 3.2 (2)  0.414634  0.463415  0.585366  0.625000  0.650  0.400000  0.500
# 3.3 (4)  0.317073  0.536585  0.195122  0.525000  0.500  0.725000  0.650
# 3.4 (2)  0.500000  0.609756  0.800000  0.875000  0.775  0.897436  0.825
# 4.1 (1)  0.170732  0.195122  0.365854  0.525000  0.575  0.450000  0.475
# 4.2 (3)  0.634146  0.682927  0.292683  0.700000  0.575  0.875000  0.875
# 4.3 (3)  0.425000  0.829268  0.675000  0.725000  0.750  0.794872  0.825
# 4.4 (4)  0.250000  0.536585  0.525000  0.600000  0.475  0.794872  0.800
#
# session         8      9        10        11     12 cage
# subject
# 1.1      0.687500  0.500  0.634146  0.550000    NaN    1
# 1.2      0.775000  0.800  0.325000  0.700000  0.650    2
# 1.3      0.725000  0.700  0.450000  0.500000  0.775    2
# 1.4      0.587500  0.425  0.439024  0.675000    NaN    1
# 2.1      0.600000  0.775  0.400000  0.550000  0.725    2
# 2.2      0.662500  0.300  0.585366  0.800000    NaN    1
# 2.3      0.837500  0.750  0.853659  0.950000    NaN    1
# 2.4      0.875000  0.900  0.800000  0.725000  0.800    2
# 3.1 (1)  0.853659  0.925  0.925000  1.000000    NaN    4
# 3.2 (2)  0.390244  0.525  0.575000  0.461538    NaN    3
# 3.3 (4)  0.682927  0.450  0.550000  0.820513    NaN    3
# 3.4 (2)  0.804878  0.850  0.800000  0.926829    NaN    4
# 4.1 (1)  0.560976  0.625  0.375000  0.512821    NaN    3
# 4.2 (3)  0.853659  0.825  0.725000  0.897436    NaN    3
# 4.3 (3)  0.731707  0.750  0.850000  0.902439    NaN    4
# 4.4 (4)  0.682927  0.825  0.850000  0.853659    NaN    4

# %%
file_path = "subject_to_date_less_than_10_seconds_original_latencies_ratios_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    original_less_than_10_latency_df.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    original_less_than_10_latency_df.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with the ratio of overlap adjusted latencies that are less than 10 seconds

# %%
overlap_adjusted_less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='overlap_adjusted_latency_less_than_10_seconds', index=['subject'],

                    columns=['session'], aggfunc=np.mean)

# %%
overlap_adjusted_less_than_10_latency_df["cage"] = overlap_adjusted_less_than_10_latency_df.index.map(subject_to_cage)

# %%
overlap_adjusted_less_than_10_latency_df
# Out:
# session         1         2         3         4      5         6      7  \
# subject
# 1.1      0.333333  0.780488  0.700000  0.926829  1.000  0.974359  0.975
# 1.2      0.187500  0.400000  0.560976  0.725000  0.950  0.974359  0.975
# 1.3      0.000000  0.225000  0.097561  0.650000  0.900  0.846154  0.825
# 1.4      0.266667  0.487805  0.025000  0.560976  0.725  0.794872  0.925
# 2.1      0.437500  0.775000  0.658537  0.875000  0.975  0.923077  1.000
# 2.2      0.266667  0.536585  0.775000  0.829268  0.975  1.000000  0.975
# 2.3      0.133333  0.487805  0.750000  0.926829  0.900  0.923077  0.950
# 2.4      0.250000  0.275000  0.560976  0.725000  0.875  0.948718  1.000
# 3.1 (1)  0.750000  0.804878  0.850000  0.900000  0.900  0.897436  0.950
# 3.2 (2)  0.487805  0.536585  0.634146  0.800000  0.875  0.800000  0.850
# 3.3 (4)  0.341463  0.585366  0.243902  0.575000  0.525  0.750000  0.675
# 3.4 (2)  0.525000  0.682927  0.825000  0.875000  0.825  0.923077  0.825
# 4.1 (1)  0.170732  0.195122  0.414634  0.550000  0.625  0.700000  0.825
# 4.2 (3)  0.634146  0.731707  0.292683  0.725000  0.600  0.875000  0.875
# 4.3 (3)  0.450000  0.829268  0.775000  0.750000  0.800  0.820513  0.825
# 4.4 (4)  0.325000  0.560976  0.525000  0.700000  0.600  0.846154  0.825
#
# session         8      9       10        11     12 cage
# subject
# 1.1      1.000000  1.000  1.00000  0.800000    NaN    1
# 1.2      0.975000  1.000  0.97500  1.000000  0.975    2
# 1.3      0.950000  0.950  0.97500  1.000000  0.975    2
# 1.4      0.900000  0.850  1.00000  0.975000    NaN    1
# 2.1      1.000000  0.975  0.90000  1.000000  1.000    2
# 2.2      1.000000  0.825  1.00000  1.000000    NaN    1
# 2.3      0.987500  0.950  0.97561  1.000000    NaN    1
# 2.4      0.925000  0.975  0.97500  1.000000  1.000    2
# 3.1 (1)  0.902439  0.950  1.00000  1.000000    NaN    4
# 3.2 (2)  0.878049  0.900  0.82500  0.794872    NaN    3
# 3.3 (4)  0.756098  0.475  0.62500  0.820513    NaN    3
# 3.4 (2)  0.878049  0.950  0.97500  1.000000    NaN    4
# 4.1 (1)  0.682927  0.700  0.42500  0.538462    NaN    3
# 4.2 (3)  0.878049  0.825  0.75000  0.923077    NaN    3
# 4.3 (3)  0.731707  0.800  0.85000  0.926829    NaN    4
# 4.4 (4)  0.756098  0.825  0.90000  0.926829    NaN    4

# %%
overlap_adjusted_less_than_10_latency_df.to_csv(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_overlap_adjusted_latencies_ratios_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
overlap_adjusted_less_than_10_latency_df.to_excel(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_overlap_adjusted_latencies_ratios_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# # Plotting the latencies

# %% [markdown]
# ## Getting the averages for all the trials in one subject and one day

# %% [markdown]
# - We will plot a line for each subject. With the X-axis being the days since the first session. And the Y-axis is the latency values averaged across all the trials for one recording session
# - Grouping all the rows with the same subject and date(aka, all the trials in one session). And then getting the mean for each value

# %%
grouped_averaged_first_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.groupby(by=["session", "subject"]).mean()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                  current_tone_time  first_port_entry_after_tone  \
# session subject
# 1       1.1             675.676667                   717.894667
#         1.2             721.885000                   679.113571
#         1.3             721.885000                   762.274667
#         1.4             675.676667                   737.022000
#         2.1             721.885000                   752.838125
#
#                  port_exit_after_first_port_entry_after_tone  \
# session subject
# 1       1.1                                       718.904667
#         1.2                                       681.099286
#         1.3                                       764.120000
#         1.4                                       737.790667
#         2.1                                       757.749375
#
#                  last_port_entry_before_tone  \
# session subject
# 1       1.1                       708.214615
#         1.2                       787.512143
#         1.3                       637.862500
#         1.4                       613.392000
#         2.1                       701.735625
#
#                  port_exit_after_last_port_entry_before_tone    latency  \
# session subject
# 1       1.1                                       708.941538  42.218000
#         1.2                                       790.962857  49.817857
#         1.3                                       640.833125  86.598000
#         1.4                                       614.831333  61.345333
#         2.1                                       703.736875  30.953125
#
#                  latency_adjusted_greater_than_30  \
# session subject
# 1       1.1                             19.980000
#         1.2                             27.120000
#         1.3                             27.746000
#         1.4                             22.285333
#         2.1                             17.701875
#
#                  overlapping_port_entry_with_tone  latency_adjusted_overlap  \
# session subject
# 1       1.1                              0.000000                 19.980000
#         1.2                              0.187500                 22.605714
#         1.3                              0.000000                 27.746000
#         1.4                              0.066667                 21.607333
#         2.1                              0.250000                 12.203125
#
#                  adjusted_30_second_latency_less_than_10_seconds_ratio  \
# session subject
# 1       1.1                                               0.333333
#         1.2                                               0.062500
#         1.3                                               0.000000
#         1.4                                               0.200000
#         2.1                                               0.250000
#
#                  overlap_adjusted_latency_less_than_10_seconds
# session subject
# 1       1.1                                           0.333333
#         1.2                                           0.187500
#         1.3                                           0.000000
#         1.4                                           0.266667
#         2.1                                           0.437500

# %% [markdown]
# ## Reformatting the Dataframe for plotting

# %% [markdown]
# - Resetting the index so that we can use the data as a value

# %%
grouped_averaged_first_porty_entry_dataframe = grouped_averaged_first_porty_entry_dataframe.reset_index()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#    session subject  current_tone_time  first_port_entry_after_tone  \
# 0        1     1.1         675.676667                   717.894667
# 1        1     1.2         721.885000                   679.113571
# 2        1     1.3         721.885000                   762.274667
# 3        1     1.4         675.676667                   737.022000
# 4        1     2.1         721.885000                   752.838125
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   718.904667                   708.214615
# 1                                   681.099286                   787.512143
# 2                                   764.120000                   637.862500
# 3                                   737.790667                   613.392000
# 4                                   757.749375                   701.735625
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   708.941538  42.218000
# 1                                   790.962857  49.817857
# 2                                   640.833125  86.598000
# 3                                   614.831333  61.345333
# 4                                   703.736875  30.953125
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         19.980000                          0.000000
# 1                         27.120000                          0.187500
# 2                         27.746000                          0.000000
# 3                         22.285333                          0.066667
# 4                         17.701875                          0.250000
#
#    latency_adjusted_overlap  \
# 0                 19.980000
# 1                 22.605714
# 2                 27.746000
# 3                 21.607333
# 4                 12.203125
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.333333
# 1                                           0.062500
# 2                                           0.000000
# 3                                           0.200000
# 4                                           0.250000
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                       0.333333
# 1                                       0.187500
# 2                                       0.000000
# 3                                       0.266667
# 4                                       0.437500

# %% [markdown]
# - Turning the date column which is a string, into an integer
#     - This will allow us to use the date as the X-axis for plotting

# %% [raw]
# grouped_averaged_first_porty_entry_dataframe["date_int"] = grouped_averaged_first_porty_entry_dataframe["date"].astype(int)

# %% [raw]
# grouped_averaged_first_porty_entry_dataframe.head()

# %% [markdown]
# - Adding the cage information
#     - We will make one plot for each cage

# %%
grouped_averaged_first_porty_entry_dataframe["subject"].unique()
# Out:
# array(['1.1', '1.2', '1.3', '1.4', '2.1', '2.2', '2.3', '2.4', '3.1 (1)',
#        '3.2 (2)', '3.3 (4)', '3.4 (2)', '4.1 (1)', '4.2 (3)', '4.3 (3)',
#        '4.4 (4)'], dtype=object)

# %%
grouped_averaged_first_porty_entry_dataframe["cage"] = grouped_averaged_first_porty_entry_dataframe["subject"].map(subject_to_cage)

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#    session subject  current_tone_time  first_port_entry_after_tone  \
# 0        1     1.1         675.676667                   717.894667
# 1        1     1.2         721.885000                   679.113571
# 2        1     1.3         721.885000                   762.274667
# 3        1     1.4         675.676667                   737.022000
# 4        1     2.1         721.885000                   752.838125
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   718.904667                   708.214615
# 1                                   681.099286                   787.512143
# 2                                   764.120000                   637.862500
# 3                                   737.790667                   613.392000
# 4                                   757.749375                   701.735625
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   708.941538  42.218000
# 1                                   790.962857  49.817857
# 2                                   640.833125  86.598000
# 3                                   614.831333  61.345333
# 4                                   703.736875  30.953125
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         19.980000                          0.000000
# 1                         27.120000                          0.187500
# 2                         27.746000                          0.000000
# 3                         22.285333                          0.066667
# 4                         17.701875                          0.250000
#
#    latency_adjusted_overlap  \
# 0                 19.980000
# 1                 22.605714
# 2                 27.746000
# 3                 21.607333
# 4                 12.203125
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.333333
# 1                                           0.062500
# 2                                           0.000000
# 3                                           0.200000
# 4                                           0.250000
#
#    overlap_adjusted_latency_less_than_10_seconds cage
# 0                                       0.333333    1
# 1                                       0.187500    2
# 2                                       0.000000    2
# 3                                       0.266667    1
# 4                                       0.437500    2

# %% [markdown]
# ## Plotting the latencies that were adjusted if they greater than 30 seconds

# %%
original_average_latency_output_directory = "./proc/plots/original_average_latency_plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
original_average_latency_output_directory
# Out:
# './proc/plots/original_average_latency_plots/cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(original_average_latency_output_directory, exist_ok=True)

# %%
plt.rcParams["figure.figsize"] = (13.5,7.5)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = (13.5,7.5)

    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["session"], subject_df["latency_adjusted_greater_than_30"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Adjusted Average Latency of First Entry to Tone Onset")
    ax.set_title("Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    file_name = "original_average_latency_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(original_average_latency_output_directory, file_name))

# %% [markdown]
# ## Plotting the original ratio of latencies that are less than 10 seconds

# %%
less_than_10_second_original_latency_ratio_plots_output_directory = "./proc/plots/less_than_10_second_original_latency_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
less_than_10_second_original_latency_ratio_plots_output_directory
# Out:
# './proc/plots/less_than_10_second_original_latency_ratio/cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(less_than_10_second_original_latency_ratio_plots_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = (13.5,7.5)

    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["session"], subject_df["adjusted_30_second_latency_less_than_10_seconds_ratio"], '-o', label=subject)
    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Less Than 10 Seconds Latencies from Tone Onset: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    
    file_name = "less_than_10_second_original_latency_ratio_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(less_than_10_second_original_latency_ratio_plots_output_directory, file_name))

# %% [markdown]
# # Plotting the Adjusted Latencies for Entries that Overlap with the Tone

# %% [markdown]
# ## Plotting the Latencies

# %%
overlap_adjusted_average_latency_plots_output_directory = "./proc/plots/overlap_adjusted_average_latency_plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
overlap_adjusted_average_latency_plots_output_directory
# Out:
# './proc/plots/overlap_adjusted_average_latency_plots/cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(overlap_adjusted_average_latency_plots_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = (13.5,7.5)

    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["session"], subject_df["latency_adjusted_overlap"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    file_name = "overlap_adjusted_average_latency_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)

    plt.savefig(os.path.join(overlap_adjusted_average_latency_plots_output_directory, file_name))

# %% [markdown]
# # Plotting the ratio of overlap adjusted latencies that are less than 10 seconds

# %%
less_than_10_second_overlap_adjusted_latency_ratio_output_directory = "./proc/plots/less_than_10_second_overlap_adjusted_latency_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
less_than_10_second_overlap_adjusted_latency_ratio_output_directory
# Out:
# './proc/plots/less_than_10_second_overlap_adjusted_latency_ratio/cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(less_than_10_second_overlap_adjusted_latency_ratio_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = (13.5,7.5)

    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["session"], subject_df["overlap_adjusted_latency_less_than_10_seconds"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Less Than 10sec Latencies from Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend(loc="lower right")
    
    
    file_name = "less_than_10_second_overlap_adjusted_latency_ratio_plot_cage{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(less_than_10_second_overlap_adjusted_latency_ratio_output_directory, file_name))

# %% [markdown]
# ## Plotting the average per strain

# %% [markdown]
# ## Getting the averages for all the trials in one subject and one day

# %% [markdown]
# - We will plot a line for each subject. With the X-axis being the days since the first session. And the Y-axis is the latency values averaged across all the trials for one recording session
# - Grouping all the rows with the same subject and date(aka, all the trials in one session). And then getting the mean for each value

# %%
subject_to_cage
# Out:
# {'2.1': '2',
#  '3.1 (1)': '4',
#  '1.4': '1',
#  '3.4 (2)': '4',
#  '4.3 (3)': '4',
#  '2.4': '2',
#  '1.1': '1',
#  '4.1 (1)': '3',
#  '2.2': '1',
#  '1.2': '2',
#  '3.3 (4)': '3',
#  '4.4 (4)': '4',
#  '1.3': '2',
#  '3.2 (2)': '3',
#  '4.2 (3)': '3',
#  '2.3': '1'}

# %%
grouped_averaged_first_porty_entry_dataframe["cage"] = grouped_averaged_first_porty_entry_dataframe["subject"].map(subject_to_cage)
grouped_averaged_first_porty_entry_dataframe["strain"] = grouped_averaged_first_porty_entry_dataframe["cage"].map(cage_to_strain)

# %%
strain_averaged_first_porty_entry_dataframe = grouped_averaged_first_porty_entry_dataframe.groupby(by=["strain", "session"]).mean()

# %%
strain_averaged_first_porty_entry_dataframe
# Out:
#                 current_tone_time  first_port_entry_after_tone  \
# strain session
# C57    1               698.780833                   734.433316
#        2              1848.554207                  1844.271133
#        3              1848.554207                  1710.002037
#        4              1848.554207                  1858.872002
#        5              1825.635000                  1831.388625
#        6              1779.753590                  1786.324071
#        7              1825.635000                  1831.237062
#        8              1825.635000                  1832.918187
#        9              1825.635000                  1836.088344
#        10             1848.554207                  1854.333738
#        11             1825.635000                  1841.851906
#        12             1825.635000                  1832.798563
# CD1    1              1848.554207                  1835.732186
#        2              1871.473415                  1869.118311
#        3              1848.554207                  1736.548635
#        4              1825.635000                  1830.558643
#        5              1825.635000                  1835.105250
#        6              1802.694295                  1811.815673
#        7              1825.635000                  1833.424656
#        8              1871.473415                  1880.469177
#        9              1825.635000                  1834.135000
#        10             1825.635000                  1828.454579
#        11             1825.613502                  1832.891348
#
#                 port_exit_after_first_port_entry_after_tone  \
# strain session
# C57    1                                         730.624326
#        2                                        1846.684866
#        3                                        1713.004554
#        4                                        1858.080024
#        5                                        1836.880594
#        6                                        1792.469744
#        7                                        1821.252619
#        8                                        1840.489578
#        9                                        1843.142906
#        10                                       1851.339534
#        11                                       1851.668312
#        12                                       1843.037750
# CD1    1                                        1839.399581
#        2                                        1868.176423
#        3                                        1741.357869
#        4                                        1835.527563
#        5                                        1838.480906
#        6                                        1814.822623
#        7                                        1837.166313
#        8                                        1884.146524
#        9                                        1837.267375
#        10                                       1833.461191
#        11                                       1836.751722
#
#                 last_port_entry_before_tone  \
# strain session
# C57    1                         690.577578
#        2                        1833.374269
#        3                        1692.127284
#        4                        1872.052778
#        5                        1824.432103
#        6                        1773.227340
#        7                        1820.546344
#        8                        1820.406828
#        9                        1818.400094
#        10                       1843.745284
#        11                       1873.034669
#        12                       1821.528000
# CD1    1                        1837.548620
#        2                        1860.896700
#        3                        1777.840024
#        4                        1814.608813
#        5                        1816.652375
#        6                        1793.668637
#        7                        1817.276687
#        8                        1862.473171
#        9                        1816.954313
#        10                       1816.459313
#        11                       1835.554646
#
#                 port_exit_after_last_port_entry_before_tone    latency  \
# strain session
# C57    1                                         692.527742  53.002185
#        2                                        1834.512652  18.630535
#        3                                        1693.640319  72.985558
#        4                                        1873.886106  10.317794
#        5                                        1827.291965   5.753625
#        6                                        1776.800769   6.570481
#        7                                        1824.753781   5.602062
#        8                                        1827.224312   7.283187
#        9                                        1827.843781  10.453344
#        10                                       1855.801200  11.509332
#        11                                       1881.306082  16.216906
#        12                                       1828.414625   7.163562
# CD1    1                                        1839.720241  27.302715
#        2                                        1862.412763  14.839676
#        3                                        1779.445921  14.032617
#        4                                        1817.926187  10.658819
#        5                                        1819.521937   9.470250
#        6                                        1799.072533   9.121378
#        7                                        1822.020313   7.789656
#        8                                        1867.865000   8.995762
#        9                                        1821.351813   8.500000
#        10                                       1820.208500   8.554755
#        11                                       1839.931377   7.277846
#
#                 latency_adjusted_greater_than_30  \
# strain session
# C57    1                               23.632771
#        2                               13.464640
#        3                               13.929044
#        4                                7.556556
#        5                                5.300937
#        6                                6.343397
#        7                                5.389281
#        8                                6.998469
#        9                                9.109562
#        10                              10.830120
#        11                               8.472719
#        12                               7.150125
# CD1    1                               15.675262
#        2                               11.159719
#        3                               11.363722
#        4                                9.303837
#        5                                9.102500
#        6                                8.402223
#        7                                7.638937
#        8                                8.478262
#        9                                7.956875
#        10                               8.144285
#        11                               6.549916
#
#                 overlapping_port_entry_with_tone  latency_adjusted_overlap  \
# strain session
# C57    1                                0.079687                 21.796391
#        2                                0.076753                 13.189141
#        3                                0.120427                 13.179933
#        4                                0.157241                  6.408477
#        5                                0.221875                  3.758562
#        6                                0.282051                  3.417821
#        7                                0.303125                  2.365656
#        8                                0.362500                  1.979469
#        9                                0.437500                  2.668594
#        10                               0.497790                  1.504085
#        11                               0.371875                  1.951562
#        12                               0.337500                  1.623750
# CD1    1                                0.105488                 14.585052
#        2                                0.106707                 10.118720
#        3                                0.126677                 10.265494
#        4                                0.125000                  7.712469
#        5                                0.168750                  7.100125
#        6                                0.227484                  5.647042
#        7                                0.215625                  5.182969
#        8                                0.234756                  5.545549
#        9                                0.221875                  5.616875
#        10                               0.234375                  5.654656
#        11                               0.291432                  4.169961
#
#                 adjusted_30_second_latency_less_than_10_seconds_ratio  \
# strain session
# C57    1                                                 0.170313
#        2                                                 0.489863
#        3                                                 0.491387
#        4                                                 0.734223
#        5                                                 0.865625
#        6                                                 0.810897
#        7                                                 0.821875
#        8                                                 0.718750
#        9                                                 0.643750
#        10                                                0.560899
#        11                                                0.681250
#        12                                                0.737500
# CD1    1                                                 0.423323
#        2                                                 0.579268
#        3                                                 0.529878
#        4                                                 0.675000
#        5                                                 0.650000
#        6                                                 0.729327
#        7                                                 0.737500
#        8                                                 0.695122
#        9                                                 0.721875
#        10                                                0.706250
#        11                                                0.796904
#
#                 overlap_adjusted_latency_less_than_10_seconds
# strain session
# C57    1                                             0.234375
#        2                                             0.495960
#        3                                             0.516006
#        4                                             0.777363
#        5                                             0.912500
#        6                                             0.923077
#        7                                             0.953125
#        8                                             0.967187
#        9                                             0.940625
#        10                                            0.975076
#        11                                            0.971875
#        12                                            0.987500
# CD1    1                                             0.460518
#        2                                             0.615854
#        3                                             0.570046
#        4                                             0.734375
#        5                                             0.718750
#        6                                             0.826522
#        7                                             0.831250
#        8                                             0.807927
#        9                                             0.803125
#        10                                            0.793750
#        11                                            0.866323

# %%
strain_sem_first_porty_entry_dataframe = grouped_averaged_first_porty_entry_dataframe.groupby(by=["strain", "session"]).sem()

# %% [markdown]
# ## Reformatting the Dataframe for plotting

# %% [markdown]
# - Resetting the index so that we can use the data as a value

# %%
strain_averaged_first_porty_entry_dataframe = strain_averaged_first_porty_entry_dataframe.reset_index()
strain_sem_first_porty_entry_dataframe = strain_sem_first_porty_entry_dataframe.reset_index()

# %%
strain_averaged_first_porty_entry_dataframe.head()
# Out:
#   strain  session  current_tone_time  first_port_entry_after_tone  \
# 0    C57        1         698.780833                   734.433316
# 1    C57        2        1848.554207                  1844.271133
# 2    C57        3        1848.554207                  1710.002037
# 3    C57        4        1848.554207                  1858.872002
# 4    C57        5        1825.635000                  1831.388625
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   730.624326                   690.577578
# 1                                  1846.684866                  1833.374269
# 2                                  1713.004554                  1692.127284
# 3                                  1858.080024                  1872.052778
# 4                                  1836.880594                  1824.432103
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   692.527742  53.002185
# 1                                  1834.512652  18.630535
# 2                                  1693.640319  72.985558
# 3                                  1873.886106  10.317794
# 4                                  1827.291965   5.753625
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         23.632771                          0.079687
# 1                         13.464640                          0.076753
# 2                         13.929044                          0.120427
# 3                          7.556556                          0.157241
# 4                          5.300937                          0.221875
#
#    latency_adjusted_overlap  \
# 0                 21.796391
# 1                 13.189141
# 2                 13.179933
# 3                  6.408477
# 4                  3.758562
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.170313
# 1                                           0.489863
# 2                                           0.491387
# 3                                           0.734223
# 4                                           0.865625
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                       0.234375
# 1                                       0.495960
# 2                                       0.516006
# 3                                       0.777363
# 4                                       0.912500

# %%
strain_averaged_first_porty_entry_dataframe.groupby(["strain"]).max()
# Out:
#         session  current_tone_time  first_port_entry_after_tone  \
# strain
# C57          12        1848.554207                  1858.872002
# CD1          11        1871.473415                  1880.469177
#
#         port_exit_after_first_port_entry_after_tone  \
# strain
# C57                                     1858.080024
# CD1                                     1884.146524
#
#         last_port_entry_before_tone  \
# strain
# C57                     1873.034669
# CD1                     1862.473171
#
#         port_exit_after_last_port_entry_before_tone    latency  \
# strain
# C57                                     1881.306082  72.985558
# CD1                                     1867.865000  27.302715
#
#         latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# strain
# C57                            23.632771                          0.497790
# CD1                            15.675262                          0.291432
#
#         latency_adjusted_overlap  \
# strain
# C57                    21.796391
# CD1                    14.585052
#
#         adjusted_30_second_latency_less_than_10_seconds_ratio  \
# strain
# C57                                              0.865625
# CD1                                              0.796904
#
#         overlap_adjusted_latency_less_than_10_seconds
# strain
# C57                                          0.987500
# CD1                                          0.866323

# %%
min_number_of_sessions = strain_averaged_first_porty_entry_dataframe.groupby(["strain"]).max()["session"].min()

# %%
strain_averaged_first_porty_entry_dataframe = strain_averaged_first_porty_entry_dataframe[strain_averaged_first_porty_entry_dataframe["session"] <= min_number_of_sessions]
strain_sem_first_porty_entry_dataframe = strain_sem_first_porty_entry_dataframe[strain_sem_first_porty_entry_dataframe["session"] <= min_number_of_sessions]

# %%
strain_averaged_first_porty_entry_dataframe
# Out:
#    strain  session  current_tone_time  first_port_entry_after_tone  \
# 0     C57        1         698.780833                   734.433316
# 1     C57        2        1848.554207                  1844.271133
# 2     C57        3        1848.554207                  1710.002037
# 3     C57        4        1848.554207                  1858.872002
# 4     C57        5        1825.635000                  1831.388625
# 5     C57        6        1779.753590                  1786.324071
# 6     C57        7        1825.635000                  1831.237062
# 7     C57        8        1825.635000                  1832.918187
# 8     C57        9        1825.635000                  1836.088344
# 9     C57       10        1848.554207                  1854.333738
# 10    C57       11        1825.635000                  1841.851906
# 12    CD1        1        1848.554207                  1835.732186
# 13    CD1        2        1871.473415                  1869.118311
# 14    CD1        3        1848.554207                  1736.548635
# 15    CD1        4        1825.635000                  1830.558643
# 16    CD1        5        1825.635000                  1835.105250
# 17    CD1        6        1802.694295                  1811.815673
# 18    CD1        7        1825.635000                  1833.424656
# 19    CD1        8        1871.473415                  1880.469177
# 20    CD1        9        1825.635000                  1834.135000
# 21    CD1       10        1825.635000                  1828.454579
# 22    CD1       11        1825.613502                  1832.891348
#
#     port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                    730.624326                   690.577578
# 1                                   1846.684866                  1833.374269
# 2                                   1713.004554                  1692.127284
# 3                                   1858.080024                  1872.052778
# 4                                   1836.880594                  1824.432103
# 5                                   1792.469744                  1773.227340
# 6                                   1821.252619                  1820.546344
# 7                                   1840.489578                  1820.406828
# 8                                   1843.142906                  1818.400094
# 9                                   1851.339534                  1843.745284
# 10                                  1851.668312                  1873.034669
# 12                                  1839.399581                  1837.548620
# 13                                  1868.176423                  1860.896700
# 14                                  1741.357869                  1777.840024
# 15                                  1835.527563                  1814.608813
# 16                                  1838.480906                  1816.652375
# 17                                  1814.822623                  1793.668637
# 18                                  1837.166313                  1817.276687
# 19                                  1884.146524                  1862.473171
# 20                                  1837.267375                  1816.954313
# 21                                  1833.461191                  1816.459313
# 22                                  1836.751722                  1835.554646
#
#     port_exit_after_last_port_entry_before_tone    latency  \
# 0                                    692.527742  53.002185
# 1                                   1834.512652  18.630535
# 2                                   1693.640319  72.985558
# 3                                   1873.886106  10.317794
# 4                                   1827.291965   5.753625
# 5                                   1776.800769   6.570481
# 6                                   1824.753781   5.602062
# 7                                   1827.224312   7.283187
# 8                                   1827.843781  10.453344
# 9                                   1855.801200  11.509332
# 10                                  1881.306082  16.216906
# 12                                  1839.720241  27.302715
# 13                                  1862.412763  14.839676
# 14                                  1779.445921  14.032617
# 15                                  1817.926187  10.658819
# 16                                  1819.521937   9.470250
# 17                                  1799.072533   9.121378
# 18                                  1822.020313   7.789656
# 19                                  1867.865000   8.995762
# 20                                  1821.351813   8.500000
# 21                                  1820.208500   8.554755
# 22                                  1839.931377   7.277846
#
#     latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                          23.632771                          0.079687
# 1                          13.464640                          0.076753
# 2                          13.929044                          0.120427
# 3                           7.556556                          0.157241
# 4                           5.300937                          0.221875
# 5                           6.343397                          0.282051
# 6                           5.389281                          0.303125
# 7                           6.998469                          0.362500
# 8                           9.109562                          0.437500
# 9                          10.830120                          0.497790
# 10                          8.472719                          0.371875
# 12                         15.675262                          0.105488
# 13                         11.159719                          0.106707
# 14                         11.363722                          0.126677
# 15                          9.303837                          0.125000
# 16                          9.102500                          0.168750
# 17                          8.402223                          0.227484
# 18                          7.638937                          0.215625
# 19                          8.478262                          0.234756
# 20                          7.956875                          0.221875
# 21                          8.144285                          0.234375
# 22                          6.549916                          0.291432
#
#     latency_adjusted_overlap  \
# 0                  21.796391
# 1                  13.189141
# 2                  13.179933
# 3                   6.408477
# 4                   3.758562
# 5                   3.417821
# 6                   2.365656
# 7                   1.979469
# 8                   2.668594
# 9                   1.504085
# 10                  1.951562
# 12                 14.585052
# 13                 10.118720
# 14                 10.265494
# 15                  7.712469
# 16                  7.100125
# 17                  5.647042
# 18                  5.182969
# 19                  5.545549
# 20                  5.616875
# 21                  5.654656
# 22                  4.169961
#
#     adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                            0.170313
# 1                                            0.489863
# 2                                            0.491387
# 3                                            0.734223
# 4                                            0.865625
# 5                                            0.810897
# 6                                            0.821875
# 7                                            0.718750
# 8                                            0.643750
# 9                                            0.560899
# 10                                           0.681250
# 12                                           0.423323
# 13                                           0.579268
# 14                                           0.529878
# 15                                           0.675000
# 16                                           0.650000
# 17                                           0.729327
# 18                                           0.737500
# 19                                           0.695122
# 20                                           0.721875
# 21                                           0.706250
# 22                                           0.796904
#
#     overlap_adjusted_latency_less_than_10_seconds
# 0                                        0.234375
# 1                                        0.495960
# 2                                        0.516006
# 3                                        0.777363
# 4                                        0.912500
# 5                                        0.923077
# 6                                        0.953125
# 7                                        0.967187
# 8                                        0.940625
# 9                                        0.975076
# 10                                       0.971875
# 12                                       0.460518
# 13                                       0.615854
# 14                                       0.570046
# 15                                       0.734375
# 16                                       0.718750
# 17                                       0.826522
# 18                                       0.831250
# 19                                       0.807927
# 20                                       0.803125
# 21                                       0.793750
# 22                                       0.866323

# %%
strain_averaged_first_porty_entry_dataframe = strain_averaged_first_porty_entry_dataframe.reset_index(drop=True)
strain_sem_first_porty_entry_dataframe = strain_sem_first_porty_entry_dataframe.reset_index(drop=True)

# %%
strain_sem_first_porty_entry_dataframe
# Out:
#    strain  session  current_tone_time  first_port_entry_after_tone  \
# 0     C57        1           8.732554                     9.858381
# 1     C57        2           8.662646                    16.206641
# 2     C57        3           8.662646                   198.926791
# 3     C57        4           8.662646                     9.620978
# 4     C57        5           0.000000                     1.027737
# 5     C57        6           0.000000                     0.859800
# 6     C57        7           0.000000                     0.822071
# 7     C57        8           0.000000                     0.597163
# 8     C57        9           0.000000                     2.596097
# 9     C57       10           8.662646                     8.259394
# 10    C57       11           0.000000                     8.166350
# 11    CD1        1           8.662646                     6.797315
# 12    CD1        2           0.000000                     9.865552
# 13    CD1        3           8.662646                   123.492666
# 14    CD1        4           0.000000                     5.492817
# 15    CD1        5           0.000000                     1.017113
# 16    CD1        6           8.670772                    10.071282
# 17    CD1        7           0.000000                     1.313846
# 18    CD1        8           0.000000                     1.304380
# 19    CD1        9           0.000000                     1.599468
# 20    CD1       10           0.000000                     5.370005
# 21    CD1       11          17.333418                    16.175455
#
#     port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                     10.121707                    21.458840
# 1                                     16.257211                     9.816555
# 2                                    199.300545                   190.152020
# 3                                     12.490109                    24.543378
# 4                                      1.717984                     5.978746
# 5                                      1.701600                     0.626506
# 6                                      8.225976                     0.596956
# 7                                      1.420446                     0.429544
# 8                                      3.050312                     1.236644
# 9                                      5.688243                     8.797253
# 10                                     8.063210                    44.903729
# 11                                     6.733962                    16.562246
# 12                                    11.423242                     6.516139
# 13                                   123.972759                    62.721958
# 14                                     5.742349                     1.449652
# 15                                     1.492423                     1.425087
# 16                                    10.249780                     7.689434
# 17                                     1.725813                     1.492971
# 18                                     1.728498                     1.589562
# 19                                     1.878868                     1.586638
# 20                                     5.368522                     2.086407
# 21                                    16.067012                    15.146724
#
#     port_exit_after_last_port_entry_before_tone    latency  \
# 0                                     21.577685   7.315065
# 1                                      9.763427   3.862162
# 2                                    190.246980  45.167431
# 3                                     24.564751   3.005664
# 4                                      5.741217   1.027737
# 5                                      1.386252   0.859800
# 6                                      0.934295   0.822071
# 7                                      0.964646   0.597163
# 8                                      1.624841   2.596097
# 9                                      7.916088   2.011260
# 10                                    45.197099   8.166350
# 11                                    16.611544   5.837154
# 12                                     6.338254   3.227186
# 13                                    62.828559   2.739048
# 14                                     1.412289   1.338022
# 15                                     1.329128   1.017113
# 16                                     9.174658   1.913345
# 17                                     1.124663   1.313846
# 18                                     1.609507   1.304380
# 19                                     1.652682   1.599468
# 20                                     2.609424   1.268489
# 21                                    15.988902   2.019491
#
#     latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                           1.375029                          0.032784
# 1                           1.964801                          0.024638
# 2                           2.625337                          0.026669
# 3                           0.947150                          0.029844
# 4                           0.675598                          0.018563
# 5                           0.815148                          0.030261
# 6                           0.718462                          0.024292
# 7                           0.529089                          0.026092
# 8                           1.786568                          0.057671
# 9                           1.730495                          0.058046
# 10                          1.212851                          0.059281
# 11                          1.642938                          0.024511
# 12                          1.686359                          0.018970
# 13                          1.488506                          0.031366
# 14                          1.012569                          0.031339
# 15                          0.956288                          0.040020
# 16                          1.582144                          0.054094
# 17                          1.247317                          0.048857
# 18                          1.158312                          0.054135
# 19                          1.393368                          0.044681
# 20                          1.145640                          0.061408
# 21                          1.457390                          0.055756
#
#     latency_adjusted_overlap  \
# 0                   1.666434
# 1                   2.032994
# 2                   2.690920
# 3                   0.974192
# 4                   0.518317
# 5                   0.450786
# 6                   0.306639
# 7                   0.328116
# 8                   0.485979
# 9                   0.265548
# 10                  0.669690
# 11                  1.727785
# 12                  1.732589
# 13                  1.581271
# 14                  0.925427
# 15                  0.975455
# 16                  0.654623
# 17                  0.619516
# 18                  0.632158
# 19                  1.192653
# 20                  1.371607
# 21                  0.950440
#
#     adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                            0.040623
# 1                                            0.071984
# 2                                            0.101558
# 3                                            0.049365
# 4                                            0.041441
# 5                                            0.041667
# 6                                            0.043670
# 7                                            0.037126
# 8                                            0.074215
# 9                                            0.067814
# 10                                           0.052769
# 11                                           0.062518
# 12                                           0.070622
# 13                                           0.080769
# 14                                           0.046049
# 15                                           0.052184
# 16                                           0.069800
# 17                                           0.062142
# 18                                           0.055885
# 19                                           0.060029
# 20                                           0.066774
# 21                                           0.070245
#
#     overlap_adjusted_latency_less_than_10_seconds
# 0                                        0.046430
# 1                                        0.072217
# 2                                        0.103184
# 3                                        0.047328
# 4                                        0.030981
# 5                                        0.024708
# 6                                        0.020287
# 7                                        0.013557
# 8                                        0.023593
# 9                                        0.011573
# 10                                       0.024748
# 11                                       0.064845
# 12                                       0.071519
# 13                                       0.084407
# 14                                       0.044806
# 15                                       0.051701
# 16                                       0.026622
# 17                                       0.027038
# 18                                       0.030027
# 19                                       0.055388
# 20                                       0.067769
# 21                                       0.053616

# %% [markdown]
# ## Plotting the latencies that were adjusted if they greater than 30 seconds

# %%
per_strain_output_directory = "./proc/plots/per_strain_plots/{}_cage_{}_date_{}_{}".format(cohort, cage_numbers_for_title, earliest_date, latest_date)

# %%
per_strain_output_directory
# Out:
# './proc/plots/per_strain_plots/pilot_1_cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(per_strain_output_directory, exist_ok=True)

# %%
plt.rcParams["figure.figsize"] = (13.5,7.5)

# %%
strain_averaged_first_porty_entry_dataframe.head()
# Out:
#   strain  session  current_tone_time  first_port_entry_after_tone  \
# 0    C57        1         698.780833                   734.433316
# 1    C57        2        1848.554207                  1844.271133
# 2    C57        3        1848.554207                  1710.002037
# 3    C57        4        1848.554207                  1858.872002
# 4    C57        5        1825.635000                  1831.388625
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   730.624326                   690.577578
# 1                                  1846.684866                  1833.374269
# 2                                  1713.004554                  1692.127284
# 3                                  1858.080024                  1872.052778
# 4                                  1836.880594                  1824.432103
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   692.527742  53.002185
# 1                                  1834.512652  18.630535
# 2                                  1693.640319  72.985558
# 3                                  1873.886106  10.317794
# 4                                  1827.291965   5.753625
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         23.632771                          0.079687
# 1                         13.464640                          0.076753
# 2                         13.929044                          0.120427
# 3                          7.556556                          0.157241
# 4                          5.300937                          0.221875
#
#    latency_adjusted_overlap  \
# 0                 21.796391
# 1                 13.189141
# 2                 13.179933
# 3                  6.408477
# 4                  3.758562
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.170313
# 1                                           0.489863
# 2                                           0.491387
# 3                                           0.734223
# 4                                           0.865625
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                       0.234375
# 1                                       0.495960
# 2                                       0.516006
# 3                                       0.777363
# 4                                       0.912500

# %%
strain_to_color = {"CD1": "#15616f", "C57": "#ffaf00"}

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (13.5,7.5)

# Plotting a line for each subject
for strain in strain_averaged_first_porty_entry_dataframe["strain"].unique():
    # Getting all the rows with the current subject
    strain_df = strain_averaged_first_porty_entry_dataframe[strain_averaged_first_porty_entry_dataframe["strain"] == strain]
    std_df = strain_sem_first_porty_entry_dataframe[strain_sem_first_porty_entry_dataframe["strain"] == strain]

    # Making the dates into days after the first session by subtracting all the dates by the first date
    ax.plot(strain_df["session"], strain_df["latency_adjusted_greater_than_30"], '-o', \
            label=strain, c=strain_to_color[strain])
#     ax.errorbar(strain_df["session"], strain_df["latency_adjusted_greater_than_30"], \
#                 yerr=std_df["latency_adjusted_greater_than_30"], c=strain_to_color[strain])
    ax.fill_between(strain_df["session"], strain_df["latency_adjusted_greater_than_30"]-std_df["latency_adjusted_greater_than_30"], \
                    strain_df["latency_adjusted_greater_than_30"]+std_df["latency_adjusted_greater_than_30"], \
                   alpha=.25, color=strain_to_color[strain])

# Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
ax.set_ylim(0, 30)
# Labeling the X/Y Axis and the title
ax.set_xlabel("The Days After the First Session")
ax.set_ylabel("Adjusted Average Latency of First Entry to Tone Onset")
ax.set_title("Average Latency of Port Entry to Tone Onset for {}".format(cohort))
# To show the legend
ax.legend()
file_name = "strain_average_latency_{}_cage_{}_date_{}_{}.svg".format(cohort, cage_numbers_for_title, earliest_date, latest_date)
plt.savefig(os.path.join(per_strain_output_directory, file_name))

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (13.5,7.5)

# Plotting a line for each subject
for strain in strain_averaged_first_porty_entry_dataframe["strain"].unique():
    # Getting all the rows with the current subject
    strain_df = strain_averaged_first_porty_entry_dataframe[strain_averaged_first_porty_entry_dataframe["strain"] == strain]
    std_df = strain_sem_first_porty_entry_dataframe[strain_sem_first_porty_entry_dataframe["strain"] == strain]

    # Making the dates into days after the first session by subtracting all the dates by the first date
    ax.plot(strain_df["session"], strain_df["overlap_adjusted_latency_less_than_10_seconds"], '-o', \
            label=strain, c=strain_to_color[strain])
#     ax.errorbar(strain_df["session"], strain_df["overlap_adjusted_latency_less_than_10_seconds"], \
#                 yerr=std_df["overlap_adjusted_latency_less_than_10_seconds"], c=strain_to_color[strain])
    ax.fill_between(strain_df["session"], strain_df["overlap_adjusted_latency_less_than_10_seconds"]-std_df["overlap_adjusted_latency_less_than_10_seconds"], \
                    strain_df["overlap_adjusted_latency_less_than_10_seconds"]+std_df["overlap_adjusted_latency_less_than_10_seconds"], \
                   alpha=.25, color=strain_to_color[strain])

# Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
# ax.set_ylim(0, 30)
# Labeling the X/Y Axis and the title
ax.set_xlabel("The Days After the First Session")
ax.set_ylabel("Proportion of Less than 10 Seconds Latencies")
ax.set_title("Less than 10 Seconds Latency of Port Entry to Tone Onset for {}".format(cohort))
# To show the legend
ax.legend()
file_name = "strain_less_than_10_seconds_latency_{}_cage_{}_date_{}_{}.svg".format(cohort, cage, earliest_date, latest_date)
plt.savefig(os.path.join(per_strain_output_directory, file_name))

# %%
grouped_averaged_first_porty_entry_dataframe["cohort"] = cohort

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#    session subject  current_tone_time  first_port_entry_after_tone  \
# 0        1     1.1         675.676667                   717.894667
# 1        1     1.2         721.885000                   679.113571
# 2        1     1.3         721.885000                   762.274667
# 3        1     1.4         675.676667                   737.022000
# 4        1     2.1         721.885000                   752.838125
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   718.904667                   708.214615
# 1                                   681.099286                   787.512143
# 2                                   764.120000                   637.862500
# 3                                   737.790667                   613.392000
# 4                                   757.749375                   701.735625
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   708.941538  42.218000
# 1                                   790.962857  49.817857
# 2                                   640.833125  86.598000
# 3                                   614.831333  61.345333
# 4                                   703.736875  30.953125
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         19.980000                          0.000000
# 1                         27.120000                          0.187500
# 2                         27.746000                          0.000000
# 3                         22.285333                          0.066667
# 4                         17.701875                          0.250000
#
#    latency_adjusted_overlap  \
# 0                 19.980000
# 1                 22.605714
# 2                 27.746000
# 3                 21.607333
# 4                 12.203125
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.333333
# 1                                           0.062500
# 2                                           0.000000
# 3                                           0.200000
# 4                                           0.250000
#
#    overlap_adjusted_latency_less_than_10_seconds cage strain   cohort
# 0                                       0.333333    1    C57  pilot_1
# 1                                       0.187500    2    C57  pilot_1
# 2                                       0.000000    2    C57  pilot_1
# 3                                       0.266667    1    C57  pilot_1
# 4                                       0.437500    2    C57  pilot_1

# %%
grouped_averaged_first_porty_entry_dataframe_output_directory = "./proc/grouped_averaged_first_porty_entry/{}_cage_{}_date_{}_{}".format(cohort, cage_numbers_for_title, earliest_date, latest_date)

# %%
grouped_averaged_first_porty_entry_dataframe_output_directory
# Out:
# './proc/grouped_averaged_first_porty_entry/pilot_1_cage_1_2_3_4_date_20220503_20220517'

# %%
os.makedirs(grouped_averaged_first_porty_entry_dataframe_output_directory, exist_ok=True)

# %%
grouped_averaged_first_porty_entry_dataframe.to_csv(os.path.join(grouped_averaged_first_porty_entry_dataframe_output_directory, "grouped_averaged_first_porty_entry_{}_cage_{}_date_{}_{}.csv".format(cohort, cage_numbers_for_title, earliest_date, latest_date)))
