# %% [markdown]
# # Notebook 1: MED-PC Extracting the Recording Data and Metadata

# %% [markdown]
# Brief 1-2 sentence description of notebook.

# %%
import os
import sys
import glob
import re
from collections import defaultdict

# %%
# Imports of all used packages and libraries
import pandas as pd

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.metadata
import extract.dataframe

# %% [markdown]
# ## Inputs & Data

# %% [markdown]
# Explanation of each input and where it comes from.

# %%
# Inputs and Required data loading
# input varaible names are in all caps snake case
# Whenever an input changes or is used for processing 
# the vairables are all lower in snake case
INPUT_VARIABLE = 1
OUTPUT_DIR = r"/root/work/" # where data is saved should always be shown in the inputs
OUTPUT_PREFIX = "example"

# %%
# Getting all the file paths of the recording files(that happen to all end in `.txt`)
ALL_MED_PC_FILE = glob.glob("./data/*.txt")

# %% [markdown]
# ## Outputs

# %% [markdown]
# Describe each output that the notebook creates.

# %% [markdown]
# - Is it a plot or is it data?

# %% [markdown]
# - How valuable is the output and why is it valuable or useful?

# %% [markdown]
# ## Processing

# %% [markdown]
# - Example of what the MED-PC Recording file looks like

# %%
with open(ALL_MED_PC_FILE[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-09-24_16h16m_Subject 2.3.txt
#
#
#
#
#
#
#
# Start Date: 09/24/22
#
# End Date: 09/24/22
#
# Subject: 2.3
#
# Experiment: CD1_vs_C57_Comparison
#
# Group: Cage_2
#
# Box: 1
#
# Start Time: 16:16:04
#
# End Time: 17:19:06
#
# MSN: C57_reward_training
#
# A:    4399.000
#
# D:    9000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    3660.000

# %% [markdown]
# - We will be extracting the first 10 or so lines that look like:
#
# ```
# File: C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (2).txt
#
# Start Date: 05/06/22
#
# End Date: 05/06/22
#
# Subject: 3.4 (2)
#
# Experiment: Pilot of Pilot
#
# Group: Cage 4
#
# Box: 1
#
# Start Time: 12:59:58
#
# End Time: 14:02:38
#
# MSN: levelNP_CS_reward_laserepochON1st_noshock
# ```

# %% [markdown]
# - We will just find all the lines that start with `"File", "Start Date", "End Date", "Subject", "Experiment", "Group", "Box", "Start Time", "End Time", or "MSN"`. And get the metadata from those lines. And then stop once all the metadata types have been collected

# %%
# This makes a nested dictionary of file paths to each individual metadata type
file_path_to_meta_data = extract.metadata.get_all_med_pc_meta_data_from_files(list_of_files=ALL_MED_PC_FILE)

# %%
# The metadata for the first file
for key, value in file_path_to_meta_data.items():
    print("File path: {}".format(key))
    print("Metadata types and associated values: {}".format(value))
    break
# Out:
# File path: ./data/2022-09-24_16h16m_Subject 2.3.txt
# Metadata types and associated values: {'File': 'C:\\MED-PC\\Data\\2022-09-24_16h16m_Subject 2.3.txt', 'Start Date': '09/24/22', 'End Date': '09/24/22', 'Subject': '2.3', 'Experiment': 'CD1_vs_C57_Comparison', 'Group': 'Cage_2', 'Box': '1', 'Start Time': '16:16:04', 'End Time': '17:19:06', 'MSN': 'C57_reward_training'}

# %% [markdown]
# ## Making a Dataframe out of the Metadata

# %% [markdown]
# - A Dataframe is essentially a "programmable" spreadsheet. But instead of clicking on cells, you will have to tell Python how you want to interact with the spreadsheet
#     - For more information: https://realpython.com/pandas-dataframe/

# %%
# Turning the dictionary into a Pandas Dataframe
metadata_df = pd.DataFrame.from_dict(file_path_to_meta_data, orient="index")
# Resetting the index because currently the file path is the index 
metadata_df = metadata_df.reset_index()

# %% [markdown]
# - Removing all rows that don't have a cage number (which is called group in here)

# %%
metadata_df = metadata_df.dropna(subset=["Group"])

# %%
metadata_df = metadata_df[metadata_df["Group"] != ""]

# %% [markdown]
# - Getting the numbers out of the column that contains the cage information

# %%
metadata_df["cage"] = metadata_df["Group"].apply(lambda x: re.findall(r'\d+', x)[0])

# %%
metadata_df["cage"].unique()
# Out:
# array(['2', '1'], dtype=object)

# %% [markdown]
# - Labeling the cohort name based on the date

# %%
# Turning the string into a datetime object
metadata_df["date"] = pd.to_datetime(metadata_df["Start Date"])

# %% [markdown]
# - Grouping the cohorts

# %%
metadata_df = metadata_df.sort_values(["date", "Start Time", "Subject"]).reset_index(drop=True)

# %%
metadata_df.head()
# Out:
#                                       index  \
# 0  ./data/2022-09-20_10h06m_Subject 1.1.txt
# 1  ./data/2022-09-20_10h06m_Subject 1.2.txt
# 2  ./data/2022-09-20_10h06m_Subject 1.3.txt
# 3  ./data/2022-09-20_10h06m_Subject 1.4.txt
# 4  ./data/2022-09-20_13h36m_Subject 2.1.txt
#
#                                                File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-09-20_10h06m_Subject 1.1.txt   09/20/22  09/20/22
# 1  C:\MED-PC\Data\2022-09-20_10h06m_Subject 1.2.txt   09/20/22  09/20/22
# 2  C:\MED-PC\Data\2022-09-20_10h06m_Subject 1.3.txt   09/20/22  09/20/22
# 3  C:\MED-PC\Data\2022-09-20_10h06m_Subject 1.4.txt   09/20/22  09/20/22
# 4  C:\MED-PC\Data\2022-09-20_13h36m_Subject 2.1.txt   09/20/22  09/20/22
#
#   Subject             Experiment   Group Box Start Time  End Time  \
# 0     1.1  CD1_vs_C57_Comparison  Cage_1   2   10:06:09  11:13:16
# 1     1.2  CD1_vs_C57_Comparison  Cage_1   4   10:06:09  11:13:16
# 2     1.3  CD1_vs_C57_Comparison  Cage_1   1   10:06:09  11:13:16
# 3     1.4  CD1_vs_C57_Comparison  Cage_1   3   10:06:09  11:13:16
# 4     2.1  CD1_vs_C57_Comparison  Cage_2   2   13:36:03  14:46:38
#
#                    MSN cage       date
# 0  C57_reward_training    1 2022-09-20
# 1  C57_reward_training    1 2022-09-20
# 2  C57_reward_training    1 2022-09-20
# 3  C57_reward_training    1 2022-09-20
# 4  C57_reward_training    2 2022-09-20

# %%
concatted_medpc_df = extract.dataframe.get_medpc_dataframe_from_list_of_files(medpc_files=ALL_MED_PC_FILE)

# %%
concatted_medpc_df = concatted_medpc_df.drop(columns=["date"])

# %% [markdown]
# - Combining the recording and the metadata into one dataframe

# %%
recording_and_metadata_df = concatted_medpc_df.merge(metadata_df, left_on='file_path', right_on='index', how="inner")

# %%
recording_and_metadata_df = recording_and_metadata_df.sort_values(["date", "Start Time", "Subject"]).reset_index(drop=True)

# %%
recording_and_metadata_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         45.37           64.0      399.0           0.0              60.01
# 1         71.12          144.0      399.0           0.0             140.01
# 2         71.24          234.0      399.0           0.0             230.01
# 3         71.56          314.0      399.0           0.0             310.01
# 4         71.66          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0        45.43        1.0                                    17.0
# 1        71.21        1.0                                    37.0
# 2        71.34        1.0                                     6.0
# 3        71.59        1.0                                    27.0
# 4        71.71        1.0                                    41.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    13.0
# 1                                    14.0
# 2                                    16.0
# 3                                    17.0
# 4                                    18.0
#
#    (I)controlled_stimulus_hourscomputer  ...  End Date  Subject  \
# 0                                  10.0  ...  09/20/22      1.1
# 1                                  10.0  ...  09/20/22      1.1
# 2                                  10.0  ...  09/20/22      1.1
# 3                                  10.0  ...  09/20/22      1.1
# 4                                  10.0  ...  09/20/22      1.1
#
#               Experiment   Group Box Start Time  End Time  \
# 0  CD1_vs_C57_Comparison  Cage_1   2   10:06:09  11:13:16
# 1  CD1_vs_C57_Comparison  Cage_1   2   10:06:09  11:13:16
# 2  CD1_vs_C57_Comparison  Cage_1   2   10:06:09  11:13:16
# 3  CD1_vs_C57_Comparison  Cage_1   2   10:06:09  11:13:16
# 4  CD1_vs_C57_Comparison  Cage_1   2   10:06:09  11:13:16
#
#                    MSN cage       date
# 0  C57_reward_training    1 2022-09-20
# 1  C57_reward_training    1 2022-09-20
# 2  C57_reward_training    1 2022-09-20
# 3  C57_reward_training    1 2022-09-20
# 4  C57_reward_training    1 2022-09-20
#
# [5 rows x 28 columns]

# %%
recording_and_metadata_df.tail()
# Out:
#         (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  \
# 201495           NaN            NaN        NaN           NaN
# 201496           NaN            NaN        NaN           NaN
# 201497           NaN            NaN        NaN           NaN
# 201498           NaN            NaN        NaN           NaN
# 201499           NaN            NaN        NaN           NaN
#
#         (S)CSpresentation  (N)Portexit  (K)CStype  \
# 201495                NaN          NaN        NaN
# 201496                NaN          NaN        NaN
# 201497                NaN          NaN        NaN
# 201498                NaN          NaN        NaN
# 201499                NaN          NaN        NaN
#
#         (G)controlled_stimulus_secondscomputer  \
# 201495                                     NaN
# 201496                                     NaN
# 201497                                     NaN
# 201498                                     NaN
# 201499                                     NaN
#
#         (H)controlled_stimulus_minutescomputer  \
# 201495                                     NaN
# 201496                                     NaN
# 201497                                     NaN
# 201498                                     NaN
# 201499                                     NaN
#
#         (I)controlled_stimulus_hourscomputer  ...  End Date  Subject  \
# 201495                                   NaN  ...  09/27/22      1.4
# 201496                                   NaN  ...  09/27/22      1.4
# 201497                                   NaN  ...  09/27/22      1.4
# 201498                                   NaN  ...  09/27/22      1.4
# 201499                                   NaN  ...  09/27/22      1.4
#
#                    Experiment   Group Box Start Time  End Time  \
# 201495  CD1_vs_C57_Comparison  Cage_1   4   16:16:59  17:26:20
# 201496  CD1_vs_C57_Comparison  Cage_1   4   16:16:59  17:26:20
# 201497  CD1_vs_C57_Comparison  Cage_1   4   16:16:59  17:26:20
# 201498  CD1_vs_C57_Comparison  Cage_1   4   16:16:59  17:26:20
# 201499  CD1_vs_C57_Comparison  Cage_1   4   16:16:59  17:26:20
#
#                         MSN cage       date
# 201495  C57_reward_training    1 2022-09-27
# 201496  C57_reward_training    1 2022-09-27
# 201497  C57_reward_training    1 2022-09-27
# 201498  C57_reward_training    1 2022-09-27
# 201499  C57_reward_training    1 2022-09-27
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Adding other useful information

# %% [markdown]
# - Adding the date as the number of subsequent days since the start

# %%
recording_and_metadata_df["cage"] = recording_and_metadata_df["cage"].apply(lambda x: str(x).strip().lower()) 
recording_and_metadata_df["Subject"] = recording_and_metadata_df["Subject"].apply(lambda x: str(x).strip().lower())

# %%
recording_and_metadata_df["cohort_cage_id"] = recording_and_metadata_df.apply(lambda x: "_".join([x["cage"], x["Subject"]]), axis=1)

# %%
recording_and_metadata_df["cohort_cage_id"].unique()
# Out:
# array(['1_1.1', '1_1.2', '1_1.3', '1_1.4', '2_2.1', '2_2.2', '2_2.3',
#        '2_2.4'], dtype=object)

# %%
recording_and_metadata_df["date_str"] = recording_and_metadata_df["date"].dt.strftime('%Y-%m-%d')

# %%
cohort_cage_id_to_date_to_session = defaultdict(dict)

for cohort_cage_id in recording_and_metadata_df["cohort_cage_id"].unique():
    cohort_cage_id_df = recording_and_metadata_df[recording_and_metadata_df["cohort_cage_id"] == cohort_cage_id]
    for index, date in enumerate(sorted(cohort_cage_id_df["date_str"].unique())):
        cohort_cage_id_to_date_to_session[cohort_cage_id][date] = index + 1

# %%
date
# Out:
# '2022-09-27'

# %%
recording_and_metadata_df["session"] = recording_and_metadata_df.apply(lambda x: cohort_cage_id_to_date_to_session[x["cohort_cage_id"]][x["date_str"]], axis=1)

# %%
recording_and_metadata_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         45.37           64.0      399.0           0.0              60.01
# 1         71.12          144.0      399.0           0.0             140.01
# 2         71.24          234.0      399.0           0.0             230.01
# 3         71.56          314.0      399.0           0.0             310.01
# 4         71.66          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0        45.43        1.0                                    17.0
# 1        71.21        1.0                                    37.0
# 2        71.34        1.0                                     6.0
# 3        71.59        1.0                                    27.0
# 4        71.71        1.0                                    41.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    13.0
# 1                                    14.0
# 2                                    16.0
# 3                                    17.0
# 4                                    18.0
#
#    (I)controlled_stimulus_hourscomputer  ...   Group  Box  Start Time  \
# 0                                  10.0  ...  Cage_1    2    10:06:09
# 1                                  10.0  ...  Cage_1    2    10:06:09
# 2                                  10.0  ...  Cage_1    2    10:06:09
# 3                                  10.0  ...  Cage_1    2    10:06:09
# 4                                  10.0  ...  Cage_1    2    10:06:09
#
#    End Time                  MSN cage       date cohort_cage_id    date_str  \
# 0  11:13:16  C57_reward_training    1 2022-09-20          1_1.1  2022-09-20
# 1  11:13:16  C57_reward_training    1 2022-09-20          1_1.1  2022-09-20
# 2  11:13:16  C57_reward_training    1 2022-09-20          1_1.1  2022-09-20
# 3  11:13:16  C57_reward_training    1 2022-09-20          1_1.1  2022-09-20
# 4  11:13:16  C57_reward_training    1 2022-09-20          1_1.1  2022-09-20
#
#   session
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
# [5 rows x 31 columns]

# %%
recording_and_metadata_df.tail()
# Out:
#         (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  \
# 201495           NaN            NaN        NaN           NaN
# 201496           NaN            NaN        NaN           NaN
# 201497           NaN            NaN        NaN           NaN
# 201498           NaN            NaN        NaN           NaN
# 201499           NaN            NaN        NaN           NaN
#
#         (S)CSpresentation  (N)Portexit  (K)CStype  \
# 201495                NaN          NaN        NaN
# 201496                NaN          NaN        NaN
# 201497                NaN          NaN        NaN
# 201498                NaN          NaN        NaN
# 201499                NaN          NaN        NaN
#
#         (G)controlled_stimulus_secondscomputer  \
# 201495                                     NaN
# 201496                                     NaN
# 201497                                     NaN
# 201498                                     NaN
# 201499                                     NaN
#
#         (H)controlled_stimulus_minutescomputer  \
# 201495                                     NaN
# 201496                                     NaN
# 201497                                     NaN
# 201498                                     NaN
# 201499                                     NaN
#
#         (I)controlled_stimulus_hourscomputer  ...   Group  Box  Start Time  \
# 201495                                   NaN  ...  Cage_1    4    16:16:59
# 201496                                   NaN  ...  Cage_1    4    16:16:59
# 201497                                   NaN  ...  Cage_1    4    16:16:59
# 201498                                   NaN  ...  Cage_1    4    16:16:59
# 201499                                   NaN  ...  Cage_1    4    16:16:59
#
#         End Time                  MSN cage       date cohort_cage_id  \
# 201495  17:26:20  C57_reward_training    1 2022-09-27          1_1.4
# 201496  17:26:20  C57_reward_training    1 2022-09-27          1_1.4
# 201497  17:26:20  C57_reward_training    1 2022-09-27          1_1.4
# 201498  17:26:20  C57_reward_training    1 2022-09-27          1_1.4
# 201499  17:26:20  C57_reward_training    1 2022-09-27          1_1.4
#
#           date_str session
# 201495  2022-09-27       8
# 201496  2022-09-27       8
# 201497  2022-09-27       8
# 201498  2022-09-27       8
# 201499  2022-09-27       8
#
# [5 rows x 31 columns]

# %%
recording_and_metadata_df.groupby(["subject", "date", "session"]).count().head(n=50)
# Out:
#                             (P)Portentry  (Q)USdelivery  (R)UStime  \
# subject date       session
# 1.1     2022-09-20 1                 919             40         40
#         2022-09-21 2                1211             40         40
#         2022-09-22 3                2448             40         40
#         2022-09-23 4                1402             40         40
#         2022-09-24 5                1237             40         40
#         2022-09-25 6                 435             40         40
#         2022-09-26 7                2415             40         40
#         2022-09-27 8                2269             40         40
# 1.2     2022-09-20 1                1142             40         40
#         2022-09-21 2                1783             40         40
#         2022-09-22 3                1427             40         40
#         2022-09-23 4                3351             40         40
#         2022-09-24 5                1236             40         40
#         2022-09-25 6                5447             40         40
#         2022-09-24 5            2508  2508  2508            2508      2508
#         2022-09-25 6            5447  5447  5447            5447      5447
#         2022-09-26 7            2684  2684  2684            2684      2684
#         2022-09-27 8            6008  6008  6008            6008      6008
# 1.3     2022-09-20 1            2508  2508  2508            2508      2508
#         2022-09-21 2            2508  2508  2508            2508      2508
#         2022-09-22 3            2508  2508  2508            2508      2508
#         2022-09-23 4            2508  2508  2508            2508      2508
#         2022-09-24 5            2508  2508  2508            2508      2508
#         2022-09-25 6            2508  2508  2508            2508      2508
#         2022-09-26 7            3297  3297  3297            3297      3297
#         2022-09-27 8            6008  6008  6008            6008      6008
# 1.4     2022-09-20 1            2508  2508  2508            2508      2508
#         2022-09-21 2            2508  2508  2508            2508      2508
#         2022-09-22 3            3158  3158  3158            3158      3158
#         2022-09-23 4            2508  2508  2508            2508      2508
#         2022-09-24 5            2508  2508  2508            2508      2508
#         2022-09-25 6            3747  3747  3747            3747      3747
#         2022-09-26 7            2763  2763  2763            2763      2763
#         2022-09-27 8            6008  6008  6008            6008      6008
# 2.1     2022-09-20 1            2508  2508  2508            2508      2508
#         2022-09-21 2            2508  2508  2508            2508      2508
#         2022-09-22 3            2508  2508  2508            2508      2508
#         2022-09-23 4            2523  2523  2523            2523      2523
#         2022-09-24 5            2508  2508  2508            2508      2508
#         2022-09-25 6            2508  2508  2508            2508      2508
#         2022-09-26 7            3720  3720  3720            3720      3720
#         2022-09-27 8            6008  6008  6008            6008      6008
# 2.2     2022-09-20 1            2508  2508  2508            2508      2508
#         2022-09-21 2            2508  2508  2508            2508      2508
#         2022-09-22 3            2508  2508  2508            2508      2508
#         2022-09-23 4            2508  2508  2508            2508      2508
#         2022-09-24 5            2508  2508  2508            2508      2508
#         2022-09-25 6            3386  3386  3386            3386      3386
#         2022-09-26 7            2508  2508  2508            2508      2508
#         2022-09-27 8            6008  6008  6008            6008      6008
# 2.3     2022-09-20 1            2508  2508  2508            2508      2508
#         2022-09-21 2            2508  2508  2508            2508      2508
#
# [50 rows x 28 columns]

# %% [markdown]
# ## Saving the dataframes(spreadsheets to files) with the metadata as part of the name

# %% [markdown]
# - Making necessary directories
#     - If you want to use any of the other metadata as part of the name, you will have to swap out the variables in the `format()` and change the name of the folder to match your new name. The variable names are the word that's in front of the `=` at the last line of each cell. The `{}` are where the metadata variables will be inserted into the file name. For more information on formatting strings: https://www.w3schools.com/python/ref_string_format.asp
#     - You can also just manually rename the files by replacing everything in `""` and removing the `.format()` part
# - **NOTE: You may get an error that the file does not exist. If this is the case, it could be the file name is too long(an issue that may happen when using Jupyter Notebooks on Windows)**

# %%
output_directory = "./proc/extracted_recording_data_and_metadata"

# %%
output_directory
# Out:
# './proc/extracted_recording_data_and_metadata'

# %%
os.makedirs(output_directory, exist_ok=True)

# %%
metadata_df.to_csv(os.path.join(output_directory, "{}_pilot_reward_training_metadata.csv".format(OUTPUT_PREFIX)))

# %%
concatted_medpc_df.to_csv(os.path.join(output_directory, "{}_pilot_reward_training_medpc.csv".format(OUTPUT_PREFIX)))

# %%
recording_and_metadata_df.to_csv(os.path.join(output_directory, "{}_pilot_reward_training_medpc_metadata.csv".format(OUTPUT_PREFIX)))

# %%
recording_and_metadata_df.groupby(["date_str", "session"]).count()
# Out:
#                     (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  \
# date_str   session
# 2022-09-20 1                7426            296        296         20008
# 2022-09-21 2                9132            312        312         20008
# 2022-09-22 3               15101            319        319         20008
# 2022-09-23 4               14235            320        320         20008
# 2022-09-24 5               11211            320        320         20008
# 2022-09-25 6               21602            320        320         20008
# 2022-09-26 7               22486            320        320         20008
# 2022-09-27 8               26881            320        320         20008
#
#                     (S)CSpresentation  (N)Portexit  (K)CStype  \
# date_str   session
# 2022-09-20 1                      784         7426       2008
# 2022-09-21 2                      784         9131       2008
# 2022-09-22 3                      784        15101       2008
# 2022-09-23 4                      784        14235       2008
# 2022-09-24 5                      784        11208       2008
# 2022-09-25 6                      784        21600       2008
# 2022-09-26 7                      784        22483       2008
# 2022-09-27 8                      784        26878       2008
#
#                     (G)controlled_stimulus_secondscomputer  \
# date_str   session
# 2022-09-20 1                                          2008
# 2022-09-21 2                                          2008
# 2022-09-22 3                                          2008
# 2022-09-23 4                                          2008
# 2022-09-24 5                                          2008
# 2022-09-25 6                                          2008
# 2022-09-26 7                                          2008
# 2022-09-27 8                                          2008
#
#                     (H)controlled_stimulus_minutescomputer  \
# date_str   session
# 2022-09-20 1                                          2008
# 2022-09-21 2                                          2008
# 2022-09-22 3                                          2008
# 2022-09-23 4                                          2008
# 2022-09-24 5                                          2008
# 2022-09-25 6                                          2008
# 2022-09-26 7                                          2008
# 2022-09-27 8                                          2008
#
#                     (I)controlled_stimulus_hourscomputer  ...  Subject  \
# date_str   session                                        ...
# 2022-09-20 1                                        2008  ...    20064
# 2022-09-21 2                                        2008  ...    20064
# 2022-09-22 3                                        2008  ...    21678
# 2022-09-23 4                                        2008  ...    20922
# 2022-09-24 5                                        2008  ...    20064
# 2022-09-25 6                                        2008  ...    27157
# 2022-09-26 7                                        2008  ...    23487
# 2022-09-27 8                                        2008  ...    48064
#
#                     Experiment  Group    Box  Start Time  End Time    MSN  \
# date_str   session
# 2022-09-20 1             20064  20064  20064       20064     20064  20064
# 2022-09-21 2             20064  20064  20064       20064     20064  20064
# 2022-09-22 3             21678  21678  21678       21678     21678  21678
# 2022-09-23 4             20922  20922  20922       20922     20922  20922
# 2022-09-24 5             20064  20064  20064       20064     20064  20064
# 2022-09-25 6             27157  27157  27157       27157     27157  27157
# 2022-09-26 7             23487  23487  23487       23487     23487  23487
# 2022-09-27 8             48064  48064  48064       48064     48064  48064
#
#                      cage   date  cohort_cage_id
# date_str   session
# 2022-09-20 1        20064  20064           20064
# 2022-09-21 2        20064  20064           20064
# 2022-09-22 3        21678  21678           21678
# 2022-09-23 4        20922  20922           20922
# 2022-09-24 5        20064  20064           20064
# 2022-09-25 6        27157  27157           27157
# 2022-09-26 7        23487  23487           23487
# 2022-09-27 8        48064  48064           48064
#
# [8 rows x 29 columns]
